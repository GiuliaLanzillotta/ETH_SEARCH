# %% [markdown]
# # Extraction and insertion
#
# In this notebook there will be only the **final, necessary** code for the data extraction (cleaning/filtering/merging) and data import (into the graph database neo4j).

# %%
import pandas as pd
import os 
import numpy as np
import re
from zipfile import ZipFile

# %% [markdown]
# ## Extraction

# %% [markdown]
# ### 1. Filtering

# %%
# read all data files, stratified by publication type

zip_file = ZipFile('RC export 2020-10-12.zip')
files = {text_file.filename: pd.read_csv(zip_file.open(text_file.filename))
       for text_file in zip_file.infolist()
       if text_file.filename.endswith('.csv')}

ed = files["educational-2020-10-12.csv"]
books = files["books-2020-10-12.csv"]
conf = files["conference-2020-10-12.csv"]
journ = files["journal-2020-10-12.csv"]
oth = files["other-2020-10-12.csv"]
pap = files["papers-2020-10-12.csv"]
pat = files["patents-2020-10-12.csv"]
pres = files["presentations-2020-10-12.csv"]
# Out:
# /Users/andreasopedal/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (4,5,21,51,56,75,76,83,84,85,87,88) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# /Users/andreasopedal/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (5,35,49,52,54,56,57,72,73,74,77,79,86,87,91) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# /Users/andreasopedal/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (5,19,22,23,36,50,52,53,54,55,58,59,73,74,75,76,79,80,81,82,83,85,89,90,91,94,95,106,108) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# /Users/andreasopedal/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (6,34,35,36,53,58,69,73,74,75,79,80,87) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# /Users/andreasopedal/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (19,27,32,38,39,40,46,48,49,52,53,61,62,63,67,68,69,72,73,74,75,76,77,79,81,82,83,86,92) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
# we restrict ourselves to only book chapters, conference papers, journal papers and other papers

research_data_df = pd.concat([books, conf, journ, pap], ignore_index=True)
print(research_data_df.shape)
print("There are ", research_data_df.shape[0], "documents, ", 
      sum(research_data_df["dc.description.abstract"].notna()), " of which have abstracts")
research_data_df.head()
# Out:
# (176057, 114)
# There are  176057 documents,  21421  of which have abstracts
#        id collection                              dc.contributor.author  \
# 0  108069        NaN                               Schützeichel, Rainer
# 1  188444        NaN                        Milman, Vitali||Wagner, Roy
# 2  125569        NaN                                      Folkers, Gerd
# 3  157378        NaN  Mack, Rüdiger||Schleich, Wolfgang P.||Haase, D...
# 4   19843        NaN                   Burkhard, Remo||Schmitt, Gerhard
#
#                      dc.contributor.editor dc.contributor.other  \
# 0            Gerber, Andri||Kurath, Stefan                  NaN
# 1           Ball, Keith M.||Milman, Vitali                  NaN
# 2         Abel, Günter||Plümacher, Martina                  NaN
# 3  Arendt, Wolfgang||Schleich, Wolfgang P.                  NaN
# 4      Wang, Xiangyu||Schnabel, Marc Aurel                  NaN
#
#   dc.contributor.supervisor   dc.date.accessioned  \
# 0                       NaN  2017-06-11T21:44:58Z
# 1                       NaN  2017-10-23T13:08:25Z
# 2                       NaN  2017-06-12T18:11:46Z
# 3                       NaN  2017-06-14T12:24:19Z
# 4                       NaN  2017-06-08T23:42:55Z
#
#                                    dc.date.available dc.date.issued  \
# 0                               2017-06-11T21:44:58Z           2016
# 1  2017-06-12T14:30:31Z||2017-08-21T11:33:24Z||20...        1999-04
# 2                               2017-06-12T18:11:46Z           2016
# 3                               2017-06-14T12:24:19Z           2008
# 4                               2017-06-08T23:42:55Z           2008
#
#   dc.date.published  ... ethz.relation.isCompiledBy  \
# 0               NaN  ...                        NaN
# 1               NaN  ...                        NaN
# 2               NaN  ...                        NaN
# 3               NaN  ...                        NaN
# 4               NaN  ...                        NaN
#
#   ethz.relation.isDocumentedBy ethz.relation.references dc.language  \
# 0                          NaN                      NaN         NaN
# 1                          NaN                      NaN         NaN
# 2                          NaN                      NaN         NaN
# 3                          NaN                      NaN         NaN
# 4                          NaN                      NaN         NaN
#
#   ethz.identifier.pubmed ethz.relation.isReviewedBy ethz.relation.reviews  \
# 0                    NaN                        NaN                   NaN
# 1                    NaN                        NaN                   NaN
# 2                    NaN                        NaN                   NaN
# 3                    NaN                        NaN                   NaN
# 4                    NaN                        NaN                   NaN
#
#   ethz.version ethz.date.retentionend ethz.date.retentionendDate
# 0          NaN                    NaN                        NaN
# 1          NaN                    NaN                        NaN
# 2          NaN                    NaN                        NaN
# 3          NaN                    NaN                        NaN
# 4          NaN                    NaN                        NaN
#
# [5 rows x 114 columns]

# %%
set(research_data_df.columns)
# Out:
# {'collection',
#  'dc.contributor',
#  'dc.contributor.author',
#  'dc.contributor.editor',
#  'dc.contributor.other',
#  'dc.contributor.supervisor',
#  'dc.date.accessioned',
#  'dc.date.available',
#  'dc.date.issued',
#  'dc.date.published',
#  'dc.description.abstract',
#  'dc.format',
#  'dc.identifier.doi',
#  'dc.identifier.isbn',
#  'dc.identifier.issn',
#  'dc.identifier.olduri',
#  'dc.identifier.other',
#  'dc.identifier.uri',
#  'dc.identifier.wos',
#  'dc.language',
#  'dc.language.iso',
#  'dc.publisher',
#  'dc.relation.isnodouble',
#  'dc.relation.ispartof',
#  'dc.relation.isreplacedbydouble',
#  'dc.rights.license',
#  'dc.rights.uri',
#  'dc.subject',
#  'dc.title',
#  'dc.title.alternative',
#  'dc.type',
#  'ethz.availability',
#  'ethz.book.title',
#  'ethz.code.ddc',
#  'ethz.code.jel',
#  'ethz.date.deposited',
#  'ethz.date.embargoend',
#  'ethz.date.retentionend',
#  'ethz.date.retentionendDate',
#  'ethz.doipreview',
#  'ethz.ecitpid',
#  'ethz.ecolpid',
#  'ethz.edit.source',
#  'ethz.edit.status',
#  'ethz.eth',
#  'ethz.event',
#  'ethz.event.date',
#  'ethz.event.location',
#  'ethz.grant',
#  'ethz.grant.agreementno',
#  'ethz.grant.funderDoi',
#  'ethz.grant.fundername',
#  'ethz.grant.program',
#  'ethz.identifier.arxiv',
#  'ethz.identifier.diss',
#  'ethz.identifier.importid',
#  'ethz.identifier.internal',
#  'ethz.identifier.nebis',
#  'ethz.identifier.orcidWorkCode',
#  'ethz.identifier.pubmed',
#  'ethz.identifier.scopus',
#  'ethz.identifier.url',
#  'ethz.identifier.urn',
#  'ethz.identifier.wos',
#  'ethz.journal.abbreviated',
#  'ethz.journal.issue',
#  'ethz.journal.title',
#  'ethz.journal.volume',
#  'ethz.leitzahl',
#  'ethz.leitzahl.certified',
#  'ethz.leitzahlIdentifiers',
#  'ethz.leitzahlIdentifiers.certified',
#  'ethz.notes',
#  'ethz.pages.end',
#  'ethz.pages.start',
#  'ethz.publication.place',
#  'ethz.publication.status',
#  'ethz.relation.cites',
#  'ethz.relation.compiles',
#  'ethz.relation.continues',
#  'ethz.relation.documents',
#  'ethz.relation.hasPart',
#  'ethz.relation.isCitedBy',
#  'ethz.relation.isCompiledBy',
#  'ethz.relation.isContinuedBy',
#  'ethz.relation.isDerivedFrom',
#  'ethz.relation.isDocumentedBy',
#  'ethz.relation.isIdenticalTo',
#  'ethz.relation.isNewVersionOf',
#  'ethz.relation.isOriginalFormOf',
#  'ethz.relation.isPartOf',
#  'ethz.relation.isPreviousVersionOf',
#  'ethz.relation.isReferencedBy',
#  'ethz.relation.isReviewedBy',
#  'ethz.relation.isSourceOf',
#  'ethz.relation.isSupplementTo',
#  'ethz.relation.isSupplementedBy',
#  'ethz.relation.isVariantFormOf',
#  'ethz.relation.references',
#  'ethz.relation.reviews',
#  'ethz.rights.license',
#  'ethz.rights.uri',
#  'ethz.rosetta.exportRequired',
#  'ethz.rosetta.installDate',
#  'ethz.rosetta.lastUpdated',
#  'ethz.rosetta.versionExported',
#  'ethz.size',
#  'ethz.source',
#  'ethz.tag',
#  'ethz.title.subtitle',
#  'ethz.version',
#  'ethz.version.deposit',
#  'ethz.version.edition',
#  'id'}

# %%
research_data_df["ethz.leitzahl.certified"][0]
# Out:
# 'ETH Zürich::00002 - ETH Zürich, direkt::00012 - Lehre und Forschung, direkt::00007 - Departemente, direkt::02100 - Departement Architektur / Department of Architecture::02601 - Institut für Geschichte und Theorie der Architektur (gta) / Institute for the History and Theory of Architecture (gta)::03414 - Magnago Lampugnani, Vittorio (emeritus)'

# %%
# let's remove all irrelevant columns

rd_f = research_data_df[["id","dc.contributor.author","dc.title","dc.date.issued","dc.type","dc.description.abstract",
                 "dc.language.iso", "ethz.journal.title"]]
rd_f = rd_f.rename({"dc.contributor.author": "author", "dc.date.issued": "publication date",
                       "dc.title": "title", "dc.type": "publication type", "dc.description.abstract": "abstract",
                       "dc.language.iso": "language", "ethz.journal.title": "journal"}, 
              axis = 1)
rd_f.head()
# Out:
#        id                                             author  \
# 0  108069                               Schützeichel, Rainer
# 1  188444                        Milman, Vitali||Wagner, Roy
# 2  125569                                      Folkers, Gerd
# 3  157378  Mack, Rüdiger||Schleich, Wolfgang P.||Haase, D...
# 4   19843                   Burkhard, Remo||Schmitt, Gerhard
#
#                                                title publication date  \
# 0  Die Perspektive des Städtebauers. Ein Blick au...             2016
# 1  Asymptotic versions for operators and operator...          1999-04
# 2                                  On Re-Positioning             2016
# 3                                      Factorization             2008
# 4     Visualising future cities in the ETH Value Lab             2008
#
#   publication type                                           abstract  \
# 0     Book Chapter                                                NaN
# 1     Book Chapter  The goal of this note is to introduce new clas...
# 2     Book Chapter                                                NaN
# 3     Book Chapter                                                NaN
# 4     Book Chapter                                                NaN
#
#   language                                            journal
# 0       de                                         Grundlagen
# 1       en  Mathematical Sciences Research Institute Publi...
# 2       en               Berlin Studies in Knowledge Research
# 3       en                                                NaN
# 4       en                                                NaN

# %% [markdown]
# ### 2. Cleaning

# %%
# define helper functions for cleaning

def separate_names(names):
    """ Separes a string of names of the form name1||name2||name3||... into a list of names."""
    if isinstance(names, str):
        return names.split("||")

def date_to_year(date):
    """Get the dates into a single format (YYYY)"""
    if isinstance(date, str) and len(re.findall("[\d]{4}",date))>0:
        return re.findall("[\d]{4}",date)[0]

def date_to_year_and_month(date):
    """Get dates into format YYYY-MM"""
    # if needed later
    if isinstance(date, str):
        if len(re.findall("[\d]{4}[-][\d]{2}",date)) > 0:
            return re.findall("[\d]{4}[-][\d]{2}",date)[0]
        else:
            return str(date)

# %%
author_array = rd_f["author"].apply(separate_names)
rd_f["author"] = author_array
# Date format
date_format = date_to_year
date_array = rd_f["publication date"].apply(date_format)
rd_f["publication date"] = date_array

rd_f.head()
# Out:
#        id                                             author  \
# 0  108069                             [Schützeichel, Rainer]
# 1  188444                      [Milman, Vitali, Wagner, Roy]
# 2  125569                                    [Folkers, Gerd]
# 3  157378  [Mack, Rüdiger, Schleich, Wolfgang P., Haase, ...
# 4   19843                 [Burkhard, Remo, Schmitt, Gerhard]
#
#                                                title publication date  \
# 0  Die Perspektive des Städtebauers. Ein Blick au...             2016
# 1  Asymptotic versions for operators and operator...             1999
# 2                                  On Re-Positioning             2016
# 3                                      Factorization             2008
# 4     Visualising future cities in the ETH Value Lab             2008
#
#   publication type                                           abstract  \
# 0     Book Chapter                                                NaN
# 1     Book Chapter  The goal of this note is to introduce new clas...
# 2     Book Chapter                                                NaN
# 3     Book Chapter                                                NaN
# 4     Book Chapter                                                NaN
#
#   language                                            journal
# 0       de                                         Grundlagen
# 1       en  Mathematical Sciences Research Institute Publi...
# 2       en               Berlin Studies in Knowledge Research
# 3       en                                                NaN
# 4       en                                                NaN

# %%
# a little detour: check how many papers were published each year

rd_f[["id","publication date"]].groupby("publication date").count().sort_values("publication date", ascending = False).rename({'id':'count'}, axis = 1).head(20)
# Out:
#                   count
# publication date
# 2021                 54
# 2020               7002
# 2019              11291
# 2018              11293
# 2017              11169
# 2016              11605
# 2015              11495
# 2014              11822
# 2013              11644
# 2012              10611
# 2011               9777
# 2010               9550
# 2009               8929
# 2008               8440
# 2007               8322
# 2006               7670
# 2005               6717
# 2004               5144
# 2003               4418
# 2002               1317

# %%
# now explode on author field

rd_fe = rd_f.explode("author")
print("Shape changed from ", rd_f.shape, " to ", rd_fe.shape)
rd_fe.head()
# Out:
# Shape changed from  (176057, 8)  to  (867718, 8)
#        id                author  \
# 0  108069  Schützeichel, Rainer
# 1  188444        Milman, Vitali
# 1  188444           Wagner, Roy
# 2  125569         Folkers, Gerd
# 3  157378         Mack, Rüdiger
#
#                                                title publication date  \
# 0  Die Perspektive des Städtebauers. Ein Blick au...             2016
# 1  Asymptotic versions for operators and operator...             1999
# 1  Asymptotic versions for operators and operator...             1999
# 2                                  On Re-Positioning             2016
# 3                                      Factorization             2008
#
#   publication type                                           abstract  \
# 0     Book Chapter                                                NaN
# 1     Book Chapter  The goal of this note is to introduce new clas...
# 1     Book Chapter  The goal of this note is to introduce new clas...
# 2     Book Chapter                                                NaN
# 3     Book Chapter                                                NaN
#
#   language                                            journal
# 0       de                                         Grundlagen
# 1       en  Mathematical Sciences Research Institute Publi...
# 1       en  Mathematical Sciences Research Institute Publi...
# 2       en               Berlin Studies in Knowledge Research
# 3       en                                                NaN

# %% [markdown]
# ### 3. Merge with department and organisation data

# %% [markdown]
# #### 3.1 Organisation data

# %%
pl = pd.read_excel("ETH Professor list.xlsx")

# %%
# create professor column and keep only the relevant columns

pl["Professor"] = pl["Name"] + ", " + pl["First name"]
pl = pl[["Professor", "Org. unit code", "Organisation"]]
pl.columns = ["professor", "organisation unit code", "organisation"]
print(pl.shape)
pl.head()
# Out:
# (732, 3)
#            professor  organisation unit code  \
# 0    Abhari, Reza S.                    2627
# 1  Acciaio, Beatrice                    9727
# 2  Ackermann, Martin                    3743
# 3  Ackermann, Martin                    2721
# 4     Adey, Bryan T.                    2604
#
#                                organisation
# 0   Institute of Energy Technology (former)
# 1                         Acciaio, Beatrice
# 2                         Ackermann, Martin
# 3  Inst. Biogeochem. and Pollutant Dynamics
# 4  Inst. Construction&Infrastructure Manag.

# %%
# merge with exploded research collection

rd_m = rd_fe.merge(pl,how="outer",right_on="professor",left_on="author")
print("Shape of research collection changed from ", rd_fe.shape, " to ", rd_m.shape, ". Diff: ", 
      rd_m.shape[0]-rd_fe.shape[0])
rd_m.head(3)
# Out:
# Shape of research collection changed from  (867718, 8)  to  (877074, 11) . Diff:  9356
#          id                author  \
# 0  108069.0  Schützeichel, Rainer
# 1  127413.0  Schützeichel, Rainer
# 2  127410.0  Schützeichel, Rainer
#
#                                                title publication date  \
# 0  Die Perspektive des Städtebauers. Ein Blick au...             2016
# 1  Einleitung. Wegmarken einer Theorie des archit...             2016
# 2  Tradition as a Means of Modernisation: The Cru...             2016
#
#   publication type abstract language     journal professor  \
# 0     Book Chapter      NaN       de  Grundlagen       NaN
# 1     Book Chapter      NaN       de         NaN       NaN
# 2     Book Chapter      NaN       en         NaN       NaN
#
#    organisation unit code organisation
# 0                     NaN          NaN
# 1                     NaN          NaN
# 2                     NaN          NaN

# %% [markdown]
# #### 3.2 Leitzahl data

# %%
leitzahl_mapping = pd.read_csv("cost_centre_dept_mapping.csv", encoding = "ISO-8859-1")
leitzahl_mapping.head()
# Out:
#     LTZL                NAME  TYPNEU                    TYPNAME  DEPT  \
# 0  T1057    T-SR Architektur      98  Totalisierungs-Leitzahlen  ARCH
# 1  T1058  Total NDS/NDK ARCH      98  Totalisierungs-Leitzahlen  ARCH
# 2  T1059        T-Lehre ARCH      98  Totalisierungs-Leitzahlen  ARCH
# 3  T1104   T-SR Bauing.wiss.      98  Totalisierungs-Leitzahlen  BAUG
# 4  T1105     T-SR Umwelting.      98  Totalisierungs-Leitzahlen  BAUG
#
#   TO_CHAR(T.VONDAT,'DD/MM/YYYY') TO_CHAR(T.BISDAT,'DD/MM/YYYY')
# 0                     01/01/2006                     31/12/9999
# 1                     01/01/2000                     31/12/2005
# 2                     01/01/2000                     31/12/9999
# 3                     01/01/2006                     31/12/9999
# 4                     01/01/2006                     31/12/9999

# %%
set(leitzahl_mapping["NAME"])
# Out:
# {'Ris, R. (em.)',
#  'Rehsteiner, F. (em.)',
#  'Bosshard, H. H.',
#  'CAS TPP: PP',
#  'Knörrer, H. (em.)',
#  'Tatbul (ehem.)',
#  'CAS ETH RM',
#  'T-Anorganische Chem.',
#  'DS Lebensmittelwiss.',
#  'Smith, Roy (Tit.)',
#  'T-Mikrobiologie',
#  'Wegener, Konrad',
#  'T-Design, Mat., Fab.',
#  'T-Atmosphärenphysik',
#  'Eisner, M. (ehem.)',
#  'Imboden, D. (em.)',
#  'DA Informatik',
#  'Vorburger (SNF)(eh.)',
#  'Total NDS/NDK INFK',
#  'SCCER-SoE',
#  'MAS ETH STP',
#  'T-Merkt, F.',
#  'GESS, nicht zuteilb.',
#  'Degen, Christian',
#  'Van Gunsteren (em.)',
#  'Waldmanagement',
#  'T-SR Rechnergest.Wi.',
#  'DZ Lebensmittelwiss.',
#  'Schwab, Martin (em.)',
#  'Ed. J. Org. Letters',
#  'Faber, Michael (eh.)',
#  'Bibliothek D-PHYS',
#  'Vaterlaus, Andreas',
#  'Mil. Sicherheitst.',
#  'DZ Rechnerg. Wiss.',
#  'Quantenelektronik',
#  'DA ARCH',
#  'Geschichte',
#  'SR Physik',
#  'Total DS BAUG',
#  'Kamgarpour, Maryam',
#  'Bsc Raumbez. Ing.',
#  'Davies, H. C. (em.)',
#  'Heinrich, Ch. (em.)',
#  'T-LSZ',
#  'Geering, H. P. (em.)',
#  'Lehre FOWI, direkt',
#  'Studienbereich',
#  'Imamoglu, Atac',
#  'Dillenburger, B.',
#  'T-Denkmalpflege',
#  'Bild- und Grafikerz.',
#  'DS Agr./Leb.w.,n.zu.',
#  'Total NDS/NDK AGRL',
#  'Holländer, Georg',
#  'SR Chemieing.',
#  'T-Hurni, L.',
#  'Gehrmann (SNF) (eh.)',
#  'DA Bauingenieurwiss.',
#  'DR MAVT',
#  'DR Interdisz.Nat.w.',
#  'Translationale Med.',
#  'Schütz, J.-P. (em.)',
#  'Hutter, Marco',
#  'Wider, G. (Tit.)',
#  'Anastasaki, Athina',
#  'Robotik u. Intell.',
#  'Aebi, M. (em.)',
#  'McKenzie, J. (em.)',
#  'Lehre Biosysteme',
#  'DR ETH-UZH Biologie',
#  'Springman, Sarah M.',
#  'Amadò, R. (em.)',
#  'Buchli (SNF) (eh.)',
#  'T-Lehre USYS',
#  'Smith, Paul (em.)',
#  'Bokulich, Nicholas',
#  'Gunzinger, A.(ehem.)',
#  'Rätsch, Gunnar',
#  'Medizinausbild. ETH',
#  'Plattner, B. (em.)',
#  'Tropeano, Ruggero',
#  'Van der Veen (em.)',
#  'Meboldt, Mirko',
#  'Gruppe Huber',
#  'Göksel, Orçun (SNF)',
#  'Physikalische Chem.',
#  'T-Stoll, H.',
#  'DS Berufsoffizier',
#  'Ruch, A. (em.)',
#  'Mazza, Edoardo',
#  'deMello, Andrew',
#  'De Bock, Katrien',
#  'Maeder, R, E.',
#  'ISG D-USYS',
#  'Altmann, Karl-Heinz',
#  'Total Werner, S.',
#  'BSc Lebensmittelwiss',
#  'T-Lehre ERDW',
#  'Wood, Vanessa',
#  'HazNETH',
#  'Kommunikation & Mark',
#  'Biogeochemie',
#  'Schmid, C. (em.)',
#  'Signorell, Ruth',
#  'Engeli, M. (em.)',
#  'Gruppe Yamakoshi',
#  'Schneider, W.',
#  'Ambühl, Michael',
#  'Gruppe Martoglio',
#  'Yang, Fan',
#  'DR GESS',
#  'Merkt, Frédéric',
#  'Uhler, Caroline',
#  'Schweitzer, G. (em.)',
#  'T-Inf.techno.u.Elek.',
#  'Bucher, Hugo',
#  'Grewe, Benjamin F.',
#  'CTM',
#  'Fonteyne, An',
#  'DR BAUG',
#  'Del Gado (SNF) (eh.)',
#  'CAS ETH Pharmaceut.',
#  'MAS Manag.,Techn.+Ec',
#  'Weis, Karsten',
#  'Iozzi, A. (Tit.)',
#  'Grün, A. (em.)',
#  'Guillén Gosálbez, G',
#  'T-Blatter, J.',
#  'SMoCC',
#  'Mateo, J.L. (em.)',
#  'Gutknecht, J. (em.)',
#  'Hinterberger (Tit.)',
#  'Ang. Biowiss.(ehem.)',
#  'Ernst, R.',
#  'PET-Plattform',
#  'Witzigmann (ehem.)',
#  'Werkstatt D-ITET',
#  'Ghazoul, Jaboury',
#  'Kressner, D. (ehem.)',
#  'Gujer, Willi (em.)',
#  'Chelle-Michou, Cyril',
#  'Eichler, Ralph (em.)',
#  'PHYS, nicht zuteilb.',
#  'T-Neuroinformatik',
#  'Jäckel, Heinz (em.)',
#  'KOF FBI',
#  'Jeschke, Gunnar',
#  'Sallusto, Federica',
#  'Peter, Thomas',
#  'T-SR Agrarwiss.',
#  'Gruppe Zenklusen',
#  'Tech. Informatik',
#  'Weck, H.',
#  'Reh, L.',
#  'Buhmann, Martin D.',
#  'Hampe, Michael',
#  'Hilvert, Donald',
#  'Heiz, Patrick',
#  'SR Bauing.wiss.',
#  'Sorkine Hornung, O.',
#  'Hamer, G.',
#  'Experimente',
#  'Landolt, E.',
#  'Seward, T. M. (em.)',
#  'DA Chemie',
#  'Delbrück, T. (Tit.)',
#  'Hertig, Gérard (em.)',
#  'Total Batlogg, B.',
#  'Wallraff, Andreas',
#  'Halin Winter, C.',
#  'Schawinski (SNF)(eh)',
#  'Wagner, Stephan M.',
#  'Humanernährung',
#  'Programmiersprachen',
#  'T-Mensch-Umw-Sy(eh.)',
#  'Werkstatt, D-MATL',
#  'DISP-Redaktion',
#  'Lehre AGRL (ehem.)',
#  'Kochmann, Dennis',
#  'Sitti, M.',
#  'Elektromaterial',
#  'Vorlesungsexp./Phys.',
#  'Läuchli, Peter',
#  'Zentrale Dienste SLA',
#  'Furrer, A. (Tit.)',
#  'Studio Basel (eh.)',
#  'Holz, Christian',
#  'Weismantel, Robert',
#  'Gehri, Ernst',
#  'Lowrie, W. (em.)',
#  'Schlunegger (ehem.)',
#  'Axhausen, Kay W.',
#  'Kartografie&Geoinf',
#  'Edwards, Peter (em.)',
#  'Gruppe Berger',
#  'T-Lagerbetriebe',
#  'Goes (SNF) (ehem.)',
#  'Total NDS/NDK BEPR',
#  'Wehner, Theo (em.)',
#  'Bau-&Infrastrukturm.',
#  'Ilmanen, Tom',
#  'Kunz, Martin (ehem.)',
#  'Stoffel, Markus',
#  'NFS Digitale Fabrik.',
#  'Widmer, F. (em.)',
#  'Bot.Gart.Grüningen',
#  'Baustatik u. Konst',
#  'Schenk, A. (Tit.)',
#  'Grohs (ehem.)',
#  'DA Agrarwissenschaft',
#  'XR D-MATL',
#  'Hampel, F. (em.)',
#  'Goldhahn, J. (Tit.)',
#  'Bernasconi S. (Tit.)',
#  'Herzog, J. (em.)',
#  'Ewald, C. Y. (SNF)',
#  'Moor, H.',
#  'T-Betriebswissensch.',
#  'Nelson, Bradley J.',
#  'Karlen, Walter (SNF)',
#  'Forst-Bibliothek',
#  'T-Geodäsie u.Photogr',
#  'Olsen, J. L.',
#  'CAS TPP: IA',
#  'BSc Biotechnologie',
#  'Mineralogie (eh.)',
#  'Dufresne, Eric',
#  'Jentzen, A. (ehem.)',
#  'Schönbächler, Maria',
#  'SR Biologie',
#  'Zitzler, E. (ehem.)',
#  'Gehart, Helmuth',
#  'Folkers, Gerd (em.)',
#  'DS BewSp/TuSp,ni.zu.',
#  'Morari, M. (em.)',
#  'IfU - Umweltlabor',
#  'Wolf (SNF) (eh.)',
#  'Köhler (SNF) (eh.)',
#  'AGRL,n.zuteilb.(eh.)',
#  'Schlapbach, L. (em.)',
#  'Würgler, Hans',
#  'Holzner (SNF) (eh.)',
#  'Prasser, H.-M.',
#  'Schumann, W.',
#  'CAS ETH CDM',
#  'Iida (SNF) (eh.)',
#  'Taylor, William R.',
#  'gta Archiv',
#  'Günther, Detlef',
#  'Agrar-u.L.wi.(ehem.)',
#  'T-Lehrlingsausbild.',
#  'Wachter, P.',
#  'Stocker, Roman',
#  'Bona, Gian-Luca',
#  'NMR D-BIOL',
#  'Steiner, D.',
#  'Züst, Rainer',
#  'Moor, Andreas',
#  'Total Boutellier, R.',
#  'NDS/NDK MATH,n.ztb.',
#  'Bailey, J.E. (ehem.)',
#  'T-Gewässersch.(eh.)',
#  'Scholz, R. (ehem.)',
#  'Witholt, B. (em.)',
#  'Elektroniker',
#  'T-Razansky, D.',
#  'Hering, Janet',
#  'Walcher, J. (SNF)',
#  'Gruppe Chabria',
#  'Hafen, Ernst',
#  'Haller, George',
#  'T-Agrarwiss.',
#  'T-Molek.Pflanzenbiol',
#  'Parrilo, P. (ehem.)',
#  'T-Atmosphäre u.K.',
#  'MSc Quantum Engin.',
#  'ETH KI-Zentrum',
#  'Kovari, K. (em.)',
#  'Sornette, Didier',
#  'Toxikol. I. (Ehem.)',
#  'Rothacher, Markus',
#  'Brändli, H. (em.)',
#  'MAS Finance',
#  'Bacher, Rainer',
#  'Weinberg, F.',
#  'T-SR Umwelting.',
#  'Thöny-Meyer (ehem.)',
#  'Graf, Gian Michele',
#  'CAS ETH RI',
#  'Snedeker, Jess G.',
#  'Schmidt, Thomas',
#  'Allain, Frédéric',
#  'T-Vance, D.',
#  'Acciaio, B.',
#  'Huang, Qiuting',
#  'CAS ETH NGRM',
#  'Anliker, M.',
#  'T-Heinrich, Ch.',
#  'Comput. Sc. (eh.)',
#  'Tschirky, H. (em.)',
#  'F.inst. Mathematik',
#  'Hierold, Christofer',
#  'Colbois, Bruno',
#  'Neutronenstreuung',
#  'DS CHEM, nicht zu.',
#  'Kucera (ehem.)',
#  'Total Schwab, M.',
#  'Individualverkehr',
#  'Ghaffari, Mohsen',
#  'MSc Atmos. Clim. Sc.',
#  'DZ Bewegungswiss.',
#  'SR Materialwiss.',
#  'DS CHAB',
#  'Total Kappel, R.',
#  'T-Agrarwirtsch.(eh.)',
#  'Schmidt, Max',
#  'Flatt, Robert J.',
#  'von Kienlin (Tit.)',
#  'MAS ETH Mediation',
#  'Fechtig, R.',
#  'Siegwart, Roland Y.',
#  'MA Comp.a.Int.Stud.',
#  'T-SR Elektrotech',
#  'Mittelenergiephys.',
#  'Biomed. Technik',
#  'Hiptmair, Ralf',
#  'Ingenieurbüro',
#  'Beever, David E.',
#  'Kapur, Manu',
#  'CAS Angewandte Erdw.',
#  'Snijder, B.',
#  'Douglas (em.)',
#  'Rudin, Markus (em.)',
#  'Boeva, Valentina',
#  'Hellweg, Stefanie',
#  'Langenberg, S.',
#  'Nievergelt, J. (em.)',
#  'BSc Informatik',
#  'Imamoglu, Oe. (Tit.)',
#  'SR Interdisz.Nat.w.',
#  'Agrarhandel',
#  'Hütter, R.',
#  'Total Brusoni, S.',
#  'I. Städtebau (ehem.)',
#  'Pregosin, P. (Tit.)',
#  'Sig.-u.Inf.verarb.',
#  'Sznitman, Alain-S.',
#  'Total Hurrell, R.',
#  'ETH+-Design++',
#  'T-CEPE',
#  'Eggimann, F. (em.)',
#  'Zheludev, Andrey',
#  'Sigrist, M. (Tit.)',
#  'NDS/NDK ERDW,n.ztb.',
#  'Anastasiou, Ch.',
#  'Stojanik, Petra',
#  'LD Geographie',
#  'IVUK-Lehre',
#  'T-Astronomie',
#  'Zimmermann, M. B.',
#  'Boutellier, R. (em.)',
#  'Thoma (Tit.) (em.)',
#  'Total Green, A. G.',
#  'Burgert, Ingo',
#  'Wenderoth, Nicole',
#  'Hovestadt, Ludger',
#  'Geodätische Komm.',
#  'Székely, G. (em.)',
#  'T-SR Materialwiss.',
#  'DAS ETH Data Science',
#  'T-Biologie',
#  'Kneubühl, F.',
#  'Wittneben, Armin',
#  'Schlatter, C.',
#  'MNSP',
#  'T-Informationssy(eh)',
#  'Informationssyst(eh)',
#  'T-Energie- u. Verf.',
#  'Pink, R.',
#  'Gander, B. (Tit.)',
#  'Vermant, Jan',
#  'T-Pflanzenbiol.Prof.',
#  'Dressler, K.',
#  'T-Mineralogie (eh.)',
#  'SR Mathematik',
#  'Landsch.u.Urb.St.',
#  'Integrative Biologie',
#  'Mitrano, Denise M.',
#  'MBA Supply Chain Man',
#  'ISG D-BIOL',
#  'DAS Militärwiss.',
#  'von Wangenheim, F.',
#  'Molecular Health Sc.',
#  'D-BSSE Clean Room F.',
#  'MSc Micro and Nanosy',
#  'IVUK-Infrastr./Adm.',
#  'Chemie u. Ang.Bio.',
#  'Hilty, R. M. (ehem.)',
#  'Christodoulou (em.)',
#  'Raspopovic, Stanisa',
#  'Griess, V.C. (vor A)',
#  'MAS Urban Design',
#  'Knutti, Reto',
#  'LD Biologie',
#  'Shinde, S. S (vor A)',
#  'Dorn, Silvia (em.)',
#  'Baustoffe (IfB)',
#  'Polania Jimenez, R.',
#  'CC-AD',
#  'Fleisch, Elgar',
#  'Vörös, Janos',
#  'Kilcher, Andreas',
#  'Schroeder, Timm',
#  'DR Rechnergestützte',
#  'T-Automatik',
#  'Wörner, Hans Jakob',
#  'Degiorgi, L. (Tit.)',
#  'Niederer, P. (em.)',
#  'DZ Umweltlehre',
#  'DS Agrarwissensch.',
#  'T-Geologisches Inst.',
#  'T-Baustatik u. Konst',
#  'Sunagawa, Shinichi',
#  'Indiveri, Giacomo',
#  'T-Lehre INFK',
#  'Puhan, Z. (em.)',
#  'Zehnder, A. J. (em.)',
#  'Spieker, H.',
#  'IBK-Berichte',
#  'T-SR Chemieing.',
#  'Weissert, H.J.(Tit.)',
#  'Grossner, Ulrike',
#  'Muschg, A.',
#  'Lehre ITET',
#  'Total Schulin, R.',
#  'Gruppe ClayLab',
#  'Lygeros, John',
#  'Zaengl, W.',
#  'Beck-Sickinger, A.',
#  'T-SR Biologie',
#  'Kretzschmar, R.',
#  'Wieler, R. (Tit.)',
#  'Balmer (SNF) (ehem.)',
#  'Flückiger, H. (em.)',
#  'T-SR Physik',
#  'Werner (SNF) (eh.)',
#  'Stricker, T. (ehem.)',
#  'Hurni, Lorenz',
#  'DR ETH-UZH Pharm.',
#  'Lanford III (em.)',
#  'Schwank, G. (ehem.)',
#  'INFK, nicht zuteilb.',
#  'Isotopengeol. (eh.)',
#  'MSc Cyber Security',
#  'Inform. Einh. D-HEST',
#  'CTU Baden',
#  'CAS ETH ELTV',
#  'DR ETH-UZH Gesundh.',
#  'MSc Materialwiss.',
#  'Fluiddynamik',
#  'Lukatskaya, Maria',
#  'Büchel, A.',
#  'BSc Architektur',
#  'T-Zentrale Werkstatt',
#  'Berdyugina(EURYI)(eh',
#  'Bode, Jeffrey W.',
#  'Jaun, B. M. (Tit.)',
#  'T-Zellbiologie (eh.)',
#  'MSc Informatik',
#  'Total Ott, H. R.',
#  'Hartland, S.',
#  'Siegrist, Michael',
#  'Fischer, P. (Tit.)',
#  'Wegscheider, Werner',
#  'Zeyer, Josef (em.)',
#  'Razavi, Kaveh',
#  'Mazzotti, Marco',
#  'Wetter Slack, Emma',
#  'Leuthold, P. (em.)',
#  'Stumm, W.',
#  'Lanzavecchia (em.)',
#  'Parrinello, M.',
#  'Fachgruppe SIM',
#  'Dunitz, J. D.',
#  'Bachmann, M.',
#  'Materialwissenschaft',
#  'Strasser (SNF) (eh.)',
#  'T-Anastasiou, Ch.',
#  'SAR Tomographie',
#  'Green, Alan G. (em.)',
#  'McDonald, Bruce',
#  'Christ, Emanuel',
#  'Delhees, K. H.',
#  'Mössenböck, H.',
#  'Moschytz, G.',
#  'Murakami, Motohiko',
#  'DR Mathematik',
#  'Feldon, Joram (em.)',
#  'Matousek (ehem.)',
#  'Dietrich, K. (em.)',
#  'Schedlowski (ehem.)',
#  'Knohl, A. (ehem.)',
#  'Harris, N. (ehem.)',
#  'Total Bourdon, B.',
#  'CAS Nutrition',
#  'MAVT, nicht zuteilb.',
#  'Denkmalpflege',
#  'Pharmazeut. Wiss.',
#  'Emerson, Tom',
#  'Biran, Paul I.',
#  'Nord-Süd-Zentrum',
#  'T-SR MTEC',
#  'Clarysse, Bart',
#  'Gruppe Hilbeck',
#  'Elektromagn. Felder',
#  'Gantenbein, Ch.',
#  'Steinfeld, Aldo',
#  'MAS ETH FSE',
#  'D-BSSE FIS',
#  'Total Spencer, N.',
#  'Eberle, Hans',
#  'McNeill, Kristopher',
#  'Lehre MATH',
#  'DA Materialwiss.',
#  'Gramazio, Fabio',
#  'Yanik, Mehmet Fatih',
#  'Mougel, Victor',
#  'BSc Biochemie',
#  'Weber-Ban, E. (Tit.)',
#  'Murphy, R. (ehem.)',
#  'MATH, nicht zuteilb.',
#  'Pauly, Mark (ehem.)',
#  'T-Biochemie',
#  'Guggenbühl Walter',
#  'Wingert, Lutz',
#  'Bomblies, Kirsten',
#  'DR Umwelting.wiss.',
#  'Werkstatt D-CHAB',
#  'Pelkmans (SNF) (eh.)',
#  'Lehrareal D-UMNW',
#  'Amann, P. (em.)',
#  'Nagel, K. (ehem.)',
#  'Ernst, M. (Tit.)',
#  'Inst. Masch. Lernen',
#  'MoBiAS',
#  'Zilberberg, O. (SNF)',
#  'Total SR Biotechnol.',
#  'DS Materialwiss.',
#  'MAS Security Policy',
#  'Crivelli, P. (Tit.)',
#  'Total Prins, R.(em.)',
#  'Jonas, Stefanie',
#  'T-Masch.u.Verf.tech.',
#  'Prins, R. (em.)',
#  'Chaperon, F.',
#  'Zamboni, N. (Tit.)',
#  'Schweitzer, Frank',
#  'Hebel, Dirk (ehem.)',
#  'Total NDS/NDK ITET',
#  'Iacobelli (Tit.)',
#  'Bar-Nur, Ori',
#  'Mezzetti, A. (Tit.)',
#  'Total DS BIOL',
#  'Hurrell, R. (em.)',
#  'T-Chemie u. Ang.Bio.',
#  'Widmer, Alexander',
#  'Blatter, Johann W.',
#  'Beisert, Niklas',
#  'Vallat, J.',
#  'Egger, Peter',
#  'Stark, Wendelin J.',
#  'Funk, M. (Tit.)',
#  'Neuhauss (SNF) (eh.)',
#  'Van Mier, J. (ehem.)',
#  'Wallny, Rainer',
#  'Cotterell, Ryan',
#  'Keller, Thomas',
#  'T-Physikalische Chem',
#  'Schneider, T. (eh.)',
#  'Kytzia, S. (ehem.)',
#  'Signer, P.',
#  'Künzle, Otto (em.)',
#  'Kollhoff, H. (em.)',
#  'Gruppe ForDev',
#  'Egli, T. (Tit.)',
#  'T-Schönbächler, M.',
#  'CAS ETH AMT',
#  'T-SR GESS',
#  'Wüthrich, M. (Tit.)',
#  'Dahlhaus, D. (ehem.)',
#  'Weidmann, Ulrich',
#  'Schlapbach (Tit.)',
#  'Meier, W. M.',
#  'Schuler (Tit.)(eh.)',
#  'Schöb, Ch. (SNF)',
#  'MSc Pharma Sc',
#  'BUK Bautech.&Konstr.',
#  'Dubois, N. (SNF)',
#  'Hangartner, Dominik',
#  'Baettig, Karl',
#  'Lubich, Christian',
#  'Brillembourg (ehem.)',
#  'T-Technologie Arch.',
#  'Kommunikation',
#  'Total NDS/NDK ARCH',
#  'BIOL, nicht zuteilb.',
#  'Maurer, J.',
#  'Kissling-Näf (ehem.)',
#  'DS Architektur',
#  'Levine, J. (ehem.)',
#  'Landis, J.',
#  'Nash, Michael',
#  'Metall.Verf.techn.',
#  'T-Bau-&Infrastruktur',
#  'Keller, Ursula',
#  'T-Hajnsek, I.',
#  'Home, Jonathan',
#  'Anderheggen, E.(em.)',
#  'NDK Mechatronik',
#  'DR UMNW',
#  'Gastprof. D-ARCH',
#  'SR Forstwiss.',
#  'Schönfeld, B. (Tit.)',
#  'T-Elektronik',
#  'Emch, F.',
#  'Oertli, J. J.',
#  'Vayena, Eftychia',
#  'von Krogh, Georg',
#  'DA FOWI',
#  'De Vylder, Jan',
#  'Bresch, David N.',
#  'DS Physik',
#  'Bergier, J.-F.',
#  'Luisi, P. L. (em.)',
#  'T-CTM',
#  'Rutherford (ehem.)',
#  'T-Computersyst.(eh.)',
#  'DA MAVT',
#  'Singla, Ankit',
#  'Total Esslinger, T.',
#  'Erdwissenschaften',
#  'Total NDS/NDK BIOL',
#  'Oechslin, W. (em.)',
#  'T-Wasserbau,Hydrolog',
#  'T-SR Informatik',
#  'Ronner, H.',
#  'Lehre INFK',
#  'Chatzi, Eleni',
#  'Schmitt, G. (em.)',
#  'Bösiger, Peter (em.)',
#  'Hilbi (SNF) (ehem.)',
#  'Geshkenbein (Tit.)',
#  'Siegmann (em.)',
#  'Lilly, S.',
#  'Netland, Torbjörn H.',
#  'Gut, R.',
#  'Bachmann, Olivier',
#  'Widmayer, P. (em.)',
#  'Meraldi (SNF) (eh.)',
#  'Schiele, B. (ehem.)',
#  'Total NDS/NDK ERDW',
#  'Onigkeit, D.',
#  'MRC',
#  'Hall, Jonathan',
#  'Renner, Renato',
#  'Lehrlabor D-BIOL',
#  'Weiterbildung D-INFK',
#  'Chu, Yiwen',
#  'SR Ges.wiss.u.Techn.',
#  'Total NDS/NDK MATH',
#  'Konstrukteur',
#  'Total Stenflo (em.)',
#  'Arbeitspsych.(ehem.)',
#  'Bourdon, B. (ehem.)',
#  'Schnebli, D.',
#  'T-Konstruktion Bauw.',
#  'Clinical Trail Cent.',
#  'Suter, Ulrich',
#  'Hilliges, Otmar',
#  'Winkler, F. K. (em.)',
#  'Physikpraktikum3+ASL',
#  'Felder, Giovanni',
#  'Baccini, Peter (em.)',
#  'T-SR Ges.wiss.',
#  'Campi, M. (em.)',
#  'Märkli, Peter (em.)',
#  'ZISC',
#  'Baiker, A. (em.)',
#  'Apel, K. (em.)',
#  'T-Comput. Sc. (eh.)',
#  'Onder, Ch. (Tit.)',
#  'T-Quantenelektronik',
#  'Gruppe Swiss CAR',
#  'Pérez-Ramírez, J.',
#  'Schürle, Simone',
#  'Katzschmann, Robert',
#  'Meyer, B. (em.)',
#  'Calaque (ehem.)',
#  'D-BSSE DAS',
#  'Total Suter, U.',
#  'Kuster, Niels',
#  'Bommier, Antoine',
#  'MAS Sust. Water Res.',
#  'Lehre PHYS',
#  'Allgöwer, Frank',
#  'Lang, H.-J.',
#  'Total Pescia, D.',
#  'Kienast, Dieter',
#  'Stüssi, Edgar (em.)',
#  'Picotti, Paola',
#  'DR ETH-UZH ITET',
#  'SSPG',
#  'DA MTEC',
#  'Food-KIC',
#  'Govindjee (ehem.)',
#  'Delucchi, V.',
#  'T-Werkzeugmaschinen',
#  'Total SR FOWI',
#  'DS Geomatik',
#  'Usability Lab',
#  'Elektr. Maschinen',
#  'Vassiliou, Michalis',
#  'Gerlich, W. (EURYI)',
#  'Leisi, H. J.',
#  'T-Raum- u. Landsch.',
#  'Tiefenbacher, Konrad',
#  'Le Roy, H. L.',
#  'Rupp (SNF) (ehem.)',
#  'Schmid, H. M. (Tit.)',
#  'Angewandte Math.',
#  'Nösberger, J. (em.)',
#  'DS Betriebs-u.Prod.',
#  'Zürcher, C.',
#  'Gruppe Pané Vidal',
#  'KOF FBU',
#  'Radiochemie LOC',
#  'IVUK-Labor/Elektr.',
#  'Koh (SNF) (ehem.)',
#  'MSc CBB',
#  'Geodäsie u.Photogr',
#  'Fischer, H.-M.(Tit.)',
#  'Malamud, S. (ehem.)',
#  'Molek. Pflanzenbiol',
#  'Proteomics Plattform',
#  'T-Studio Basel (eh.)',
#  'Steurer, W. (em.)',
#  'T-Festkörperphysik',
#  'T-SR Erd- u. Klimaw.',
#  'SR MTEC',
#  'Phys. Kolloquium',
#  'Simon, Klaus',
#  'Diplomverm.kurs',
#  'Total Amrhein (em.)',
#  'Bechtold, Stefan',
#  'BSc Rechnergestützte',
#  'Carandini (SNF)(eh.)',
#  'gta Digital',
#  'Verfahrenstech. (eh)',
#  'Automatik',
#  'Meier, M. (ehem.)',
#  'T-Integrative Biol.',
#  'T-Hilliges, O.',
#  'Christiaanse (em.)',
#  'Archiv f. Zeitgesch.',
#  'Raubal, Martin',
#  'T-Sem. für Statistik',
#  'Energietechnik (eh.)',
#  'Johnson, Steven',
#  'Mathys, Alexander',
#  'Burg (SNF) (ehem.)',
#  'Müller, Stefan',
#  'BWI Betriebswiss. Z.',
#  'De Moraes, Consuelo',
#  'Benini, Luca',
#  'Feuerriegel, Stefan',
#  'Carmeliet, Jan',
#  'Bardow, André',
#  'Sansavini, Giovanni',
#  'T-Comput. Platforms',
#  'T-Neurowiss.',
#  'Doctoral School Math',
#  'Müller-Herold (Tit.)',
#  'Konstruktion Bauw.',
#  'T-SR Mathematik',
#  'T-Integr. Systeme',
#  'Total Wenderoth, N.',
#  'MSc Quant. Finance',
#  'Merkle, H. P. (em.)',
#  'DS BAUG,n.ztb.',
#  'CAS ETH AIT',
#  'Gruissem, Wilhelm',
#  'Leisinger, T. (em.)',
#  'Prohl, A. (ehem.)',
#  'T-Umweltnaturwissen.',
#  'Schubiger, P. (em.)',
#  'Henz, A.',
#  'Baladi, Viviane',
#  'Material D-CHAB',
#  'T-Verfahrenst. (eh.)',
#  'Mansuy, Isabelle',
#  'Fusi (SNF)(ehem.)',
#  'Panse (SNF) (eh.)',
#  'ARCH, nicht zuteilb.',
#  'Batlogg, B. (em.)',
#  'Galí-Izard, Teresa',
#  'Constantinescu, C.',
#  'Schär, Christoph',
#  'LPC Professoren-OK',
#  'Agrarwirtsch. (eh.)',
#  'Physiol. d. Pflanzen',
#  'Gabriel, J. M. (em.)',
#  'DR Erdwiss.',
#  'T-Nutztierwiss.(eh.)',
#  'Ash, Elliott',
#  'Pflanzenbiol.Prof.',
#  'Böhni, H. (em.)',
#  'Stern, Elsbeth',
#  'Jang, Taekwang',
#  'T-Gruber, N.',
#  'CC-PM',
#  'Fröhlich, K. (em.)',
#  'Virtanen, S. (ehem.)',
#  'Engeler, E.',
#  'Detmar, Michael',
#  'Climate-KIC',
#  'Seeberger (ehem.)',
#  'NFS Automation',
#  'Stoll, Heather',
#  'MAS ETH GPB',
#  'DA ERDW',
#  'Gruppe Scalari',
#  'I.f.Klimaforschung',
#  'Bühlmann, H.',
#  'SR Humanmedizin',
#  'Total Imamoglu, A.',
#  'Geologisches Inst.',
#  'Energy Science Cent.',
#  'Hermanns St. (ehem.)',
#  'Disney Research',
#  'Fiechter, A.',
#  'Studer, Christoph',
#  'DR Biosysteme',
#  'Caminada, G.A.',
#  'Winterhalter (em.)',
#  'Charbonnet, François',
#  'Potrykus, I.',
#  'Petersen, W. (Tit.)',
#  'Haug, Gerald',
#  'Chen, Peter',
#  'Müntener, M. (em.)',
#  'Werner, Sabine',
#  'Furrer G. (Tit.)',
#  'Bau,Umw.u.Geomatik',
#  'Werkstatt Umw.sys.',
#  'BSc Pharmazeut.Wiss.',
#  'MSc Biotechnologie',
#  'Camartin, I.',
#  'MAS ETH GTA',
#  'T-Biosysteme',
#  'Grange, Rachel',
#  'Barnes, Alexander',
#  'Hugel, J. (em.)',
#  'Barral, Yves',
#  'Richmond, T. (em.)',
#  'Borschberg, H.(Tit.)',
#  'MSc Raumentwicklung',
#  'Herrmann, Hans (em.)',
#  'MAS Medizinphysik',
#  'Zentrale Werkstatt',
#  'Integr. Systeme',
#  'CAS ETH Verkehr',
#  'Angst, Ueli (SNF)',
#  'Grünenfelder Marc',
#  'Kissling, E. (Tit.)',
#  'Togni, Antonio',
#  'Windhab, Erich  J.',
#  'Ges.wiss. u. Technol',
#  'Gilmour (ehem.)',
#  'Locher, Kaspar',
#  'Anagnostou, Georgios',
#  'Physik-Werkstatt',
#  'Ott, H. R. (em.)',
#  'Seminarien und Koll.',
#  'Kündig, A. (em.)',
#  'NDS/NDK ITET,n.ztb.',
#  'Zenobi-Wong, Marcy',
#  'Steffen, K. (ehem.)',
#  'T-Informatik',
#  'Müller, Bernhard',
#  'Supponen, Outi',
#  'Stelling, Jörg',
#  'Jagannathan, Madhav',
#  'Kälin, August N.',
#  'DS Umwelting.wiss.',
#  'NDS/NDK BAUG,n.ztb.',
#  'Noble Gas Group',
#  'Viertel, G. (Tit.)',
#  'T-Intell.interakt.Sy',
#  'Entomological Coll.',
#  'Maurer, Max',
#  'Stremitzer, A.',
#  'Benz, A. (Tit.)',
#  'Saar, Martin O.',
#  'Kreuzer, Michael',
#  'Total Lehre FOWI',
#  'Schubert, R. (em.)',
#  'Blatter, C. (em.)',
#  'Hidber, C.',
#  'Elkana, Yehuda',
#  'Kaiser, F. (ehem.)',
#  'Tassion, Vincent',
#  'Mech. Lehrwerkstatt',
#  'Troyer, M. (SNF)',
#  'Solms, J.',
#  'Wutz, Anton',
#  'Spengler, C. (Tit.)',
#  'Sticher, O. (em.)',
#  'Frei, Ch. (SNF)',
#  'Uggowitzer, P.(Tit.)',
#  'Alimonti, Andrea',
#  'MAS Water Resources',
#  'Escher, Felix (em.)',
#  'Betriebe D-PHYS',
#  'DR FOWI',
#  'Wittmann, F.H. (em.)',
#  'Grote, Gudela',
#  'Support L+F D-BAUG',
#  'Arbenz, Peter (Tit.)',
#  'WBZ Raumentwicklung',
#  'Lamuniere, Ines',
#  'Theor. Informatik',
#  'Feichtner (SNF)(eh.)',
#  'Danuser, G. (ehem.)',
#  'Hugi, H. R.',
#  'Total McKenzie, J.',
#  'D-BSSE Animal Facil.',
#  'NSL D-ARCH',
#  'Jochem, E. (em.)',
#  'Pooladministration',
#  'CAS ETH Raumplanung',
#  'Tay, Savas (ehem.)',
#  'Willett, Sean',
#  'Hora, P. (em)',
#  'Walter, Achim',
#  'Mlynek, J.',
#  'Flury, U.',
#  'Betriebstech.Anlagen',
#  'Dissertori, Günther',
#  'Analytik IPW',
#  'Teuber, M. (em.)',
#  'Spaldin, Nicola A.',
#  'Wattenhofer, Roger',
#  'Quitterer, Ursula M.',
#  'T-F.inst. Mathematik',
#  'Leichtbau',
#  'Halter (SNF) (ehem.)',
#  'Röthlisberger (eh.)',
#  'Verh.,Ges.,Tierwohl',
#  'Ingensand (em.)',
#  'Rüegg, Arthur (em.)',
#  'Roscoe, Timothy',
#  'Schmid, Ch. (Tit.)',
#  'Werner, Wendelin',
#  'Bachmann, P. (em.)',
#  'Tang, Siyu',
#  'Aceto, N. (vor A.)',
#  'Spreng, D. T. (Tit.)',
#  'Pratsinis, Sotiris',
#  'Gruppe Sauer',
#  'Pandharipande, Rahul',
#  'Bachmann, H. (em.)',
#  'D-PHYS Shop',
#  'Total DS AGRL',
#  'Perrig, Adrian',
#  'DA UMNW',
#  'T-NSL D-ARCH',
#  'Boulouchos, K.',
#  'Giardini, Domenico',
#  'CAS MZ Technologie',
#  'Hoffmann, Volker',
#  'NMR-Service LOC',
#  'Herrmann, Inge K.',
#  'MSc Elektrotechnik',
#  'Bühlmann, Peter L.',
#  'Massey, J. L.',
#  'Dep.admin. D-USYS',
#  'Pollefeys, Marc',
#  'VandeVondele (ehem.)',
#  'CAS ARC Untern.',
#  'Refregier, Alexandre',
#  'DZ El.technik&Inf.',
#  'Wüstholz (em.)',
#  'Wang, Jing',
#  'T-Selbständige Prof.',
#  'Tibbitt, Mark',
#  'Speidel, M. (em.)',
#  'Troyer (ehem.)',
#  'Mérel, P. (ehem.)',
#  'Daniel, H.-D. (em.)',
#  ...}

# %%
# note: we have no department-specific code/leitzahl
ln = leitzahl_mapping[["NAME","DEPT"]]

# %%
# map department code to department names
dep_map = {'AGRL': 'Agricultural Sciences',
 'ANBI': 'Applied Biosciences',
 'ARCH': 'Architecture',
 'BAUG': 'Civil, Environmental and Geomatic Engineering',
 'BIOL': 'Biology',
 'BSSE': 'Biosystems Science and Engineering',
 'CHAB': 'Chemistry and Applied Biosciences',
 'ERDW': 'Earth Sciences',
 'GESS': 'Humanities, Social and Political Sciences',
 'HEST': 'Health Sciences and Technology',
 'INFK': 'Computer Science',
 'ITET': 'Information Technology and Electrical Engineering',
 'MATH': 'Mathematics',
 'MATL': 'Materials',
 'MAVT': 'Mechanical and Process Engineering',
 'MTEC': 'Management, Technology and Economics',
 'PHYS': 'Physics',
 'USYS': 'Environmental Systems Science'}

def transform_dep_code(code):
    return dep_map[code]

# %%
def transform_dep_code(code):
    return dep_map[code]

transform_dep_code('MATH')
# Out:
# 'Mathematics'

# %%
ln["DEPT"] = ln["DEPT"].apply(transform_dep_code)
# Out:
# /Users/andreasopedal/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ln.head()
# Out:
#                  NAME                                           DEPT
# 0    T-SR Architektur                                   Architecture
# 1  Total NDS/NDK ARCH                                   Architecture
# 2        T-Lehre ARCH                                   Architecture
# 3   T-SR Bauing.wiss.  Civil, Environmental and Geomatic Engineering
# 4     T-SR Umwelting.  Civil, Environmental and Geomatic Engineering

# %%
# now try with deleting parentheses after the names

def delete_parenthesis(name):
    if isinstance(name, str):
        return re.split('(\s\([a-zA-Z.]+\))', name)[0]

print(delete_parenthesis('Schlunegger (ehem.)'))
print(delete_parenthesis('Fontana, M. (em.)'))
print(delete_parenthesis('Smith, Roy (Tit.)'))
print(delete_parenthesis('Baccini, Peter (em.)'))
# Out:
# Schlunegger
# Fontana, M.
# Smith, Roy
# Baccini, Peter

# %%
# apply to leitzahl names, merge and check coverage

ln["NAME"] = ln["NAME"].apply(delete_parenthesis)
rd_m2 = rd_m.merge(ln, how = "left", left_on = "author", right_on = "NAME")
print("Number of entries with complete author and department: ", 
      sum((rd_m2["author"].notna() & rd_m2["DEPT"].notna())))
# Out:
# /Users/andreasopedal/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# Number of entries with complete author and department:  68999

# %%
# Out:
#          id                author  \
# 0  108069.0  Schützeichel, Rainer
# 1  127413.0  Schützeichel, Rainer
# 2  127410.0  Schützeichel, Rainer
# 3   28599.0  Schützeichel, Rainer
# 4  319574.0  Schützeichel, Rainer
#
#                                                title publication date  \
# 0  Die Perspektive des Städtebauers. Ein Blick au...             2016
# 1  Einleitung. Wegmarken einer Theorie des archit...             2016
# 2  Tradition as a Means of Modernisation: The Cru...             2016
# 3  Architettura contestuale. Difesa di una proget...             2010
# 4                             Die Stadt und das Haus             2010
#
#   publication type abstract language     journal professor  \
# 0     Book Chapter      NaN       de  Grundlagen       NaN
# 1     Book Chapter      NaN       de         NaN       NaN
# 2     Book Chapter      NaN       en         NaN       NaN
# 3     Book Chapter      NaN       it         NaN       NaN
# 4     Book Chapter      NaN   en||de         NaN       NaN
#
#    organisation unit code organisation NAME DEPT
# 0                     NaN          NaN  NaN  NaN
# 1                     NaN          NaN  NaN  NaN
# 2                     NaN          NaN  NaN  NaN
# 3                     NaN          NaN  NaN  NaN
# 4                     NaN          NaN  NaN  NaN

# %% [markdown]
# ### 4. Final touches

# %%
# add professor indicator
# problem: only professors that can be matched to the organisations data will be indicated as professors
#rd_m2["is_professor"] = rd_m2["author"] == rd_m2["professor"]
#
#rd_m2.head()

# %%
# drop professor and name columns

rd_final = rd_m2.drop(columns = ["professor", "NAME"])

# rename for ease of neo4j import 

rd_final = rd_final.rename({"publication date": "publication_date", "publication type": "publication_type",
                           "organisation unit code": "organisation_unit_code", "DEPT": "department"},
                          axis = 1)
rd_final.head()
# Out:
#          id                author  \
# 0  108069.0  Schützeichel, Rainer
# 1  127413.0  Schützeichel, Rainer
# 2  127410.0  Schützeichel, Rainer
# 3   28599.0  Schützeichel, Rainer
# 4  319574.0  Schützeichel, Rainer
#
#                                                title publication_date  \
# 0  Die Perspektive des Städtebauers. Ein Blick au...             2016
# 1  Einleitung. Wegmarken einer Theorie des archit...             2016
# 2  Tradition as a Means of Modernisation: The Cru...             2016
# 3  Architettura contestuale. Difesa di una proget...             2010
# 4                             Die Stadt und das Haus             2010
#
#   publication_type abstract language     journal  organisation_unit_code  \
# 0     Book Chapter      NaN       de  Grundlagen                     NaN
# 1     Book Chapter      NaN       de         NaN                     NaN
# 2     Book Chapter      NaN       en         NaN                     NaN
# 3     Book Chapter      NaN       it         NaN                     NaN
# 4     Book Chapter      NaN   en||de         NaN                     NaN
#
#   organisation department
# 0          NaN        NaN
# 1          NaN        NaN
# 2          NaN        NaN
# 3          NaN        NaN
# 4          NaN        NaN

# %%
# issue: quotes need to be escaped in neo4j
# the following function helps us avoid errors when importing

def add_quote(abstract):
    if isinstance(abstract, str):
        abstract = abstract.replace('\\"', '""')
        return abstract.replace('"', '""')

rd_final["abstract"] = rd_final["abstract"].apply(add_quote)

# %% [markdown]
# ## Import/export :):

# %%
rd_final.to_csv("graph_data_final.csv", index=False)
#rc_m.to_json("metadata_final.json", orient = "records")

# %% [markdown]
# ### Neo4j import details
#
# The following nodes will be created:
# - **person** [name, gender]
# - **publication** [id, title, date, type, abstract, journal]
# - **organisation** [name, code] ## NOTE: No code with leitzahl mapping data
# - **department** [name, code]
#
#
# ---
#
#
# **The commands**
#
#
# To load the csv you first have to <u>copy it into your Neo4j base directory</u>. More info [here](https://neo4j.com/docs/cypher-manual/current/clauses/load-csv/#load-csv-import-data-from-a-csv-file). I did the following:
#
# ```cp .\metadata_final.csv C:/Users/Giulia/.Neo4jDesktop/neo4jDatabases/database-befe90d3-7991-457e-9671-62c55c830654/installation-3.5.12/import```
#
# <u>Constraints first</u>
#
# The constraints are here to make sure we don't create duplicate nodes.
#
#     CREATE CONSTRAINT ON (c:Person) ASSERT c.name IS UNIQUE;
#     CREATE CONSTRAINT ON (c:Organisation) ASSERT c.code IS UNIQUE;
#     CREATE CONSTRAINT ON (c:Publication) ASSERT c.title IS UNIQUE;
#     CREATE CONSTRAINT ON (c:Department) ASSERT c.name IS UNIQUE; # or c.code
#     CREATE INDEX ON :Publication(id)
#
#
# Now we'll <u>load the data</u> in a very lightweight manner:
#
# 1) person nodes <br>
# ```
#     LOAD CSV WITH HEADERS FROM "file:///graph_data_final.csv" AS line
#     WITH line WHERE line.author IS NOT NULL
#     MERGE (person:Person {name: line.author})
# ```
#         > Added 267877 labels, created 267877 nodes, set 316963 properties, completed after 11841 ms.
#
# 2) publication nodes (this might take a while) <br>
#
#         LOAD CSV WITH HEADERS FROM "file:///graph_data_final.csv" AS line
#         WITH line where line.id IS NOT NULL
#         MERGE (publication: Publication {title: line.title})
#         SET publication.id=line.id,
#             publication.type=line.publication_type,
#             publication.date=date(line.publication_date),
#             publication.abstract=line.abstract,
#             publication.journal=line.journal;
#
#         > Added 170284 labels, created 170284 nodes, set 3704438 properties, completed after 13718 ms.
#
# 3) organisation nodes <br>
#
#         LOAD CSV WITH HEADERS FROM "file:///graph_data_final.csv" AS line
#         WITH line where line.organisation_unit_code IS NOT NULL
#         MERGE (organisation:Organisation {code:line.organisation_unit_code})
#         SET organisation.name=line.organisation;
#
#         > Added 383 labels, created 383 nodes, set 80749(****) properties, completed after 5205 ms.
#
# 4) department nodes <br>
#
#         LOAD CSV WITH HEADERS FROM "file:///graph_data_final.csv" AS line
#         WITH line where line.department IS NOT NULL
#         MERGE (department:Department {name:line.department})
#         SET department.name=line.department;
#
#         > Added 16 labels, created 16 nodes, set 49319 properties, completed after 5271 ms.
#
#
# 5) finally all the edges <br>
#
#         LOAD CSV WITH HEADERS FROM "file:///graph_data_final.csv" AS line
#         MATCH (person:Person {name:line.author}),
#                (publication:Publication {id:line.id})
#         MERGE (person)-[:PUBLISHED]->(publication)
#
#         >
#
#         LOAD CSV WITH HEADERS FROM "file:///graph_data_final.csv" AS line
#         MATCH (person:Person {name:line.author}),
#                (organisation:Organisation {code:line.organisation_unit_code})
#         MERGE (person)-[:BELONGS_TO]->(organisation)
#
#         > Created 664 relationships, completed after 6556 ms.
#
#         LOAD CSV WITH HEADERS FROM "file:///graph_data_final.csv" AS line
#         MATCH (person:Person {name:line.author}),
#                (department:Department {name:line.department})
#         MERGE (person)-[:WORKS_IN]->(department)
#
#         Alternative without leitzahl:
#         LOAD CSV WITH HEADERS FROM "file:///graph_data_final.csv" AS line
#         MATCH (person:Person {name:line.author}),
#                (department:Department {name:line.department})
#         MERGE (person)-[:WORKS_IN]->(department)
#
#         >
#
# Note: in case you did something wrong and you want to erase the network here's the query:
#
#         MATCH (n)
#         DETACH DELETE n;

# %% [markdown]
# ## Export for topic modeling

# %%
# select only english publications

rd_full_en = rd_m2[rd_m2["language"] == "en"]

# %%
# drop duplicates (keeping only the first)

abstracts_data = rd_full_en.drop_duplicates(subset = ["id"], keep = "first")
print(abstracts_data.shape)
# Out:
# (158522, 15)

# %%
# keep only the entries that have an abstract

print("Number of abstracts: ", sum(abstracts_data["abstract"].notna()))
abstracts_only = abstracts_data[abstracts_data["abstract"].notna()]
# Out:
# Number of abstracts:  20494

# %%
# export only abstract and id

abstracts_only[["abstract","id","title"]].to_csv("abstracts_eng.csv", index = False)

# %% [markdown]
# ## Function for estimating storage requirements

# %%
def compute_storage_upper_bound(nrpubs, nrdeps, nrorgs, nrpeople):
    """Gives a rough upper bound of the storage required for a graph (GB) with the given input parameter values"""
    import numpy as np
    
    # Record size per node: 15B
    # Record size per edge: 34B
    # Record size per attribute: 41B
    # Record size per string or array attribute: 128B
    # https://neo4j.com/developer/kb/understanding-data-on-disk/
    
    nrtopics = np.log(nrpubs) # assume that the number of topics grows logarithmically with the number of publications
    
    # for each type on node, multiply the number of nodes with the storage required for the node annd its attributes
    node_storage = nrpubs*(15+2*41+4*128) + nrdeps*(15+41+128) + nrorgs*(15+41+128) + nrpeople*(15+41+128) + nrtopics*(15+41+128)
    
    dep_people_edges = nrdeps*40 # assume max 40 professors per department on average
    org_people_edges = nrorgs*5 # assume max 5 professors per organisation on average
    pub_people_edges = nrpubs*10 # assume max 10 authors per publication on average
    pub_topic_edges = nrpubs*20 # assume max 10 topics per publication on average
    
    # for each type on edge, multiply the number of nodes with the storage required for the node annd its attributes
    edge_storage = dep_people_edges*34 + org_people_edges*34 + pub_people_edges*34 + pub_topic_edges*(34+128)
    
    # storage required for indices
    # following neo4j heuristics: average property value size * (1/3)
    # we have four indices, one for each node
    avg_prop_size = (6*41+9*128)/15
    index_storage = avg_prop_size*(nrpubs + nrdeps + nrorgs + nrpeople)*(1/3)
    
    # add and return in GB
    return (node_storage + edge_storage + index_storage)/10**9

# %%
compute_storage_upper_bound(170000, 16, 400, 10000)
# Out:
# 0.7197434437472171
