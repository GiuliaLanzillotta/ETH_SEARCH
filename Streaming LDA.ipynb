# %%
import pandas as pd
import os 
import numpy as np
import re
import random
import nltk
import pickle
from nltk import word_tokenize, RegexpTokenizer,PunktSentenceTokenizer, sent_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
#nltk.download('stopwords')
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# %%
abstracts = pd.read_csv("abstracts_eng.csv")
abs_list = list(abstracts['abstract'])

# %%
tokenised = []
count = 0
for abstract in abs_list:
    raw = abstract
    tokens = gensim.utils.simple_preprocess(str(raw), deacc=True)
    tokenised.append(tokens)
    count += len(tokens)
print(str(count)+" tokens created")
# Out:
# 3855522 tokens created

# %%
c = []
for doc in tokenised: 
    c+=doc
len(set(c))
# Out:
# 71429

# %%
stop_words = stopwords.words('english')
print(len(stop_words))
stop_words = stop_words + stopwords.words('german')
print(len(stop_words))
stop_words = stop_words + stopwords.words('french')
print(len(stop_words))
cleaned = [[word for word in doc if word not in stop_words] for doc in tokenised]
# Out:
# 179
# 411
# 568

# %%
c = []
for doc in cleaned: 
    c+=doc
len(set(c))
# Out:
# 71081

# %%
#word_stemmer = PorterStemmer()
lemmatiser = WordNetLemmatizer()
word_stemmer = PorterStemmer()
lemmatized = [[lemmatiser.lemmatize(word_stemmer.stem(word)) for word in doc] for doc in cleaned]

# %%
c = []
for doc in lemmatized: 
    c+=doc
len(set(c))
# Out:
# 50809

# %%
cleaned = lemmatized

# %%
cleaned[0]
# Out:
# ['goal',
#  'note',
#  'introduce',
#  'new',
#  'classes',
#  'operator',
#  'ideals',
#  'moreover',
#  'new',
#  'way',
#  'constructing',
#  'classes',
#  'application',
#  'operators',
#  'asymptotic',
#  'structure',
#  'recently',
#  'introduced',
#  'maurey',
#  'milman',
#  'tomczak',
#  'jaegermann',
#  'op',
#  'th',
#  'adv',
#  'appl']

# %%
pickle.dump(cleaned, open( "collection_cleaned_fullwords.p", "wb" ))

# %%
pickle.dump(cleaned, open( "collection_cleaned.p", "wb" ))

# %% [markdown]
# ### Training models

# %%
import sys
import tomotopy as tp

# %%
SEED = 11
random.seed(SEED)
random.shuffle(cleaned)

# %%
# Defining hyperparameters
tw = tp.TermWeight.IDF # term weighting scheme in TermWeight. The default value is TermWeight.ONE
k = 100 # number of topics...
min_cf=3 # minimum collection frequency of words. Words with a smaller collection frequency than min_cf are excluded from the model. The default value is 0, which means no words are excluded.
min_df=0 # minimum document frequency of words. Words with a smaller document frequency than min_df are excluded from the model. The default value is 0, which means no words are excluded
rm_top=5 # the number of top words to be removed. If you want to remove too common words from model, you can set this value to 1 or more. The default value is 0, which means no top words are removed.
alpha = 0.1 # hyperparameter of Dirichlet distribution for document-topic
eta = 0.01 # hyperparameter of Dirichlet distribution for topic-word
seed = 41 # random seed
model_burn_in = 100 
train_updates = 1000
train_iter = 10
save_path = "lda_model150.bin" #.bin format

# %%
def train_LDA(documents, k, tw, min_cf=0, min_df=0, rm_top=0, alpha=0.1, eta=0.01, model_burn_in=100, 
              train_updates = 1000, train_iter = 10, seed=41):
    
    # instantiate
    model = tp.LDAModel(tw=tw, min_df=min_df, min_cf=min_cf, rm_top=rm_top, k=k, alpha = alpha, eta = eta, seed=seed)
    
    # add documents to model
    for doc in documents: model.add_doc(doc)
    
    # training**
    model.burn_in = model_burn_in
    # initialising 
    model.train(iter=0)
    print('Num docs:', len(model.docs), ', Vocab size:', len(model.used_vocabs), ', Num words:', model.num_words)
    print('Removed top words:', model.removed_top_words)
    print('Training...', file=sys.stderr, flush=True)
    # actual training 
    time = []
    LLs = []
    for i in range(0, train_updates, train_iter):
        model.train(train_iter)
        if i%100==0:print('Iteration: {}'.format(i))
        time.append(i)
        LLs.append(model.ll_per_word)
    
    return model, LLs, time

# %% [markdown]
# ### Top Models Topics from gridsearch

# %%
# Defining hyperparameters
tw = tp.TermWeight.IDF # term weighting scheme in TermWeight. The default value is TermWeight.ONE
min_cf=3 # minimum collection frequency of words. Words with a smaller collection frequency than min_cf are excluded from the model. The default value is 0, which means no words are excluded.
min_df=0 # minimum document frequency of words. Words with a smaller document frequency than min_df are excluded from the model. The default value is 0, which means no words are excluded
rm_top=8 # the number of top words to be removed. If you want to remove too common words from model, you can set this value to 1 or more. The default value is 0, which means no top words are removed.
seed = 41 # random seed
model_burn_in = 100 
train_updates = 1000
train_iter = 10

# %%
Subset = 5000
parameters = [{'k':175, 'alpha':5.71E-05,'eta':2.82E-05},{'k':150, 'alpha':0.000666667,'eta':2.82E-05},
              {'k':125, 'alpha':0.0008,'eta':2.82E-05},{'k':100, 'alpha':0.0001,'eta':2.82E-05},
              {'k':75, 'alpha':0.000133333,'eta':2.82E-05}]
models = []
LLs = []
batch = cleaned[10000:3*Subset]
for dicti in parameters:
    model, loglikes, _ = train_LDA(batch, **dicti, tw=tw, min_cf=min_cf, rm_top=rm_top, 
                                 model_burn_in=model_burn_in, 
                                 train_updates = train_updates, train_iter = train_iter, seed = seed)
    models.append(model)
    LLs.append(loglikes)
# Out:
# Training...
# Num docs: 5000 , Vocab size: 17520 , Num words: 568962
# Removed top words: ['data', 'model', 'based', 'results', 'using', 'two', 'high', 'study']
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Training...
# Num docs: 5000 , Vocab size: 17520 , Num words: 568962
# Removed top words: ['data', 'model', 'based', 'results', 'using', 'two', 'high', 'study']
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Training...
# Num docs: 5000 , Vocab size: 17520 , Num words: 568962
# Removed top words: ['data', 'model', 'based', 'results', 'using', 'two', 'high', 'study']
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-4b07df817638> in <module>
#       9     model, loglikes, _ = train_LDA(batch, **dicti, tw=tw, min_cf=min_cf, rm_top=rm_top,
#      10                                  model_burn_in=model_burn_in,
# ---> 11                                  train_updates = train_updates, train_iter = train_iter, seed = seed)
#      12     models.append(model)
#      13     LLs.append(loglikes)
#
# <ipython-input-13-fe656abb34e4> in train_LDA(documents, k, tw, min_cf, min_df, rm_top, alpha, eta, model_burn_in, train_updates, train_iter, seed)
#      20     for i in range(0, train_updates, train_iter):
#      21         model.train(train_iter)
# ---> 22         if i%100==0:print('Iteration: {}'.format(i))
#      23         time.append(i)
#      24         LLs.append(model.ll_per_word)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Evaluating manually results from top 5 grid-search models

# %%
print(models[2].summary())
#print(LLs[0])
# Out:
# <Basic Info>
# | LDAModel (current version: 0.9.1)
# | 5000 docs, 568621 words
# | Total Vocabs: 24636, Used Vocabs: 11897
# | Entropy of words: -7.95917
# | Removed Vocabs: use model result data studi base differ system
# |
# <Training Info>
# | Iterations: 1000, Burn-in steps: 100
# | Optimization Interval: 10
# | Log-likelihood per word: -29.35916
# |
# <Initial Parameters>
# | tw: TermWeight.IDF
# | min_cf: 3 (minimum collection frequency of words)
# | min_df: 0 (minimum document frequency of words)
# | rm_top: 8 (the number of top words to be removed)
# | k: 125 (the number of topics between 1 ~ 32767)
# | alpha: 0.0008 (hyperparameter of Dirichlet distribution for document-topic)
# | eta: 2.82e-05 (hyperparameter of Dirichlet distribution for topic-word)
# | seed: 41 (random seed)
# | trained in version 0.9.1
# |
# <Parameters>
# | alpha (Dirichlet prior on the per-document topic distributions)
# |  [0.01890876 0.03327749 0.02756519 0.03001748 0.30038354 0.08986171
# |   0.01580108 0.08982162 0.02185369 0.02927051 0.02233893 0.05185439
# |   0.01129061 0.40859014 0.02704086 0.0222178  0.01171764 0.01037625
# |   0.01144968 0.01047778 0.01313897 0.02922549 0.03404425 0.01335939
# |   0.03511122 0.06402308 0.0516989  0.0205155  0.00941426 0.10694552
# |   0.01555886 0.08553656 0.01156082 0.01247853 0.01010678 0.00904783
# |   0.00786188 0.01544492 0.01146986 0.01177212 0.02530446 0.05188403
# |   0.03050941 0.02381381 0.05382099 0.02556203 0.0333138  0.0397423
# |   0.01853933 0.01778479 0.0295393  0.01172912 0.00964545 0.17924713
# |   0.02588366 0.12758577 0.01703299 0.03511725 0.03091458 0.00981831
# |   0.037761   0.09402224 0.02667727 0.00733185 0.02200259 0.01168125
# |   0.0204857  0.05925253 0.01524686 0.01839248 0.00926395 0.007622
# |   0.01882504 0.01420527 0.03910429 0.07707909 0.02114504 0.02482978
# |   0.01362663 0.0744482  0.05517156 0.07428321 0.03127457 0.05984493
# |   0.05347418 0.18148741 0.02490239 0.05612065 0.01134892 0.02785396
# |   0.01246965 0.04016779 0.01939483 0.03940081 0.02242122 0.00828587
# |   0.02271824 0.03552142 0.00846476 0.0135331  0.01023046 0.02416242
# |   0.09294128 0.01139615 0.00824781 0.01544748 0.00667433 0.01173942
# |   0.0166338  0.04037106 0.04712452 0.00733564 0.02509716 0.01939786
# |   0.02895245 0.00797705 0.13582873 0.05636029 0.04633066 0.01138277
# |   0.25804842 0.01349785 0.04566184 0.00973929 0.01161844]
# | eta (Dirichlet prior on the per-topic word distribution)
# |  2.82e-05
# |
# <Topics>
# | #0 (2085) : membran stem protein tissu load
# | #1 (4821) : train age intervent pain game
# | #2 (2850) : metal ray materi optic crystal
# | #3 (6910) : quark collis proton gev lhc
# | #4 (29712) : quantum state error physic type
# | #5 (9453) : resourc gait social research trade
# | #6 (1292) : worker cmr bank gfp polici
# | #7 (8452) : compound atom transfer molecul catalyst
# | #8 (4083) : boson higg lepton decay tev
# | #9 (4451) : metabol bacteria strain microbiota bacteri
# | #10 (2982) : patient clinic therapi drug stroke
# | #11 (5868) : firm countri institut manag knowledg
# | #12 (1028) : app memori asthma avalanch damp
# | #13 (42379) : optim problem time estim method
# | #14 (3770) : flower degrad delet mutant translat
# | #15 (3447) : climat emiss global chang warm
# | #16 (1588) : mitochondri ribosom viru drosophila nk
# | #17 (1029) : li mc electrod batteri swi
# | #18 (1252) : reaction lipid embryo edc pcg
# | #19 (1073) : park acut mn lung coronari
# | #20 (1249) : cluster dri ch n iav
# | #21 (3493) : biofilm morpholog growth fe rock
# | #22 (3739) : heat thermal entropi flow build
# | #23 (1610) : resist antibiot antibodi transmiss cri
# | #24 (3570) : fluid liquid graphen lattic crystallin
# | #25 (8154) : speci tree forest ecosystem commun
# | #26 (5491) : pul failur laser coat cr
# | #27 (2760) : innov galaxi financi sector econom
# | #28 (1148) : maiz insect inp gm seed
# | #29 (10498) : theori fit rate cirru languag
# | #30 (2249) : neuron cortex cortic cognit disord
# | #31 (10915) : energi environment cost food demand
# | #32 (1405) : milk hiv veget streamflow exposur
# | #33 (1068) : al alcohol ethnic microwav prime
# | #34 (1083) : peptid cow graze phage r
# | #35 (997) : cd th wood pet prokaryot
# | #36 (643) : resili social bird microbiom disast
# | #37 (1981) : earthquak sediment slope north anomali
# | #38 (1867) : ice glacier nucleat dust water
# | #39 (1091) : root cattl br privaci wing
# | #40 (2344) : landscap log graph color shoot
# | #41 (5342) : motor learn educ cognit task
# | #42 (3158) : aid disk star flood imag
# | #43 (2242) : harmon moment stochast execut tc
# | #44 (5455) : hous servic market agent stock
# | #45 (4914) : jet section pb measur hadron
# | #46 (3328) : photon differenti cross qcd adhes
# | #47 (4293) : fault grid storag monitor energi
# | #48 (2144) : manufactur stiff fluid pc mpc
# | #49 (2332) : isotop carbon water organ deposit
# | #50 (5286) : cell receptor tumor tissu blood
# | #51 (1254) : variant cc tumor imput inhal
# | #52 (782) : vr dot sen frame remot
# | #53 (18184) : flow dimens topolog size order
# | #54 (2867) : marin latitud ocean record period
# | #55 (14579) : variabl chang precipit water weather
# | #56 (1996) : ro ion hg anod nh
# | #57 (5569) : ocean ensembl evapor global tropic
# | #58 (2890) : cooper protect interview tl fund
# | #59 (1191) : iron infant satellit child matern
# | #60 (3914) : urban citi gp build site
# | #61 (10059) : user secur architectur challeng strategi
# | #62 (2874) : stabil mechan film nitrogen thin
# | #63 (730) : ferment pol catalyst wine nr
# | #64 (3322) : ozon stratospher trend solar yr
# | #65 (1062) : node tendon edg digit black
# | #66 (2406) : robot classif landslid task feedback
# | #67 (6565) : technolog risk particip sustain conflict
# | #68 (1453) : cardiac pd plasmon nanoparticl label
# | #69 (2135) : methyl brain fur epigenet sensori
# | #70 (1112) : forecast drought ctl sg cmv
# | #71 (688) : ln antenna crime qmc exciton
# | #72 (1950) : street tunnel actor hb virtual
# | #73 (2186) : emot mg ca biomass ph
# | #74 (3999) : plan user compress vehicl loop
# | #75 (7940) : electr power convers control engin
# | #76 (1809) : di regim epidemiolog long stochast
# | #77 (3435) : co carbon flux emiss ga
# | #78 (1196) : pt ligand vector anomal colour
# | #79 (8000) : travel converg algorithm choic approxim
# | #80 (6750) : transport traffic network mode road
# | #81 (9269) : learn network machin circuit code
# | #82 (3417) : isol conform resist bi segreg
# | #83 (8764) : atmospher seismic temperatur sea km
# | #84 (5455) : phosphoryl incom heterogen kina evid
# | #85 (16362) : rout loss environ transform research
# | #86 (3486) : gene express protein transcript bind
# | #87 (10655) : cloud aerosol particl droplet veloc
# | #88 (1428) : dose ct cu patient groundwat
# | #89 (3141) : contact walk deform alloy load
# | #90 (1271) : femal male breath profit cassava
# | #91 (4686) : spin electron np volatil bc
# | #92 (3051) : soil moistur water precipit cmip
# | #93 (5612) : mouse signal respons human activ
# | #94 (2342) : catchment lake hydrolog pressur elev
# | #95 (1020) : sleep wake sp zircon nrem
# | #96 (2123) : magnet soc soft logic motion
# | #97 (3826) : diffus curv invers rate strain
# | #98 (1077) : sr clock inflammatori lymphat dc
# | #99 (1399) : health valenc covid hospit supplement
# | #100 (963) : mirna word pesticid river broadcast
# | #101 (3131) : popul trait genotyp diver household
# | #102 (9860) : sensor movement devic stress memori
# | #103 (980) : si oa deform prefront shear
# | #104 (869) : magma drink quartz volcan poultri
# | #105 (1880) : muscl exercis mri fatigu particip
# | #106 (741) : woman men fn soft russland
# | #107 (1452) : snow bone arctic tensil temperatur
# | #108 (1395) : methan campaign μg reaction uv
# | #109 (5179) : imag score map myocardi acquisit
# | #110 (7508) : gene genom mutat sequenc genet
# | #111 (794) : parasit host kill print wg
# | #112 (3314) : farm summer climat farmer grassland
# | #113 (3241) : plant soil microbi biomass speci
# | #114 (3684) : infect viral viru diver uav
# | #115 (724) : daphnia cft hr thrust blockchain
# | #116 (14856) : dna human content sequenc detect
# | #117 (9529) : cell pathogen protein host diseas
# | #118 (4771) : pathway rna line ev plastic
# | #119 (1147) : macrophag island fossil taxon calv
# | #120 (25858) : decis inform project share relat
# | #121 (1627) : fractur wave polar voltag crack
# | #122 (7313) : search mass channel reson event
# | #123 (960) : car photograph subduct fleet rossi
# | #124 (1190) : m fluoresc eeg fibril adolesc
# |
#
# None

# %%
test = cleaned[15000:]
test_inf=[models[3].make_doc(doc) for doc in test]
tpc_dist, ll = models[3].infer(test_inf)

# %%
len(tpc_dist)
# Out:
# 5494

# %%
topic_test = np.array(tpc_dist[1])
np.argsort(topic_test, axis=0)
# Out:
# array([74, 25, 96, 95,  0, 20, 10, 17, 93, 99, 43, 91, 56, 86, 40, 38, 42,
#        52, 65, 77, 57, 51, 50, 60,  8, 68, 66, 45, 33, 70, 14, 23, 89, 78,
#        48, 31, 22, 84, 36, 73,  4, 16, 81, 54, 41,  7, 71, 94, 63,  6, 19,
#        32, 98, 55, 64, 53, 21, 15, 92,  9, 46,  3, 39, 11, 90, 75, 26, 28,
#        83, 72, 79, 62, 58,  1, 12, 88, 30, 37, 44, 49, 82, 97, 13, 80, 24,
#        67, 35, 34,  2, 61, 69, 29, 85, 59, 27,  5, 18, 76, 87, 47],
#       dtype=int64)

# %%
models[3].get_topic_words(76)
# Out:
# [('particl', 0.04570361599326134),
#  ('aerosol', 0.023621078580617905),
#  ('nucleat', 0.0215678159147501),
#  ('droplet', 0.01915661059319973),
#  ('liquid', 0.018538711592555046),
#  ('concentr', 0.01778131164610386),
#  ('dust', 0.014575991779565811),
#  ('measur', 0.013146561570465565),
#  ('chemic', 0.01259393710643053),
#  ('phase', 0.012286645360291004)]

# %%
' '.join(cleaned[15001])
# Out:
# 'atom load optic lattic process gradual turn lattic almost adiabat paper investig temperatur chang go gapless superfluid phase gap mott phase along isentrop line calcul entropi singl band bose hubbard model variou densiti interact strength temperatur one two dimens homogen trap system theori abl reproduc experiment observ visibl therefor strongli support view current experi remain quantum regim consid lattic depth low temperatur minim heat'

# %% [markdown]
# ### Finally training and storing best models for 4 batches

# %%
models = []
LLs = []
num_batches = 4
batches = np.array_split(cleaned, num_batches)
dicti = {'k':125, 'alpha':0.0008,'eta':2.82E-05}
for batch_num in range(0, num_batches):

    batch = batches[batch_num].tolist()
    model, loglikes, _ = train_LDA(batch, **dicti, tw=tw, min_cf=min_cf, rm_top=rm_top, 
                                 model_burn_in=model_burn_in, 
                                 train_updates = train_updates, train_iter = train_iter)
    models.append(model)
    LLs.append(loglikes)
# Out:
# Training...
# Num docs: 5124 , Vocab size: 17574 , Num words: 575391
# Removed top words: ['data', 'model', 'results', 'based', 'using', 'study', 'time', 'two']
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Training...
# Num docs: 5124 , Vocab size: 17506 , Num words: 575061
# Removed top words: ['data', 'model', 'results', 'based', 'using', 'two', 'study', 'time']
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Training...
# Num docs: 5123 , Vocab size: 17670 , Num words: 581054
# Removed top words: ['data', 'model', 'based', 'results', 'using', 'two', 'high', 'study']
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Training...
# Num docs: 5123 , Vocab size: 17453 , Num words: 570023
# Removed top words: ['data', 'model', 'results', 'based', 'using', 'study', 'two', 'high']
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900

# %%
names = ['LDA1batch1.bin','LDA1batch2.bin','LDA1batch3.bin','LDA1batch4.bin']
for i,model in enumerate(models):
    model.save(names[i])

# %% [markdown]
# ##### Choice based on ll of 125 topics per 5000

# %% [markdown]
# ##### Future work: Training on one batch and checking topic on another seems to give coherent results. This is an indication that aggregation of topics through a divergence or clustering technique may be relevant.

# %% [markdown]
# ##### TODO: Check the function to determine number of topics per documents.

# %% [markdown]
# ### Topic embeddings and comparisons

# %%
def get_top_topics(document, model, min_score=0.8):
    """ 
    Extracting top n topics for each document. 
    Selects the n most likely topics whose p(topic|document) sum to min_score.
    """
    # inserting the document in the model
    new_doc = model.make_doc(document)
    _,_ = model.infer(new_doc)
    # ordering from most probable topic to least one 
    dist = new_doc.get_topic_dist()
    indices = np.flip(np.argsort(dist))
    score = 0
    indices_kept = []
    probs_kept = []
    for index in indices:
        if score > min_score: break
        score += dist[index]
        indices_kept.append(index)
        probs_kept.append(dist[index])
    return list(zip(indices_kept, probs_kept))

# %%
def get_top_words(topic, model, min_score=0.8):
    """
    Extracting top n words for each document. 
    Selects the n most likely words whose p(word|topic) sum to min_score.
    """
    dist = model.get_topic_word_dist(topic)
    indices = np.flip(np.argsort(dist))
    score = 0
    word_kept = []
    word_prob_kept = []
    for index in indices:
        if score > min_score: break
        score += dist[index]
        word_kept.append(model.used_vocabs[index])
        word_prob_kept.append(dist[index])
    return list(zip(word_kept, word_prob_kept))

# %%
num_topics = k
topics2words_list = []
for batch in range(0, num_batches):
    topics2words_list.append([get_top_words(i, models[batch], min_score=0.25) for i in range(num_topics)])

# %%
topics2words_list[2]
# Out:
# [[('urban', 0.050270602),
#   ('housing', 0.0266549),
#   ('city', 0.024721002),
#   ('singapore', 0.014500451),
#   ('building', 0.014409492),
#   ('semper', 0.012176565),
#   ('art', 0.01048656),
#   ('architect', 0.009767988),
#   ('urbanization', 0.009495137),
#   ('architecture', 0.009068691),
#   ('park', 0.009034045),
#   ('area', 0.008838711),
#   ('heat', 0.008206975),
#   ('cultural', 0.008192347),
#   ('flap', 0.0080487365),
#   ('m²', 0.007941464),
#   ('island', 0.0079045165),
#   ('architectural', 0.007722412),
#   ('photograph', 0.007466815)],
#  [('de', 0.029385291),
#   ('sanitation', 0.026249573),
#   ('mf', 0.02443935),
#   ('ppm', 0.022096686),
#   ('toilet', 0.016968342),
#   ('patent', 0.016009055),
#   ('con', 0.015961478),
#   ('max', 0.014739622),
#   ('mine', 0.014156663),
#   ('kof', 0.012269286),
#   ('fertility', 0.01191171),
#   ('mm', 0.011577112),
#   ('et', 0.011533953),
#   ('wu', 0.010911403),
#   ('aggression', 0.009820397),
#   ('une', 0.009820397)],
#  [('science', 0.013667408),
#   ('research', 0.012726501),
#   ('scientific', 0.00788139),
#   ('article', 0.007788716),
#   ('issue', 0.007769599),
#   ('development', 0.007417705),
#   ('collaboration', 0.0068326034),
#   ('project', 0.0066860104),
#   ('community', 0.00626831),
#   ('challenge', 0.0059627932),
#   ('social', 0.0059585166),
#   ('trust', 0.0058745584),
#   ('process', 0.005813815),
#   ('perspective', 0.005757123),
#   ('way', 0.0055825803),
#   ('society', 0.0054671234),
#   ('practice', 0.0052808854),
#   ('world', 0.0051844725),
#   ('workshop', 0.0051757395),
#   ('knowledge', 0.005086944),
#   ('author', 0.0050679445),
#   ('theory', 0.0050457264),
#   ('role', 0.005039301),
#   ('researcher', 0.0049553295),
#   ('review', 0.0047971327),
#   ('understanding', 0.004756303),
#   ('scientist', 0.00469796),
#   ('coordination', 0.004621789),
#   ('aspect', 0.004446989),
#   ('discipline', 0.00444351),
#   ('idea', 0.004384861),
#   ('concept', 0.0043023997),
#   ('discussion', 0.0042920867),
#   ('paper', 0.004277726),
#   ('theme', 0.004209311),
#   ('cooperative', 0.004168886),
#   ('discus', 0.004163088),
#   ('today', 0.0041031064),
#   ('learning', 0.004088796),
#   ('context', 0.004063221),
#   ('aim', 0.004055356),
#   ('behaviour', 0.0040208595),
#   ('organization', 0.0040079234),
#   ('international', 0.004006442),
#   ('tie', 0.0040061055),
#   ('work', 0.003997828)],
#  [('tissue', 0.017139304),
#   ('mouse', 0.015943054),
#   ('tendon', 0.010935456),
#   ('cell', 0.01032953),
#   ('blood', 0.0102731595),
#   ('skin', 0.0093491115),
#   ('muscle', 0.009031648),
#   ('vivo', 0.008854709),
#   ('disease', 0.008433786),
#   ('liver', 0.008362292),
#   ('vascular', 0.00803698),
#   ('vitro', 0.0078334445),
#   ('lymphatic', 0.0074432404),
#   ('implant', 0.007068008),
#   ('vessel', 0.007009938),
#   ('human', 0.0068403566),
#   ('inflammatory', 0.0067408695),
#   ('vegf', 0.0066413665),
#   ('animal', 0.0064308983),
#   ('healing', 0.006368921),
#   ('drug', 0.0059371446),
#   ('therapy', 0.0057318504),
#   ('bone', 0.005636515),
#   ('inflammation', 0.005426542),
#   ('immune', 0.0053565493),
#   ('wound', 0.005342448),
#   ('receptor', 0.005065479),
#   ('endothelial', 0.0050231623),
#   ('treatment', 0.0048991237),
#   ('induced', 0.0047641178),
#   ('cd', 0.0047347853),
#   ('treated', 0.0045338287),
#   ('organ', 0.004493985),
#   ('exposure', 0.004482602)],
#  [('air', 0.026867045),
#   ('wind', 0.017311499),
#   ('km', 0.012507066),
#   ('winter', 0.011819246),
#   ('mixing', 0.011003182),
#   ('transport', 0.009276741),
#   ('summer', 0.009120132),
#   ('layer', 0.008323257),
#   ('station', 0.0081281075),
#   ('pollution', 0.0076946863),
#   ('pco', 0.0076852897),
#   ('trajectory', 0.007456665),
#   ('atmospheric', 0.0074319104),
#   ('measurement', 0.006989438),
#   ('concentration', 0.006882),
#   ('north', 0.006685951),
#   ('meteorological', 0.0063284086),
#   ('resolution', 0.0062639653),
#   ('site', 0.005989632),
#   ('day', 0.005959024),
#   ('valley', 0.005813844),
#   ('precipitation', 0.0058099334),
#   ('temperature', 0.0057710046),
#   ('parcel', 0.0056263595),
#   ('tropopause', 0.0055848756),
#   ('altitude', 0.0054536853),
#   ('regional', 0.005330498),
#   ('water', 0.0051914123),
#   ('scale', 0.0051318263),
#   ('convection', 0.005087443),
#   ('weather', 0.005015874),
#   ('troposphere', 0.005012366)],
#  [('protein', 0.029960899),
#   ('binding', 0.019352593),
#   ('peptide', 0.014391069),
#   ('nmr', 0.012685429),
#   ('ligand', 0.012641527),
#   ('enzyme', 0.012122545),
#   ('structure', 0.011562808),
#   ('residue', 0.010618929),
#   ('complex', 0.009551519),
#   ('affinity', 0.009381286),
#   ('structural', 0.00890532),
#   ('molecular', 0.008500793),
#   ('conformation', 0.0082940925),
#   ('membrane', 0.0068314574),
#   ('site', 0.0067611234),
#   ('compound', 0.0063410513),
#   ('conformational', 0.006324857),
#   ('amino', 0.005822898),
#   ('helix', 0.0057774344),
#   ('molecule', 0.005713146),
#   ('terminal', 0.0057071196),
#   ('acid', 0.0055737137),
#   ('domain', 0.005328415),
#   ('interaction', 0.0051817023),
#   ('activity', 0.0050209113),
#   ('assembly', 0.004868858),
#   ('dota', 0.004554013),
#   ('ring', 0.0044680224)],
#  [('brain', 0.027039163),
#   ('neuron', 0.023277763),
#   ('neural', 0.013449457),
#   ('connectivity', 0.013199627),
#   ('cortex', 0.011544967),
#   ('synaptic', 0.009671441),
#   ('motor', 0.009178873),
#   ('sensory', 0.00901045),
#   ('neuronal', 0.008803541),
#   ('stimulation', 0.00845693),
#   ('fmri', 0.008192221),
#   ('nogo', 0.008095926),
#   ('cortical', 0.007854638),
#   ('network', 0.007739693),
#   ('memory', 0.0074165207),
#   ('learning', 0.0073448094),
#   ('stimulus', 0.0072775134),
#   ('circuit', 0.0069870776),
#   ('spike', 0.006641051),
#   ('cognitive', 0.005893473),
#   ('functional', 0.0058222315),
#   ('activity', 0.0057853158),
#   ('plasticity', 0.0056916843),
#   ('resting', 0.005278508),
#   ('behavioral', 0.005264723),
#   ('nerve', 0.005215405),
#   ('visual', 0.005108914),
#   ('reward', 0.005047256)],
#  [('icc', 0.022530157),
#   ('migration', 0.022309689),
#   ('ethnic', 0.015703684),
#   ('jlca', 0.015403577),
#   ('hka', 0.013034003),
#   ('nwb', 0.013034003),
#   ('annoyance', 0.013034003),
#   ('lca', 0.012624205),
#   ('norm', 0.012236629),
#   ('team', 0.012098332),
#   ('functionality', 0.011711554),
#   ('rebel', 0.011412363),
#   ('group', 0.0108281905),
#   ('irr', 0.010374998),
#   ('crispatus', 0.009479642),
#   ('actor', 0.009165363),
#   ('allocation', 0.009094461),
#   ('wb', 0.0089901965),
#   ('risky', 0.008900778),
#   ('latency', 0.008853038)],
#  [('lake', 0.035842758),
#   ('river', 0.028910823),
#   ('groundwater', 0.027551712),
#   ('avalanche', 0.024893766),
#   ('sediment', 0.022529908),
#   ('water', 0.022529058),
#   ('monsoon', 0.020771649),
#   ('floodplain', 0.015538145),
#   ('channel', 0.013738854),
#   ('valley', 0.013411051),
#   ('flood', 0.013354744),
#   ('dam', 0.012520533)],
#  [('child', 0.02159102),
#   ('decision', 0.020138072),
#   ('risk', 0.018246377),
#   ('preference', 0.014771461),
#   ('perception', 0.014637132),
#   ('gender', 0.014474797),
#   ('acceptance', 0.013802249),
#   ('perceived', 0.011560871),
#   ('uncertainty', 0.010521874),
#   ('school', 0.010421102),
#   ('woman', 0.010314789),
#   ('respondent', 0.009859731),
#   ('attitude', 0.009695006),
#   ('career', 0.00919928),
#   ('attribute', 0.009075243),
#   ('questionnaire', 0.008883434),
#   ('task', 0.00808279),
#   ('belief', 0.007740322),
#   ('mvpa', 0.0076940176),
#   ('social', 0.007454179),
#   ('ssh', 0.007236274),
#   ('online', 0.006973872)],
#  [('bd', 0.023180783),
#   ('cheese', 0.022822155),
#   ('planet', 0.021907745),
#   ('ngo', 0.019811518),
#   ('separator', 0.019495502),
#   ('star', 0.01903154),
#   ('aid', 0.017187817),
#   ('companion', 0.016986363),
#   ('ac', 0.015746165),
#   ('fo', 0.015454272),
#   ('smear', 0.014207727),
#   ('disk', 0.0118525475),
#   ('collapse', 0.011308077),
#   ('fv', 0.011163481),
#   ('rack', 0.010607207)],
#  [('host', 0.02665481),
#   ('parasite', 0.019983903),
#   ('pathogen', 0.019670876),
#   ('specie', 0.018175557),
#   ('immune', 0.010847598),
#   ('population', 0.010626712),
#   ('infection', 0.010513803),
#   ('fungal', 0.009877463),
#   ('resistance', 0.009734663),
#   ('trait', 0.008518243),
#   ('genotype', 0.008411318),
#   ('selection', 0.008030437),
#   ('evolutionary', 0.007145736),
#   ('virulence', 0.006749006),
#   ('disease', 0.0062763602),
#   ('taxon', 0.0062425374),
#   ('animal', 0.006121367),
#   ('infected', 0.006102427),
#   ('mate', 0.0059349798),
#   ('insect', 0.0059152055),
#   ('organism', 0.0058659688),
#   ('clade', 0.0055687223),
#   ('interaction', 0.005250709),
#   ('natural', 0.0051840576),
#   ('isolates', 0.0050816177),
#   ('egg', 0.005035736),
#   ('divergence', 0.0049968916),
#   ('tritici', 0.0049884887)],
#  [('eruption', 0.017310869),
#   ('mantle', 0.015325485),
#   ('melt', 0.015001884),
#   ('volcanic', 0.014371279),
#   ('magma', 0.013169736),
#   ('plume', 0.012326349),
#   ('rock', 0.010916617),
#   ('crustal', 0.010471841),
#   ('crust', 0.009276494),
#   ('calving', 0.009236317),
#   ('tremor', 0.008757964),
#   ('garnet', 0.008553311),
#   ('ridge', 0.007564071),
#   ('lithosphere', 0.0072839367),
#   ('hydrothermal', 0.006719475),
#   ('melting', 0.0065539707),
#   ('zircon', 0.006541997),
#   ('o', 0.0065350337),
#   ('quartz', 0.0062414445),
#   ('zone', 0.006168847),
#   ('fluid', 0.0061369273),
#   ('slab', 0.006072288),
#   ('formation', 0.005913071),
#   ('subduction', 0.0058832667),
#   ('caldera', 0.0057265176),
#   ('silicate', 0.00569875),
#   ('inclusion', 0.005667717),
#   ('tectonic', 0.0054537226),
#   ('sr', 0.0054537226)],
#  [('disorder', 0.020403849),
#   ('asd', 0.017542923),
#   ('adhd', 0.012972506),
#   ('social', 0.011560526),
#   ('pain', 0.01138747),
#   ('child', 0.010191717),
#   ('dog', 0.010042889),
#   ('control', 0.009077706),
#   ('behavior', 0.008732553),
#   ('adolescent', 0.0083903195),
#   ('deficit', 0.008257002),
#   ('autism', 0.0078101354),
#   ('age', 0.007677993),
#   ('cocaine', 0.0075196624),
#   ('related', 0.0071538365),
#   ('cognitive', 0.0070500025),
#   ('emotional', 0.007043297),
#   ('mental', 0.0070061446),
#   ('dd', 0.0069807675),
#   ('meniscus', 0.0068599572),
#   ('depression', 0.006678201),
#   ('fc', 0.006474093),
#   ('impairment', 0.006448424),
#   ('stress', 0.0062472206),
#   ('anxiety', 0.006213861),
#   ('psychiatric', 0.006071925),
#   ('abnormality', 0.006071925),
#   ('pe', 0.006071925),
#   ('canine', 0.0058037634),
#   ('healthy', 0.0056818295)],
#  [('jet', 0.019344209),
#   ('section', 0.017862769),
#   ('collision', 0.015522662),
#   ('cross', 0.01485397),
#   ('proton', 0.014682276),
#   ('gev', 0.01314536),
#   ('momentum', 0.012922458),
#   ('transverse', 0.011566254),
#   ('detector', 0.010566154),
#   ('energy', 0.010189058),
#   ('measured', 0.009705262),
#   ('measurement', 0.009565188),
#   ('qcd', 0.009457214),
#   ('particle', 0.009399558),
#   ('photon', 0.009349218),
#   ('pp', 0.00901775),
#   ('lhc', 0.008969344),
#   ('hadron', 0.00883468),
#   ('pt', 0.00858664),
#   ('pb', 0.008478084),
#   ('cm', 0.008381835),
#   ('tev', 0.008100022),
#   ('event', 0.008036811)],
#  [('household', 0.044206295),
#   ('psma', 0.042876273),
#   ('lu', 0.03362688),
#   ('consumer', 0.02761248),
#   ('sc', 0.021851454),
#   ('appliance', 0.020218426),
#   ('consumption', 0.020180566),
#   ('literacy', 0.018977094),
#   ('anastomosis', 0.018003622),
#   ('mbq', 0.017717797)],
#  [('energy', 0.036549553),
#   ('electricity', 0.019967526),
#   ('co', 0.014667769),
#   ('cost', 0.014450548),
#   ('storage', 0.01405416),
#   ('building', 0.013728143),
#   ('power', 0.012955469),
#   ('emission', 0.012564708),
#   ('demand', 0.012214646),
#   ('solar', 0.0121100005),
#   ('renewable', 0.012064905),
#   ('technology', 0.0110858865),
#   ('environmental', 0.011072606),
#   ('consumption', 0.009862163),
#   ('system', 0.009298297),
#   ('supply', 0.009240959),
#   ('carbon', 0.008462258),
#   ('production', 0.00841779),
#   ('grid', 0.0083431)],
#  [('sleep', 0.08569987),
#   ('asthma', 0.02262601),
#   ('eeg', 0.020393487),
#   ('dopamine', 0.019049928),
#   ('healthcare', 0.015595261),
#   ('ant', 0.01471272),
#   ('vta', 0.013737626),
#   ('provider', 0.013586745),
#   ('nrem', 0.013405814),
#   ('wake', 0.012773375),
#   ('hfo', 0.012121559),
#   ('rem', 0.011320655)],
#  [('genome', 0.021791726),
#   ('gene', 0.01977362),
#   ('genetic', 0.018777948),
#   ('mutation', 0.01438595),
#   ('allele', 0.014047023),
#   ('locus', 0.012728589),
#   ('male', 0.012226617),
#   ('variant', 0.012217721),
#   ('population', 0.012053679),
#   ('chromosome', 0.011997722),
#   ('sequence', 0.011469754),
#   ('genomic', 0.009974875),
#   ('lineage', 0.009635636),
#   ('genotype', 0.008723642),
#   ('recombination', 0.008537058),
#   ('specie', 0.008306619),
#   ('marker', 0.008184673),
#   ('snp', 0.0077609825),
#   ('trait', 0.0074108425),
#   ('sex', 0.0072790743),
#   ('evolution', 0.0069648367),
#   ('dna', 0.00695959)],
#  [('crop', 0.037564583),
#   ('food', 0.021936504),
#   ('agricultural', 0.017967852),
#   ('wheat', 0.016894097),
#   ('yield', 0.016398663),
#   ('maize', 0.014145195),
#   ('milk', 0.013775695),
#   ('farmer', 0.012731894),
#   ('rice', 0.012626141),
#   ('agriculture', 0.0123269865),
#   ('cow', 0.012295042),
#   ('farm', 0.012212852),
#   ('bean', 0.012017041),
#   ('soil', 0.011508303),
#   ('production', 0.0104401605),
#   ('cultivar', 0.008978597),
#   ('breeding', 0.008860428)],
#  [('ozone', 0.05325719),
#   ('climate', 0.022395436),
#   ('stratospheric', 0.014895645),
#   ('warming', 0.0136917485),
#   ('change', 0.013174477),
#   ('stratosphere', 0.012255196),
#   ('trend', 0.011577345),
#   ('global', 0.011242175),
#   ('chemistry', 0.010486182),
#   ('simulation', 0.010381963),
#   ('increase', 0.009736317),
#   ('emission', 0.009217563),
#   ('projected', 0.009096124),
#   ('latitude', 0.008876642),
#   ('forcing', 0.008468723),
#   ('cmip', 0.008274567),
#   ('temperature', 0.008033367),
#   ('century', 0.007887949),
#   ('scenario', 0.0076989764)],
#  [('il', 0.045376085),
#   ('tnf', 0.03101759),
#   ('erk', 0.015397435),
#   ('cytokine', 0.014341551),
#   ('cartilage', 0.013174985),
#   ('inflammatory', 0.012978117),
#   ('typhimurium', 0.0129245715),
#   ('ivd', 0.0122208325),
#   ('salmonella', 0.011993885),
#   ('anti', 0.011620167),
#   ('egcg', 0.011085763),
#   ('mmp', 0.011052906),
#   ('inflammation', 0.01074619),
#   ('hp', 0.009963286),
#   ('msc', 0.009510441),
#   ('expression', 0.009452442),
#   ('culture', 0.008759488)],
#  [('diffusion', 0.03253593),
#   ('influenza', 0.024669472),
#   ('virus', 0.02180518),
#   ('outbreak', 0.02113711),
#   ('epidemic', 0.02055476),
#   ('poultry', 0.01991583),
#   ('farm', 0.019130135),
#   ('infection', 0.017698614),
#   ('transmission', 0.015159272),
#   ('diffusivities', 0.014516898),
#   ('hpai', 0.014477551),
#   ('coefficient', 0.01312418),
#   ('infected', 0.011912867),
#   ('pandemic', 0.011576991)],
#  [('igf', 0.04287448),
#   ('education', 0.036727134),
#   ('vet', 0.030107377),
#   ('employment', 0.020607656),
#   ('vocational', 0.018401101),
#   ('goat', 0.018065993),
#   ('job', 0.017701011),
#   ('sar', 0.017510004),
#   ('conversational', 0.015933115),
#   ('worker', 0.012764146),
#   ('olm', 0.012487836),
#   ('polarimetric', 0.012250627)],
#  [('lignin', 0.025748355),
#   ('copper', 0.018627292),
#   ('sfr', 0.015229537),
#   ('bn', 0.014636817),
#   ('nematode', 0.014004231),
#   ('cu', 0.01295747),
#   ('phenol', 0.012884712),
#   ('pretreatment', 0.012634779),
#   ('explosion', 0.012414322),
#   ('xylan', 0.012384256),
#   ('wood', 0.012121974),
#   ('prg', 0.011936396),
#   ('hoi', 0.011018292),
#   ('sarcopenia', 0.010836354),
#   ('hydrolysis', 0.009353444),
#   ('smoking', 0.009288453),
#   ('hyperacusis', 0.009182083),
#   ('digestibility', 0.009182083),
#   ('naphthol', 0.009182083),
#   ('pgp', 0.009182083)],
#  [('iron', 0.07689612),
#   ('vitamin', 0.022575496),
#   ('retinal', 0.020706141),
#   ('deficiency', 0.017519854),
#   ('rhodopsin', 0.016124774),
#   ('hepcidin', 0.013052833),
#   ('sii', 0.01044059),
#   ('retina', 0.01015405),
#   ('sbsec', 0.009551169),
#   ('micronutrient', 0.008816195),
#   ('infant', 0.008681929),
#   ('africa', 0.008670301),
#   ('status', 0.00815942),
#   ('ida', 0.008043197),
#   ('absorption', 0.0077404957),
#   ('anemia', 0.007614833)],
#  [('argo', 0.021414852),
#   ('swelling', 0.018737176),
#   ('foam', 0.018523391),
#   ('epos', 0.018202823),
#   ('oxygen', 0.016881714),
#   ('dna', 0.01625821),
#   ('native', 0.01517343),
#   ('dp', 0.015029306),
#   ('bone', 0.013279468),
#   ('starch', 0.013190994),
#   ('pore', 0.012450645),
#   ('anhydrite', 0.012352571),
#   ('bla', 0.011778762),
#   ('granule', 0.011776951),
#   ('ruminant', 0.011191829),
#   ('membrane', 0.010928353),
#   ('gelatin', 0.010775392),
#   ('float', 0.010708084)],
#  [('forecast', 0.07364414),
#   ('vr', 0.04201332),
#   ('forecasting', 0.03572852),
#   ('rp', 0.027185302),
#   ('exergames', 0.02621784),
#   ('virtual', 0.019109495),
#   ('cv', 0.017653268),
#   ('skill', 0.015399445)],
#  [('plant', 0.06964575),
#   ('root', 0.034842025),
#   ('leaf', 0.026809895),
#   ('growth', 0.026762672),
#   ('flower', 0.014224062),
#   ('pollinator', 0.013469916),
#   ('specie', 0.011971422),
#   ('tree', 0.010666233),
#   ('drought', 0.00935105),
#   ('shoot', 0.009177636),
#   ('herbivore', 0.009007044),
#   ('stress', 0.008412501),
#   ('trait', 0.00816224)],
#  [('cell', 0.030898007),
#   ('protein', 0.010259851),
#   ('expression', 0.007841965),
#   ('signaling', 0.0072582453),
#   ('pathway', 0.006583497),
#   ('growth', 0.0064507187),
#   ('cellular', 0.0063217725),
#   ('receptor', 0.0059428494),
#   ('mouse', 0.005598573),
#   ('metabolic', 0.0054617464),
#   ('gene', 0.005027144),
#   ('mutant', 0.0046327757),
#   ('activation', 0.0046207462),
#   ('activity', 0.0045383004),
#   ('extracellular', 0.0044950545),
#   ('mediated', 0.0044817035),
#   ('kinase', 0.0043125497),
#   ('glucose', 0.0040724506),
#   ('mechanism', 0.0040595257),
#   ('insulin', 0.0040161223),
#   ('stress', 0.0038546184),
#   ('role', 0.0038242135),
#   ('factor', 0.0038082306),
#   ('membrane', 0.0037798502),
#   ('induced', 0.0037201361),
#   ('dependent', 0.003713561),
#   ('differentiation', 0.0036633862),
#   ('intracellular', 0.0035663398),
#   ('metabolism', 0.0035283407),
#   ('proliferation', 0.0034716392),
#   ('tissue', 0.003350686),
#   ('function', 0.003341916),
#   ('adhesion', 0.0033096531),
#   ('inhibition', 0.0032699471),
#   ('enzyme', 0.0031909726),
#   ('mutation', 0.0031506717),
#   ('regulator', 0.0030458164),
#   ('human', 0.0030213133),
#   ('stem', 0.0029484986),
#   ('response', 0.0029441381),
#   ('upon', 0.0028516338),
#   ('regulation', 0.002831696),
#   ('aging', 0.0027670804),
#   ('complex', 0.0027153413),
#   ('specific', 0.0026981141),
#   ('homeostasis', 0.0026935604),
#   ('mitochondrial', 0.0026921195),
#   ('formation', 0.0026888156),
#   ('regulated', 0.0026658801),
#   ('drosophila', 0.0026637546),
#   ('type', 0.0026618792),
#   ('phosphorylation', 0.0026019549),
#   ('phenotype', 0.0025998494),
#   ('molecule', 0.0025561347),
#   ('secretion', 0.002540999),
#   ('mammalian', 0.002539427),
#   ('target', 0.002527414)],
#  [('fracture', 0.041799534),
#   ('rock', 0.031186251),
#   ('injection', 0.016900476),
#   ('donation', 0.016166765),
#   ('stress', 0.014436824),
#   ('sliding', 0.014264409),
#   ('fractured', 0.012958882),
#   ('oscillation', 0.011997405),
#   ('overshoot', 0.0119485175),
#   ('fkh', 0.010959149),
#   ('pressure', 0.010873805),
#   ('tunnel', 0.010734296),
#   ('odor', 0.0097083645),
#   ('dot', 0.00960448),
#   ('opening', 0.009524735),
#   ('shear', 0.009226225),
#   ('pin', 0.008918061)],
#  [('logic', 0.028142005),
#   ('pha', 0.021355715),
#   ('verification', 0.020513693),
#   ('program', 0.018717995),
#   ('disc', 0.017541897),
#   ('telescope', 0.015173609),
#   ('genipin', 0.014353719),
#   ('semantics', 0.013931754),
#   ('cherenkov', 0.013899373),
#   ('dune', 0.0132269515),
#   ('cul', 0.0117300525),
#   ('pur', 0.0117300525),
#   ('apd', 0.011704908),
#   ('jml', 0.011483192),
#   ('agn', 0.009915737),
#   ('binary', 0.00920517),
#   ('kt', 0.008625779)],
#  [('travel', 0.027640084),
#   ('choice', 0.025851298),
#   ('car', 0.018710786),
#   ('transport', 0.016411414),
#   ('survey', 0.01613018),
#   ('trip', 0.014334118),
#   ('mobility', 0.013001814),
#   ('mode', 0.012379556),
#   ('demand', 0.011463443),
#   ('transportation', 0.010385708),
#   ('household', 0.009835979),
#   ('public', 0.009603619),
#   ('location', 0.00947397),
#   ('activity', 0.0092739295),
#   ('service', 0.008949435),
#   ('respondent', 0.008758441),
#   ('vehicle', 0.008426438),
#   ('distance', 0.0084128715),
#   ('sharing', 0.008383001),
#   ('accessibility', 0.007894314)],
#  [('robot', 0.05248838),
#   ('motion', 0.021639451),
#   ('mc', 0.021380043),
#   ('soft', 0.019754546),
#   ('arm', 0.01962145),
#   ('force', 0.01478442),
#   ('processor', 0.013615417),
#   ('robotic', 0.013615123),
#   ('controller', 0.013324673),
#   ('actuator', 0.012914201),
#   ('actuation', 0.0115758125),
#   ('body', 0.010677858),
#   ('parallel', 0.009567357),
#   ('museum', 0.008195659),
#   ('dynamic', 0.008100623)],
#  [('coral', 0.02726921),
#   ('carbonate', 0.01651397),
#   ('age', 0.016023694),
#   ('zn', 0.014672178),
#   ('reef', 0.014240663),
#   ('fish', 0.0138631845),
#   ('holocene', 0.0136094885),
#   ('th', 0.013315487),
#   ('ka', 0.012771064),
#   ('cave', 0.011488513),
#   ('dating', 0.011445643),
#   ('pa', 0.011410786),
#   ('wastewater', 0.010499069),
#   ('bp', 0.009431133),
#   ('coastal', 0.009409642),
#   ('radiocarbon', 0.009174734),
#   ('edc', 0.0088548055),
#   ('sediment', 0.008844749),
#   ('calcification', 0.008616557),
#   ('anammox', 0.008301423),
#   ('archaeological', 0.0076699494)],
#  [('hm', 0.022725957),
#   ('thread', 0.02078758),
#   ('crime', 0.020688409),
#   ('object', 0.019721914),
#   ('box', 0.018801562),
#   ('census', 0.017762799),
#   ('ownership', 0.01682159),
#   ('type', 0.013485756),
#   ('svg', 0.012986859),
#   ('typing', 0.012791674),
#   ('sampler', 0.012529057),
#   ('black', 0.011973837),
#   ('sat', 0.011339317),
#   ('job', 0.010996017),
#   ('business', 0.010970864),
#   ('soldier', 0.010837453),
#   ('cnf', 0.010837453)],
#  [('ice', 0.05667183),
#   ('cloud', 0.042749874),
#   ('particle', 0.034188956),
#   ('aerosol', 0.03212777),
#   ('nucleation', 0.031478126),
#   ('dust', 0.021804428),
#   ('droplet', 0.021356799),
#   ('freezing', 0.018102441)],
#  [('isotope', 0.02223489),
#   ('ecm', 0.01897708),
#   ('aot', 0.01725981),
#   ('vesicle', 0.016074937),
#   ('meteorite', 0.015533953),
#   ('ce', 0.01518191),
#   ('pani', 0.014220063),
#   ('diamond', 0.0135115655),
#   ('cholesterol', 0.013505664),
#   ('outgrowth', 0.012082236),
#   ('gcr', 0.011972909),
#   ('iab', 0.011865638),
#   ('tspo', 0.010975269),
#   ('gsr', 0.010975269),
#   ('piglet', 0.010428374),
#   ('neurite', 0.010356378),
#   ('aminoglycoside', 0.010040344),
#   ('btuf', 0.0099776285),
#   ('cobinamide', 0.009744927)],
#  [('glacier', 0.02754638),
#   ('ice', 0.021205083),
#   ('catchment', 0.02092241),
#   ('snow', 0.015699275),
#   ('rainfall', 0.014148761),
#   ('discharge', 0.013579737),
#   ('soil', 0.013472015),
#   ('precipitation', 0.011136616),
#   ('runoff', 0.0110228285),
#   ('surface', 0.010249212),
#   ('water', 0.009682731),
#   ('river', 0.00934839),
#   ('hydrological', 0.009276614),
#   ('topography', 0.009197198),
#   ('landslide', 0.008253583),
#   ('basin', 0.0075506773),
#   ('erosion', 0.007482644),
#   ('area', 0.00732489),
#   ('elevation', 0.0071133235),
#   ('alp', 0.007099142),
#   ('sediment', 0.007060961),
#   ('balance', 0.0069383327)],
#  [('virus', 0.03963164),
#   ('resistance', 0.03538604),
#   ('antibiotic', 0.034918472),
#   ('infection', 0.03035775),
#   ('viral', 0.027534919),
#   ('hiv', 0.025564795),
#   ('cd', 0.021897106),
#   ('cell', 0.021486785),
#   ('resistant', 0.014931482)],
#  [('quantum', 0.022603134),
#   ('spin', 0.015974663),
#   ('magnetic', 0.011509529),
#   ('state', 0.011072318),
#   ('field', 0.009058357),
#   ('electron', 0.008748183),
#   ('phase', 0.0070268027),
#   ('electronic', 0.006601141),
#   ('charge', 0.006480336),
#   ('density', 0.006374265),
#   ('temperature', 0.006215056),
#   ('energy', 0.006142838),
#   ('topological', 0.005932382),
#   ('transition', 0.0058712903),
#   ('lattice', 0.0058080233),
#   ('gate', 0.0055057807),
#   ('superconducting', 0.0055004144),
#   ('coupling', 0.0052637625),
#   ('theory', 0.005119246),
#   ('chiral', 0.004961209),
#   ('ion', 0.0049188533),
#   ('mode', 0.004909121),
#   ('polarization', 0.0048844153),
#   ('neutron', 0.0046612397),
#   ('dot', 0.0046376646),
#   ('excitation', 0.0044184458),
#   ('interaction', 0.0043679434),
#   ('band', 0.004148797),
#   ('dimensional', 0.004144034),
#   ('qubits', 0.004109612),
#   ('symmetry', 0.0040931874),
#   ('hole', 0.00408447),
#   ('molecule', 0.003974197),
#   ('fermi', 0.0038827283),
#   ('atom', 0.0037562184),
#   ('observe', 0.0037339272),
#   ('regime', 0.003707761),
#   ('atomic', 0.003572998),
#   ('wave', 0.0035256036),
#   ('hall', 0.0035181532),
#   ('material', 0.0035112815),
#   ('entanglement', 0.0034593234)],
#  [('gnss', 0.023311695),
#   ('camera', 0.020277767),
#   ('satellite', 0.019531647),
#   ('positioning', 0.018101335),
#   ('flight', 0.016705176),
#   ('trajectory', 0.014478549),
#   ('scanner', 0.014065071),
#   ('orbit', 0.013589848),
#   ('map', 0.012898134),
#   ('daoa', 0.0121978475),
#   ('dao', 0.0121978475),
#   ('position', 0.0118778),
#   ('antenna', 0.010675501),
#   ('laser', 0.010514918),
#   ('plato', 0.010455439),
#   ('character', 0.01031828),
#   ('angle', 0.009693879),
#   ('outlier', 0.009551868)],
#  [('theory', 0.022004114),
#   ('loop', 0.01626455),
#   ('symmetry', 0.014941761),
#   ('algebra', 0.014380875),
#   ('spin', 0.010823465),
#   ('string', 0.009914669),
#   ('gravity', 0.009055194),
#   ('amplitude', 0.0086583495),
#   ('ad', 0.008315439),
#   ('dimension', 0.008234361),
#   ('limit', 0.008151418),
#   ('tensor', 0.008093036),
#   ('integral', 0.007899995),
#   ('expansion', 0.007826491),
#   ('quantum', 0.0076283496),
#   ('entropy', 0.0075992923),
#   ('gauge', 0.0068231313),
#   ('yang', 0.006771141),
#   ('dual', 0.0063539827),
#   ('cft', 0.0057845567),
#   ('conformal', 0.0057845567),
#   ('gluon', 0.0057119885),
#   ('cfts', 0.0056940867),
#   ('relation', 0.005567417),
#   ('charge', 0.005554562),
#   ('mill', 0.0055244104),
#   ('term', 0.00539181),
#   ('coupling', 0.0053658024),
#   ('orbifold', 0.005314513),
#   ('field', 0.0052546463)],
#  [('fn', 0.03518277),
#   ('ec', 0.03358509),
#   ('bell', 0.032098588),
#   ('exposure', 0.023230234),
#   ('tsc', 0.020874308),
#   ('fibril', 0.01779334),
#   ('pup', 0.016968073),
#   ('hbm', 0.01614959),
#   ('muscat', 0.012919916),
#   ('sha', 0.0128977625),
#   ('dbf', 0.0128977625),
#   ('cow', 0.012689381),
#   ('urine', 0.012311459)],
#  [('different', 0.003812962),
#   ('type', 0.003293999),
#   ('may', 0.0032361909),
#   ('change', 0.0032140797),
#   ('time', 0.0030467757),
#   ('analysis', 0.0029372154),
#   ('potential', 0.0028870387),
#   ('however', 0.0027587581),
#   ('understanding', 0.002692579),
#   ('effect', 0.0025629308),
#   ('important', 0.0024350532),
#   ('well', 0.00240494),
#   ('recent', 0.0023947833),
#   ('provide', 0.0023759918),
#   ('could', 0.0023582818),
#   ('significant', 0.0023338895),
#   ('impact', 0.0023215944),
#   ('one', 0.0022880954),
#   ('related', 0.0022721773),
#   ('interaction', 0.0022674212),
#   ('finding', 0.0022628868),
#   ('environment', 0.0021096822),
#   ('influence', 0.0020984185),
#   ('pattern', 0.0020905356),
#   ('increasing', 0.0020889963),
#   ('new', 0.0020751406),
#   ('thus', 0.0020636944),
#   ('process', 0.0020534194),
#   ('difference', 0.0020489062),
#   ('development', 0.0020421238),
#   ('within', 0.0020399888),
#   ('evidence', 0.002031217),
#   ('used', 0.002015501),
#   ('future', 0.002004127),
#   ('increase', 0.0020011528),
#   ('level', 0.0019851082),
#   ('condition', 0.0019839276),
#   ('including', 0.0019815643),
#   ('importance', 0.0019756274),
#   ('mechanism', 0.0019544726),
#   ('research', 0.001954327),
#   ('first', 0.0019284434),
#   ('two', 0.0019136245),
#   ('found', 0.00190592),
#   ('four', 0.0019056011),
#   ('three', 0.001855198),
#   ('even', 0.0018393345),
#   ('many', 0.001820205),
#   ('since', 0.001819155),
#   ('role', 0.0018069401),
#   ('limited', 0.0017933801),
#   ('part', 0.0017255567),
#   ('main', 0.0017243467),
#   ('non', 0.0017220115),
#   ('major', 0.0017057715),
#   ('despite', 0.0017043919),
#   ('characteristic', 0.0016982891),
#   ('highly', 0.0016965218),
#   ('yet', 0.0016901223),
#   ('particular', 0.0016852608),
#   ('behavior', 0.0016723587),
#   ('show', 0.0016662132),
#   ('insight', 0.0016609405),
#   ('use', 0.0016574648),
#   ('contrast', 0.0016499971),
#   ('would', 0.001631994),
#   ('high', 0.00163133),
#   ('year', 0.0015815521),
#   ('still', 0.0015794437),
#   ('need', 0.0015763179),
#   ('current', 0.0015740414),
#   ('present', 0.001573292),
#   ('strongly', 0.0015645921),
#   ('better', 0.0015509018),
#   ('knowledge', 0.001548144),
#   ('several', 0.0015376447),
#   ('observed', 0.001537626),
#   ('strategy', 0.0015351934),
#   ('individual', 0.001514198),
#   ('higher', 0.001513881),
#   ('large', 0.001510763),
#   ('known', 0.0015000073),
#   ('investigate', 0.0014956731),
#   ('help', 0.0014948769),
#   ('common', 0.0014937285),
#   ('focus', 0.001492298),
#   ('system', 0.0014900017),
#   ('specific', 0.0014892657),
#   ('possible', 0.0014873864),
#   ('affect', 0.0014836807),
#   ('therefore', 0.00148255),
#   ('across', 0.0014758917),
#   ('due', 0.0014756566),
#   ('long', 0.0014707737),
#   ('support', 0.0014588111),
#   ('furthermore', 0.0014569638),
#   ('whether', 0.0014561221),
#   ('amount', 0.001452596),
#   ('report', 0.0014480447),
#   ('small', 0.0014445585),
#   ('understand', 0.0014407824),
#   ('identify', 0.0014364814),
#   ('le', 0.0014326936),
#   ('considered', 0.0014282684),
#   ('become', 0.0014232267),
#   ('mainly', 0.0014193148),
#   ('question', 0.0014187347),
#   ('suggest', 0.0014060856),
#   ('assessment', 0.0013994253),
#   ('significantly', 0.0013990995),
#   ('lead', 0.001389537),
#   ('relationship', 0.0013864561),
#   ('ass', 0.0013864406),
#   ('address', 0.0013761673),
#   ('might', 0.0013753),
#   ('various', 0.0013709093),
#   ('highlight', 0.0013677262),
#   ('reported', 0.0013610827),
#   ('represent', 0.001343598),
#   ('investigated', 0.0013428666),
#   ('target', 0.0013374563),
#   ('positive', 0.0013351756),
#   ('remains', 0.0013308725),
#   ('transition', 0.0013308071),
#   ('review', 0.0013268756),
#   ('little', 0.0013240313),
#   ('developed', 0.0013223037),
#   ('crucial', 0.0013186083),
#   ('area', 0.0013082499),
#   ('consistent', 0.0012994716),
#   ('aspect', 0.0012977032),
#   ('addition', 0.0012907606),
#   ('potentially', 0.0012905861),
#   ('number', 0.0012887827),
#   ('point', 0.0012848966),
#   ('information', 0.0012844363),
#   ('five', 0.0012833748),
#   ('often', 0.0012793873),
#   ('context', 0.0012791309),
#   ('form', 0.0012745848),
#   ('although', 0.0012739645),
#   ('explain', 0.0012727297),
#   ('dynamic', 0.0012568306),
#   ('together', 0.0012559098)],
#  [('aerosol', 0.03404351),
#   ('galaxy', 0.026290163),
#   ('bc', 0.024743725),
#   ('pm', 0.02382005),
#   ('organic', 0.01831593),
#   ('oa', 0.0175848),
#   ('am', 0.01616606),
#   ('mass', 0.014729546),
#   ('cluster', 0.014672524),
#   ('fire', 0.012800938),
#   ('emission', 0.012605448),
#   ('burning', 0.012152713),
#   ('particle', 0.01169049),
#   ('redshift', 0.011564813)],
#  [('forest', 0.03245783),
#   ('specie', 0.029400678),
#   ('soil', 0.020054808),
#   ('climate', 0.018225271),
#   ('ecosystem', 0.01791019),
#   ('land', 0.01613149),
#   ('tree', 0.014983654),
#   ('drought', 0.014318176),
#   ('biodiversity', 0.013790866),
#   ('habitat', 0.01237114),
#   ('vegetation', 0.011732644),
#   ('change', 0.011376125),
#   ('water', 0.011284928),
#   ('plant', 0.010677143),
#   ('community', 0.008147606),
#   ('richness', 0.008076694)],
#  [('vaccine', 0.03095538),
#   ('antibody', 0.027907962),
#   ('hg', 0.02547161),
#   ('vaccination', 0.020355951),
#   ('epitope', 0.017432071),
#   ('igg', 0.016493011),
#   ('gc', 0.015821483),
#   ('pylorus', 0.014747111),
#   ('lem', 0.013406549),
#   ('antigen', 0.012408831),
#   ('taspase', 0.011476732),
#   ('gi', 0.010572989),
#   ('ig', 0.010055144),
#   ('earthworm', 0.009017632),
#   ('human', 0.00897318),
#   ('mmr', 0.008309767)],
#  [('mirnas', 0.034145094),
#   ('mirna', 0.025064839),
#   ('classification', 0.023871187),
#   ('learning', 0.02351384),
#   ('machine', 0.022957463),
#   ('embryo', 0.021528237),
#   ('classifier', 0.018904284),
#   ('outlier', 0.016131116),
#   ('neural', 0.015563427),
#   ('clock', 0.01301484),
#   ('training', 0.011986097),
#   ('accuracy', 0.0119547825),
#   ('alkane', 0.0108980965),
#   ('network', 0.010866088)],
#  [('ocean', 0.023118751),
#   ('carbon', 0.019815695),
#   ('sea', 0.011635102),
#   ('isotope', 0.009986977),
#   ('marine', 0.009543159),
#   ('organic', 0.009028767),
#   ('sediment', 0.0086892815),
#   ('isotopic', 0.008549149),
#   ('water', 0.0080958875),
#   ('emission', 0.0076489164),
#   ('co', 0.0072598886),
#   ('southern', 0.007120575),
#   ('anthropogenic', 0.006833156),
#   ('global', 0.006440845),
#   ('south', 0.006367684),
#   ('record', 0.00612261),
#   ('climate', 0.0060430774),
#   ('source', 0.0059625255),
#   ('concentration', 0.0058989157),
#   ('north', 0.005894606),
#   ('arctic', 0.005891524),
#   ('cycle', 0.0058282516),
#   ('oc', 0.0058190436),
#   ('flux', 0.005471925),
#   ('pacific', 0.0053988467),
#   ('phytoplankton', 0.005116988),
#   ('glacial', 0.0049570184),
#   ('temperature', 0.004902932),
#   ('atlantic', 0.004680342),
#   ('variability', 0.004663691),
#   ('proxy', 0.004416093),
#   ('biogeochemical', 0.004382607),
#   ('surface', 0.0043748436),
#   ('atmospheric', 0.004102454)],
#  [('indicator', 0.02492739),
#   ('disaster', 0.024227545),
#   ('adaptation', 0.023222595),
#   ('business', 0.02225033),
#   ('resilience', 0.020533813),
#   ('euro', 0.018914387),
#   ('pearl', 0.017424649),
#   ('sib', 0.013736864),
#   ('sif', 0.012706081),
#   ('vulnerability', 0.012660679),
#   ('product', 0.012306889),
#   ('sustainability', 0.01196643),
#   ('compliance', 0.01186429),
#   ('supply', 0.01174355),
#   ('ints', 0.011281714),
#   ('footprint', 0.010856411)],
#  [('gene', 0.049381193),
#   ('rna', 0.031711478),
#   ('expression', 0.020089122),
#   ('protein', 0.013597999),
#   ('dna', 0.011897493),
#   ('transcriptional', 0.010232731),
#   ('sequencing', 0.009940132),
#   ('genome', 0.009816696),
#   ('transcript', 0.009483634),
#   ('transcriptome', 0.008930887),
#   ('transcription', 0.008829325),
#   ('promoter', 0.0077556428),
#   ('seq', 0.007606501),
#   ('mrna', 0.007570351),
#   ('methylation', 0.0066623953),
#   ('chromatin', 0.0066623953),
#   ('read', 0.0066075837),
#   ('regulation', 0.0064019975),
#   ('sequence', 0.0063618165),
#   ('conserved', 0.0061458624),
#   ('splicing', 0.006128025)],
#  [('network', 0.038901065),
#   ('node', 0.026923668),
#   ('social', 0.026242983),
#   ('http', 0.025769824),
#   ('emotion', 0.019842116),
#   ('emotional', 0.019430881),
#   ('org', 0.015576212),
#   ('database', 0.014986854),
#   ('alliance', 0.014941907),
#   ('valence', 0.014071426),
#   ('centrality', 0.013086339),
#   ('graph', 0.012731867),
#   ('online', 0.012664643)],
#  [('soil', 0.029324234),
#   ('microbial', 0.024081297),
#   ('strain', 0.017576907),
#   ('bacteria', 0.017045103),
#   ('community', 0.015881361),
#   ('microbiota', 0.015385157),
#   ('bacterial', 0.014561539),
#   ('gut', 0.009715415),
#   ('food', 0.008480017),
#   ('nutrient', 0.008255677),
#   ('fermentation', 0.007649192),
#   ('composition', 0.007279973),
#   ('microorganism', 0.0071899337),
#   ('acid', 0.0070544565),
#   ('microbe', 0.0070240553),
#   ('metabolic', 0.006926238),
#   ('abundance', 0.0061048334),
#   ('production', 0.006065165),
#   ('organic', 0.005675271),
#   ('culture', 0.005649351),
#   ('carbon', 0.005466124),
#   ('colonization', 0.0054155686),
#   ('spp', 0.005273046),
#   ('rrna', 0.005195763),
#   ('specie', 0.0051170704)],
#  [('parking', 0.050953362),
#   ('engine', 0.027822087),
#   ('fuel', 0.027268639),
#   ('combustion', 0.026478842),
#   ('nurse', 0.021311266),
#   ('ev', 0.021187134),
#   ('ace', 0.020352924),
#   ('controller', 0.018929621),
#   ('vehicle', 0.017283237),
#   ('diesel', 0.016565857),
#   ('cc', 0.014874978)],
#  [('material', 0.017611021),
#   ('strain', 0.016899861),
#   ('mechanical', 0.016083492),
#   ('force', 0.014037949),
#   ('concrete', 0.013888365),
#   ('stress', 0.012721062),
#   ('load', 0.012187029),
#   ('specimen', 0.0119588),
#   ('deformation', 0.011834403),
#   ('adhesive', 0.011680217),
#   ('crack', 0.011129186),
#   ('fracture', 0.010977635),
#   ('fibre', 0.010793763),
#   ('test', 0.010736148),
#   ('strength', 0.010705683),
#   ('wood', 0.009562916),
#   ('timber', 0.00949649),
#   ('shear', 0.008580251),
#   ('structural', 0.008238492),
#   ('steel', 0.008033165),
#   ('structure', 0.007988334),
#   ('geometry', 0.00791093)],
#  [('game', 0.067844056),
#   ('et', 0.052166473),
#   ('al', 0.040406205),
#   ('agent', 0.03416342),
#   ('player', 0.02742823),
#   ('equilibrium', 0.020650009),
#   ('reviewer', 0.016758246)],
#  [('mineral', 0.02070857),
#   ('ray', 0.018131198),
#   ('spectrum', 0.015440283),
#   ('clay', 0.014042276),
#   ('peak', 0.013778211),
#   ('laser', 0.012174794),
#   ('spectral', 0.01010489),
#   ('absorption', 0.0097682215),
#   ('solar', 0.009655865),
#   ('light', 0.009462419),
#   ('infrared', 0.009365551),
#   ('emission', 0.009016617),
#   ('wavelength', 0.009001477),
#   ('nm', 0.008679551),
#   ('radio', 0.008642889),
#   ('sample', 0.008624969),
#   ('element', 0.007616761),
#   ('diffuse', 0.0075361244),
#   ('reflectance', 0.0068384907),
#   ('imprecision', 0.0067499997),
#   ('pulse', 0.0066251373),
#   ('lyman', 0.006554446),
#   ('earth', 0.0064322413),
#   ('resolution', 0.0064081047),
#   ('dissolution', 0.006358826),
#   ('spectroscopy', 0.0062151533)],
#  [('image', 0.033109374),
#   ('sensor', 0.022477038),
#   ('imaging', 0.010263593),
#   ('camera', 0.009557843),
#   ('resolution', 0.009357285),
#   ('pixel', 0.009207529),
#   ('object', 0.008833073),
#   ('reconstruction', 0.00867499),
#   ('detection', 0.008410691),
#   ('noise', 0.007985416),
#   ('signal', 0.0078219585),
#   ('processing', 0.007692518),
#   ('channel', 0.007329975),
#   ('segmentation', 0.0062760655),
#   ('monitoring', 0.006155293),
#   ('filter', 0.0059409225),
#   ('wireless', 0.005925682),
#   ('digital', 0.0055747093),
#   ('accuracy', 0.0052292394),
#   ('localization', 0.005228579),
#   ('tracking', 0.005197509),
#   ('video', 0.005192585),
#   ('algorithm', 0.0051195053),
#   ('device', 0.0050244937),
#   ('real', 0.0050122757),
#   ('acquisition', 0.0049793054),
#   ('vision', 0.0049193674),
#   ('high', 0.004907147),
#   ('aerial', 0.0047609545),
#   ('quality', 0.004708119),
#   ('scene', 0.004670536),
#   ('measurement', 0.004657511)],
#  [('graph', 0.049285326),
#   ('bound', 0.029510548),
#   ('algorithm', 0.025502479),
#   ('log', 0.023324048),
#   ('edge', 0.02159324),
#   ('vertex', 0.019912075),
#   ('problem', 0.015333041),
#   ('cut', 0.014626013),
#   ('minimum', 0.012157757),
#   ('complexity', 0.011754301),
#   ('upper', 0.009498794),
#   ('lower', 0.008807891),
#   ('number', 0.008673603),
#   ('node', 0.008456917)],
#  [('mhc', 0.026535336),
#   ('morphing', 0.02283982),
#   ('acetylation', 0.021801714),
#   ('valve', 0.021010395),
#   ('histone', 0.019356595),
#   ('usu', 0.014648854),
#   ('ptms', 0.014594053),
#   ('nose', 0.014156559),
#   ('drb', 0.013498949),
#   ('xylose', 0.013498949),
#   ('smbh', 0.013317278),
#   ('gara', 0.013317278),
#   ('crithidia', 0.0128263),
#   ('skin', 0.0124590825),
#   ('bombi', 0.012349046),
#   ('abdg', 0.012271909)],
#  [('material', 0.011247095),
#   ('polymer', 0.010679281),
#   ('nanoparticles', 0.0092278505),
#   ('laser', 0.00847972),
#   ('device', 0.008318177),
#   ('optical', 0.008245723),
#   ('film', 0.008056431),
#   ('nm', 0.00790034),
#   ('surface', 0.0069704927),
#   ('light', 0.0064348313),
#   ('layer', 0.006321828),
#   ('metal', 0.005630397),
#   ('fabrication', 0.0053987913),
#   ('property', 0.005367004),
#   ('plasmonic', 0.0052347635),
#   ('printing', 0.0049359896),
#   ('np', 0.004907652),
#   ('silicon', 0.00456874),
#   ('application', 0.0044755666),
#   ('spectroscopy', 0.0044227564),
#   ('substrate', 0.0043323366),
#   ('nanoparticle', 0.0041852714),
#   ('coating', 0.003949072),
#   ('thin', 0.003893129),
#   ('waveguide', 0.0038831134),
#   ('microscopy', 0.003856066),
#   ('crystal', 0.0037908154),
#   ('nanoscale', 0.0036992894),
#   ('nano', 0.0036584751),
#   ('deposition', 0.0036367043),
#   ('structure', 0.003618605),
#   ('gold', 0.0035834103),
#   ('thz', 0.0035423022),
#   ('infrared', 0.0035103026),
#   ('electron', 0.0034877127),
#   ('optic', 0.0033703991),
#   ('au', 0.0033482506),
#   ('wavelength', 0.00333003),
#   ('absorption', 0.0033241),
#   ('dielectric', 0.0032839323),
#   ('manufacturing', 0.0032757618),
#   ('oxide', 0.003263325),
#   ('chemical', 0.0032043827),
#   ('high', 0.0031232454),
#   ('bulk', 0.0031087105),
#   ('semiconductor', 0.0030505606),
#   ('single', 0.0030387416),
#   ('graphene', 0.0030341211),
#   ('interface', 0.0030037884),
#   ('colloidal', 0.0029864083),
#   ('array', 0.0029603096),
#   ('platform', 0.0029135454),
#   ('low', 0.0028895873),
#   ('cnt', 0.002857717)],
#  [('fluid', 0.040901005),
#   ('flow', 0.03992115),
#   ('viscosity', 0.026221609),
#   ('geothermal', 0.025382014),
#   ('gnp', 0.01302046),
#   ('cfd', 0.012589317),
#   ('plate', 0.011664009),
#   ('velocity', 0.01123505),
#   ('wall', 0.011053675),
#   ('stokes', 0.0108620925),
#   ('runtime', 0.010763213),
#   ('supercritical', 0.010458087),
#   ('egs', 0.010209841),
#   ('lame', 0.010092921),
#   ('particle', 0.009774935)],
#  [('seismic', 0.05317285),
#   ('earthquake', 0.045628008),
#   ('fault', 0.023646839),
#   ('seismicity', 0.020143937),
#   ('rock', 0.015446461),
#   ('clove', 0.011140377),
#   ('station', 0.010721196),
#   ('rupture', 0.010459671),
#   ('inversion', 0.010285912),
#   ('wave', 0.010090937),
#   ('motion', 0.010087201),
#   ('hazard', 0.010002976),
#   ('slip', 0.009568122),
#   ('velocity', 0.009398894),
#   ('borehole', 0.009269081)],
#  [('security', 0.02159211),
#   ('protocol', 0.01883423),
#   ('user', 0.018721996),
#   ('attack', 0.016790979),
#   ('privacy', 0.012598832),
#   ('device', 0.012353702),
#   ('application', 0.012027493),
#   ('access', 0.011846719),
#   ('service', 0.010865183),
#   ('message', 0.010336486),
#   ('fault', 0.009070325),
#   ('communication', 0.00905409),
#   ('server', 0.008721362),
#   ('distributed', 0.008628571),
#   ('memory', 0.0084885135),
#   ('secure', 0.007960283),
#   ('proof', 0.007734548),
#   ('channel', 0.007300275),
#   ('code', 0.006875597),
#   ('adversary', 0.006802173),
#   ('quantum', 0.0064109196),
#   ('smart', 0.006294085),
#   ('key', 0.006180408),
#   ('update', 0.006128764)],
#  [('firm', 0.07496593),
#   ('innovation', 0.039511494),
#   ('ict', 0.025479285),
#   ('sn', 0.018241545),
#   ('investment', 0.017368006),
#   ('market', 0.01722768),
#   ('foreign', 0.015797641),
#   ('technology', 0.014268504),
#   ('capital', 0.011289043),
#   ('green', 0.011173596),
#   ('productivity', 0.010902497)],
#  [('wall', 0.04442521),
#   ('sa', 0.024573624),
#   ('di', 0.023097957),
#   ('gmp', 0.018035676),
#   ('sars', 0.017003635),
#   ('legged', 0.016769743),
#   ('nt', 0.01574756),
#   ('domain', 0.015109971),
#   ('cov', 0.014169924),
#   ('rubber', 0.013792312),
#   ('ifn', 0.013521504),
#   ('terrain', 0.013276556),
#   ('covid', 0.01323956),
#   ('pandemic', 0.012743158)],
#  [('flux', 0.042958084),
#   ('co', 0.03169843),
#   ('yr', 0.018637124),
#   ('ch', 0.017336652),
#   ('carbon', 0.015486954),
#   ('eddy', 0.012953765),
#   ('emission', 0.012126816),
#   ('variability', 0.011649488),
#   ('pg', 0.011172503),
#   ('canopy', 0.010541348),
#   ('covariance', 0.0102483025),
#   ('cb', 0.009977018),
#   ('ecosystem', 0.009609373),
#   ('gpp', 0.009460065),
#   ('uptake', 0.008945387),
#   ('estimate', 0.00864168),
#   ('site', 0.008625152)],
#  [('reaction', 0.026599342),
#   ('catalyst', 0.016930673),
#   ('oxidation', 0.010901564),
#   ('ph', 0.010346495),
#   ('co', 0.009569291),
#   ('chemical', 0.008721846),
#   ('oxygen', 0.008146426),
#   ('water', 0.0075371712),
#   ('acid', 0.007049536),
#   ('metal', 0.006978587),
#   ('product', 0.0067366334),
#   ('radical', 0.006690754),
#   ('concentration', 0.0065502194),
#   ('hydrogen', 0.00650685),
#   ('tio', 0.0059976922),
#   ('synthesis', 0.0059248735),
#   ('catalytic', 0.0058931285),
#   ('redox', 0.0057830154),
#   ('graphite', 0.0057728),
#   ('surface', 0.005704291),
#   ('reduction', 0.0055279476),
#   ('formation', 0.005518267),
#   ('salt', 0.005462682),
#   ('compound', 0.0053242357),
#   ('active', 0.005098344),
#   ('mgo', 0.0049927547),
#   ('electrochemical', 0.0049183285),
#   ('solvent', 0.004835469),
#   ('stability', 0.0048040976),
#   ('carbon', 0.004776838),
#   ('specie', 0.004760289),
#   ('electrolyte', 0.0046402593),
#   ('aqueous', 0.0045875097),
#   ('mo', 0.0045045097),
#   ('cation', 0.004473961),
#   ('fe', 0.0044583436)],
#  [('lectin', 0.026559813),
#   ('sentiment', 0.022857862),
#   ('gfp', 0.018520374),
#   ('h', 0.017678596),
#   ('wedge', 0.016279086),
#   ('tcp', 0.014719577),
#   ('psf', 0.0145698935),
#   ('intestinal', 0.013697259),
#   ('calcite', 0.013518025),
#   ('gland', 0.010770524),
#   ('thickness', 0.010608502),
#   ('ccl', 0.010281996),
#   ('negation', 0.010087241),
#   ('apical', 0.010081483),
#   ('uninfected', 0.0098134745),
#   ('ruderal', 0.0098134745),
#   ('successional', 0.0098134745),
#   ('hpc', 0.0091651),
#   ('inoculation', 0.008980645)],
#  [('fur', 0.023920635),
#   ('russia', 0.017766792),
#   ('fyw', 0.016863845),
#   ('buchen', 0.011413825),
#   ('wurde', 0.011277082),
#   ('russian', 0.01093575),
#   ('uber', 0.009002682),
#   ('fichten', 0.008560571),
#   ('untersucht', 0.00779462),
#   ('secondly', 0.0075128255),
#   ('wurden', 0.007230153),
#   ('teil', 0.0068234964),
#   ('firstly', 0.0067816237),
#   ('schweiz', 0.006117946),
#   ('hohe', 0.006013957),
#   ('eaeu', 0.005916636),
#   ('edition', 0.005893195),
#   ('ketten', 0.0057073175),
#   ('verpflanzten', 0.0057073175),
#   ('vier', 0.005621819),
#   ('transnational', 0.0052503916),
#   ('konnten', 0.005117824),
#   ('auswirkungen', 0.005117824),
#   ('wahrend', 0.0049972613),
#   ('befragten', 0.0049972613),
#   ('baumarten', 0.0049940036),
#   ('zeigt', 0.0049086474),
#   ('ausgabe', 0.0048230067),
#   ('deren', 0.0048113265),
#   ('sowie', 0.0048113265),
#   ('klimawandel', 0.0048113265),
#   ('thirdly', 0.0047463966),
#   ('ukraine', 0.004667104)],
#  [('sb', 0.028648498),
#   ('resonator', 0.026573513),
#   ('acoustic', 0.024622228),
#   ('trap', 0.021238742),
#   ('resonant', 0.019988345),
#   ('memory', 0.019636853),
#   ('wave', 0.019060269),
#   ('frequency', 0.013357041),
#   ('trapping', 0.012759952),
#   ('waw', 0.012183032),
#   ('nrmse', 0.012183032),
#   ('metasurfaces', 0.011773605),
#   ('force', 0.010384692),
#   ('resonance', 0.0093818735),
#   ('couch', 0.009185702)],
#  [('flow', 0.014193182),
#   ('hydrogel', 0.013966482),
#   ('bubble', 0.013591983),
#   ('droplet', 0.012861555),
#   ('surface', 0.012781781),
#   ('microfluidic', 0.0124031035),
#   ('capillary', 0.011466812),
#   ('liquid', 0.010451177),
#   ('sheet', 0.009296513),
#   ('pore', 0.0090483315),
#   ('ppi', 0.008263937),
#   ('shear', 0.008104676),
#   ('immobilization', 0.008023454),
#   ('self', 0.007583657),
#   ('micro', 0.007519732),
#   ('shape', 0.007360333),
#   ('cell', 0.0070847506),
#   ('porous', 0.006919438),
#   ('diameter', 0.006836336),
#   ('fluid', 0.0066438057),
#   ('layer', 0.0065978044),
#   ('mm', 0.0065915855),
#   ('chip', 0.006490418),
#   ('pressure', 0.0059815557),
#   ('immobilized', 0.0059305187),
#   ('pdms', 0.0058867014),
#   ('bacterial', 0.0058484008),
#   ('force', 0.0057154666),
#   ('md', 0.0057138754),
#   ('mechanical', 0.005662558)],
#  [('boson', 0.022348788),
#   ('mass', 0.020961147),
#   ('quark', 0.019340906),
#   ('tev', 0.018709706),
#   ('proton', 0.017098326),
#   ('search', 0.01648866),
#   ('decay', 0.015193575),
#   ('higgs', 0.014775574),
#   ('gev', 0.014159266),
#   ('fb', 0.013293636),
#   ('limit', 0.0124175465),
#   ('standard', 0.01193152),
#   ('lepton', 0.0116863325),
#   ('jet', 0.011556864),
#   ('pair', 0.011326746),
#   ('top', 0.010776513),
#   ('luminosity', 0.010618776)],
#  [('ad', 0.04145782),
#   ('aβ', 0.026585516),
#   ('amyloid', 0.021574255),
#   ('dram', 0.021304535),
#   ('mt', 0.017328952),
#   ('alzheimer', 0.015942182),
#   ('tau', 0.014658635),
#   ('etna', 0.013557885),
#   ('ep', 0.013153838),
#   ('disease', 0.012015496),
#   ('app', 0.011594654),
#   ('neuron', 0.0113895405),
#   ('bw', 0.01062904),
#   ('seafood', 0.010192444),
#   ('gli', 0.010192444)],
#  [('traffic', 0.038240038),
#   ('network', 0.022305544),
#   ('road', 0.016579833),
#   ('urban', 0.012368432),
#   ('congestion', 0.012361895),
#   ('time', 0.011379547),
#   ('train', 0.010853511),
#   ('transport', 0.010677564),
#   ('matsim', 0.010490109),
#   ('pricing', 0.010259749),
#   ('railway', 0.010120587),
#   ('agent', 0.009819373),
#   ('flow', 0.009733433),
#   ('vehicle', 0.009520918),
#   ('bus', 0.00940496),
#   ('delay', 0.009122519),
#   ('planning', 0.008985845),
#   ('city', 0.008586489),
#   ('simulation', 0.008448147),
#   ('travel', 0.008112448),
#   ('plan', 0.0079830345)],
#  [('user', 0.024046866),
#   ('ai', 0.009345637),
#   ('digital', 0.009085586),
#   ('map', 0.0090277735),
#   ('participant', 0.008340874),
#   ('design', 0.008337112),
#   ('research', 0.0077355155),
#   ('expert', 0.007655664),
#   ('task', 0.0070842644),
#   ('learning', 0.006763093),
#   ('information', 0.0060828426),
#   ('project', 0.0059116688),
#   ('atlas', 0.005848686),
#   ('tool', 0.005793756),
#   ('visual', 0.005654148),
#   ('technology', 0.00546292),
#   ('layout', 0.0053185895),
#   ('document', 0.0051273433),
#   ('researcher', 0.0051228637),
#   ('evaluation', 0.004995863),
#   ('spatial', 0.004987302),
#   ('web', 0.0049670036),
#   ('text', 0.0048768474),
#   ('mobile', 0.004842965),
# ...
#   ('crystalline', 0.007579779),
#   ('sample', 0.0075135413),
#   ('powder', 0.007478035),
#   ('anisotropy', 0.0072291475),
#   ('glass', 0.0071820207),
#   ('thermal', 0.007128291),
#   ('morphology', 0.0070616673),
#   ('cuo', 0.0067803273),
#   ('crystallization', 0.006734157),
#   ('magnetization', 0.006110517)],
#  [('iodine', 0.03527474),
#   ('malaria', 0.022203054),
#   ('adipose', 0.020554846),
#   ('fat', 0.020055503),
#   ('obesity', 0.019830484),
#   ('ucp', 0.016374104),
#   ('adipocytes', 0.015757319),
#   ('prenatal', 0.015611053),
#   ('allergic', 0.014814769),
#   ('uic', 0.014193226),
#   ('ifi', 0.013349683),
#   ('np', 0.013100232),
#   ('pregnant', 0.012702179),
#   ('review', 0.01243634),
#   ('adipocyte', 0.012160744)],
#  [('cloud', 0.057939492),
#   ('aerosol', 0.02152457),
#   ('radiation', 0.018779183),
#   ('vertical', 0.016827304),
#   ('convective', 0.016211575),
#   ('sky', 0.014464219),
#   ('radiative', 0.01354876),
#   ('turbulence', 0.01272126),
#   ('turbulent', 0.012701107),
#   ('optical', 0.011112747),
#   ('aod', 0.009795136),
#   ('lidar', 0.009354328),
#   ('glt', 0.009137655),
#   ('surface', 0.008729834),
#   ('layer', 0.008631804),
#   ('ftsz', 0.008420344),
#   ('flight', 0.008373699)],
#  [('cca', 0.027501853),
#   ('bat', 0.020832228),
#   ('latifolia', 0.019099684),
#   ('fragmentation', 0.017052423),
#   ('karyotype', 0.017042704),
#   ('ccmk', 0.015571866),
#   ('gqi', 0.014274334),
#   ('wolf', 0.013794625),
#   ('creatine', 0.012033324),
#   ('tuber', 0.012033324),
#   ('mangrove', 0.0116792675),
#   ('group', 0.011476126),
#   ('peg', 0.011128678),
#   ('ue', 0.01076249),
#   ('recruit', 0.010722418),
#   ('vpit', 0.010381735),
#   ('flo', 0.010381735),
#   ('vulgaris', 0.009920878)],
#  [('method', 0.005904584),
#   ('approach', 0.0050551877),
#   ('parameter', 0.0040581096),
#   ('system', 0.0040471177),
#   ('used', 0.0031241567),
#   ('performance', 0.0031039768),
#   ('work', 0.0029907147),
#   ('simulation', 0.002967153),
#   ('using', 0.0028807),
#   ('application', 0.0028451204),
#   ('technique', 0.0028314472),
#   ('dynamic', 0.0028302514),
#   ('present', 0.0026913593),
#   ('framework', 0.002622932),
#   ('proposed', 0.0026148008),
#   ('two', 0.0025412706),
#   ('step', 0.0024830634),
#   ('applied', 0.0024823241),
#   ('allows', 0.0024674244),
#   ('design', 0.0024213295),
#   ('set', 0.0023995135),
#   ('process', 0.002357862),
#   ('show', 0.0022899513),
#   ('prediction', 0.0022310857),
#   ('large', 0.0022187927),
#   ('simple', 0.0022104294),
#   ('scale', 0.0022009509),
#   ('use', 0.0021403234),
#   ('distribution', 0.0021390726),
#   ('tool', 0.0021240388),
#   ('presented', 0.0021144988),
#   ('order', 0.0020857276),
#   ('obtained', 0.0020825134),
#   ('procedure', 0.0020753166),
#   ('measurement', 0.002074005),
#   ('computational', 0.002034902),
#   ('control', 0.0020263435),
#   ('experimental', 0.001987199),
#   ('field', 0.001955899),
#   ('single', 0.0019536898),
#   ('real', 0.0019431156),
#   ('well', 0.0019339903),
#   ('state', 0.00193114),
#   ('new', 0.0019228929),
#   ('multi', 0.0019217394),
#   ('accurate', 0.0019203062),
#   ('modeling', 0.0019195288),
#   ('function', 0.0018982146),
#   ('paper', 0.0018634042),
#   ('algorithm', 0.001849994),
#   ('estimate', 0.0018208326),
#   ('demonstrate', 0.0018171761),
#   ('different', 0.0018166481),
#   ('error', 0.0018001118),
#   ('complex', 0.0017853146),
#   ('component', 0.0017817238),
#   ('provides', 0.0017801392),
#   ('power', 0.0017775642),
#   ('local', 0.0017758507),
#   ('case', 0.0017691919),
#   ('structure', 0.0017323615),
#   ('three', 0.001722456),
#   ('problem', 0.0017212121),
#   ('rate', 0.0017192486),
#   ('value', 0.0017189537),
#   ('required', 0.0017131472),
#   ('efficient', 0.0017002004),
#   ('accuracy', 0.00169467),
#   ('free', 0.0016851303),
#   ('uncertainty', 0.001677294),
#   ('linear', 0.0016766443),
#   ('first', 0.0016398425),
#   ('estimation', 0.0016257362),
#   ('phase', 0.0016241164),
#   ('good', 0.0016131641),
#   ('efficiency', 0.0015908259),
#   ('existing', 0.0015907995),
#   ('novel', 0.0015824643),
#   ('propose', 0.0015798396),
#   ('number', 0.0015734733),
#   ('open', 0.0015725847),
#   ('provide', 0.0015719903),
#   ('analysis', 0.0015702288),
#   ('modelling', 0.00156916),
#   ('input', 0.0015640336),
#   ('developed', 0.0015543331),
#   ('size', 0.0015206037),
#   ('due', 0.0015198151),
#   ('series', 0.001516864),
#   ('typically', 0.0015069699),
#   ('several', 0.0015063583),
#   ('configuration', 0.0015063456),
#   ('one', 0.0015060129),
#   ('non', 0.00150574),
#   ('range', 0.0014972074),
#   ('second', 0.0014953311),
#   ('full', 0.0014935724),
#   ('compared', 0.0014892934),
#   ('information', 0.0014854602),
#   ('available', 0.0014625866),
#   ('independent', 0.0014612771),
#   ('spatial', 0.0014553465),
#   ('given', 0.0014405017),
#   ('term', 0.001439373),
#   ('achieved', 0.0014148046),
#   ('length', 0.0014101488),
#   ('solution', 0.0013992685),
#   ('analytical', 0.0013975959),
#   ('high', 0.0013937941),
#   ('sampling', 0.0013925468),
#   ('cost', 0.0013883882),
#   ('mean', 0.0013835899),
#   ('test', 0.0013800084),
#   ('geometry', 0.0013609625),
#   ('detail', 0.0013514219),
#   ('moreover', 0.0013482621),
#   ('constraint', 0.0013460935),
#   ('measure', 0.0013396023),
#   ('small', 0.0013344648),
#   ('property', 0.0013325232),
#   ('account', 0.0013306678),
#   ('suitable', 0.0013273609),
#   ('implementation', 0.0013271974),
#   ('introduced', 0.0013252265),
#   ('assumption', 0.0013234199),
#   ('standard', 0.0013112254),
#   ('improvement', 0.001295808),
#   ('compare', 0.0012729615),
#   ('testing', 0.0012696914),
#   ('varying', 0.0012671824),
#   ('feature', 0.0012617284),
#   ('network', 0.001257732),
#   ('variable', 0.0012482718)],
#  [('cr', 0.025006846),
#   ('water', 0.023234416),
#   ('concentration', 0.016766654),
#   ('rh', 0.015535788),
#   ('liquid', 0.015335892),
#   ('gas', 0.015070067),
#   ('dm', 0.01427466),
#   ('phase', 0.011820877),
#   ('organic', 0.011409893),
#   ('temperature', 0.010729736),
#   ('mixture', 0.009974936),
#   ('sorption', 0.009951891),
#   ('edna', 0.009189048),
#   ('kg', 0.008944435),
#   ('aqueous', 0.008709058),
#   ('acid', 0.0082134465),
#   ('pu', 0.008206117),
#   ('wet', 0.008063424),
#   ('activity', 0.007997722),
#   ('vapor', 0.0076674414),
#   ('mg', 0.0076449187)],
#  [('tb', 0.043785706),
#   ('nest', 0.039482873),
#   ('rbc', 0.022209894),
#   ('taxonomy', 0.021742107),
#   ('taxonomic', 0.017103743),
#   ('folate', 0.016965067),
#   ('tmp', 0.01548086),
#   ('pareto', 0.013667368),
#   ('scatterers', 0.012659248),
#   ('trace', 0.012407185),
#   ('cloaking', 0.01238504),
#   ('ko', 0.011628762),
#   ('inference', 0.011316003)],
#  [('methane', 0.037972808),
#   ('ch', 0.034881804),
#   ('fcc', 0.026535204),
#   ('sad', 0.025521295),
#   ('hh', 0.023064664),
#   ('anoxic', 0.016047006),
#   ('oxygen', 0.015602617),
#   ('daphnia', 0.0136640575),
#   ('gas', 0.012238863),
#   ('poi', 0.01184234),
#   ('lake', 0.011119964),
#   ('ephippia', 0.010404202),
#   ('oxidation', 0.010131532),
#   ('forefields', 0.010020623)],
#  [('cry', 0.031015027),
#   ('ribosome', 0.023616856),
#   ('bt', 0.022603484),
#   ('ab', 0.021752242),
#   ('subunit', 0.021675084),
#   ('toxin', 0.02096634),
#   ('pre', 0.016793763),
#   ('ribosomal', 0.01576258),
#   ('export', 0.014802823),
#   ('rice', 0.014800082),
#   ('opv', 0.0145817315),
#   ('line', 0.0136486525),
#   ('translation', 0.01334995),
#   ('transgene', 0.01280505)],
#  [('patient', 0.024652002),
#   ('intervention', 0.0120416405),
#   ('group', 0.00974085),
#   ('age', 0.009316416),
#   ('ci', 0.009292638),
#   ('participant', 0.009281097),
#   ('clinical', 0.009249473),
#   ('outcome', 0.008896762),
#   ('treatment', 0.0081585),
#   ('health', 0.008092817),
#   ('pain', 0.0075054206),
#   ('year', 0.006761707),
#   ('trial', 0.0063994266),
#   ('conclusion', 0.006399205),
#   ('measure', 0.0060923933),
#   ('activity', 0.0058062384),
#   ('month', 0.0053913854),
#   ('risk', 0.0052945125),
#   ('sd', 0.0052758288),
#   ('week', 0.0051460476),
#   ('therapy', 0.0051294332),
#   ('included', 0.005086632),
#   ('hospital', 0.004845839),
#   ('child', 0.0046612145),
#   ('background', 0.0045643803),
#   ('subject', 0.004545384),
#   ('objective', 0.00449896),
#   ('assessed', 0.0044648997),
#   ('physical', 0.004434325),
#   ('day', 0.0042730886),
#   ('chronic', 0.0042626057),
#   ('heart', 0.004219222),
#   ('assessment', 0.0041797133),
#   ('control', 0.0041786707),
#   ('median', 0.004145099),
#   ('baseline', 0.00411992),
#   ('life', 0.004116188),
#   ('post', 0.004104102),
#   ('significant', 0.0040637776)],
#  [('problem', 0.011239126),
#   ('equation', 0.010804102),
#   ('approximation', 0.010241352),
#   ('space', 0.008634141),
#   ('finite', 0.008116942),
#   ('solution', 0.007947095),
#   ('convergence', 0.00750093),
#   ('algorithm', 0.007456109),
#   ('numerical', 0.0072053415),
#   ('linear', 0.006907708),
#   ('stochastic', 0.0066222697),
#   ('time', 0.0059042177),
#   ('prove', 0.005481943),
#   ('random', 0.005454504),
#   ('polynomial', 0.0053982725),
#   ('entropy', 0.0053655375),
#   ('function', 0.0051572267),
#   ('monte', 0.00515441),
#   ('theorem', 0.0050337724),
#   ('carlo', 0.005009408),
#   ('class', 0.0049810186),
#   ('dimensional', 0.004733404),
#   ('scheme', 0.0043941),
#   ('formula', 0.004263061),
#   ('bound', 0.004035296),
#   ('number', 0.0040102666),
#   ('boundary', 0.0040065753),
#   ('order', 0.003892498),
#   ('operator', 0.0038430218),
#   ('error', 0.0038082872),
#   ('classical', 0.0037891027),
#   ('dimension', 0.0037698252),
#   ('matrix', 0.0036935615),
#   ('approximate', 0.0036059562),
#   ('bounded', 0.0034815117),
#   ('inequality', 0.0034515099),
#   ('optimal', 0.0034364813),
#   ('deterministic', 0.003394136),
#   ('law', 0.0033928275),
#   ('galerkin', 0.0033795314),
#   ('quadratic', 0.0033795314),
#   ('element', 0.003264429),
#   ('parametric', 0.0032592975),
#   ('discretization', 0.0032347608),
#   ('constraint', 0.0032237102),
#   ('solved', 0.0031417802),
#   ('computation', 0.003050528),
#   ('elliptic', 0.0030456407),
#   ('probability', 0.003037049),
#   ('square', 0.003000534),
#   ('consider', 0.002981697)],
#  [('patient', 0.018515619),
#   ('cardiac', 0.016982533),
#   ('cmr', 0.015768792),
#   ('pet', 0.013039327),
#   ('perfusion', 0.011789112),
#   ('imaging', 0.011736501),
#   ('coronary', 0.011584893),
#   ('ct', 0.010856291),
#   ('myocardial', 0.010821001),
#   ('heart', 0.009027293),
#   ('healthy', 0.008432002),
#   ('artery', 0.008249541),
#   ('flow', 0.008232648),
#   ('mri', 0.008204842),
#   ('aortic', 0.007988265),
#   ('lv', 0.0076390835),
#   ('cardiovascular', 0.0065157027),
#   ('fdg', 0.006401482),
#   ('dyssynchrony', 0.0063629462),
#   ('mmhg', 0.006333183),
#   ('memory', 0.0060647237),
#   ('ventricular', 0.005837302),
#   ('value', 0.0055756276),
#   ('rt', 0.0055726306),
#   ('tomography', 0.005380718),
#   ('scan', 0.0053381706),
#   ('blood', 0.0053301086),
#   ('strain', 0.005293623),
#   ('dcmr', 0.0052803974)],
#  [('student', 0.05795497),
#   ('gm', 0.03327357),
#   ('bank', 0.028830007),
#   ('bitcoin', 0.024606263),
#   ('school', 0.018756568),
#   ('science', 0.01817712),
#   ('language', 0.017015355),
#   ('grade', 0.016159847),
#   ('teacher', 0.016015217),
#   ('teaching', 0.015690196),
#   ('privacy', 0.013486253)],
#  [('extreme', 0.04928979),
#   ('flood', 0.030842794),
#   ('event', 0.02948826),
#   ('climate', 0.027207525),
#   ('wetland', 0.025597103),
#   ('risk', 0.024015173),
#   ('weather', 0.019451983),
#   ('warning', 0.015919114),
#   ('summer', 0.015553673),
#   ('smartphone', 0.013483992)],
#  [('sulfate', 0.023660988),
#   ('sulfur', 0.02021981),
#   ('atf', 0.018434606),
#   ('ryegrass', 0.017705314),
#   ('phylogenetic', 0.016371947),
#   ('sulfide', 0.014938168),
#   ('lolium', 0.01380297),
#   ('endometrium', 0.011982911),
#   ('asexual', 0.011861549),
#   ('fabarum', 0.011537031),
#   ('cryptic', 0.01134707),
#   ('fe', 0.010553621),
#   ('teosinte', 0.010527702),
#   ('mrt', 0.010527702),
#   ('perenne', 0.010280168),
#   ('phylogeny', 0.010263084),
#   ('sexual', 0.010034475),
#   ('perennial', 0.009834285),
#   ('vegfa', 0.009762286)],
#  [('fluid', 0.034482002),
#   ('working', 0.02453319),
#   ('orc', 0.022730852),
#   ('comt', 0.022398924),
#   ('camd', 0.021119043),
#   ('design', 0.019218158),
#   ('solvent', 0.01809819),
#   ('process', 0.017620305),
#   ('cf', 0.017247437),
#   ('saft', 0.016015548),
#   ('cq', 0.014706317),
#   ('molecular', 0.014414001),
#   ('rrm', 0.014006065)],
#  [('wave', 0.056040715),
#   ('mesh', 0.036924608),
#   ('velocity', 0.03408119),
#   ('stability', 0.023780847),
#   ('gad', 0.018561665),
#   ('impulse', 0.01736883),
#   ('mtbc', 0.016114611),
#   ('dg', 0.01412263),
#   ('gesture', 0.013694684),
#   ('mb', 0.013181222),
#   ('fcd', 0.0129339965)],
#  [('policy', 0.01941003),
#   ('country', 0.01520031),
#   ('risk', 0.008678567),
#   ('economic', 0.008568325),
#   ('national', 0.008383464),
#   ('government', 0.0074586924),
#   ('public', 0.0070444304),
#   ('political', 0.006725062),
#   ('tax', 0.006310143),
#   ('income', 0.006183372),
#   ('governance', 0.006032217),
#   ('eu', 0.005921356),
#   ('european', 0.005687594),
#   ('international', 0.0056354147),
#   ('economy', 0.0052597974),
#   ('institution', 0.005221736),
#   ('social', 0.004848733),
#   ('market', 0.004804607),
#   ('financial', 0.0047773193),
#   ('swiss', 0.0047641853),
#   ('sector', 0.004693305),
#   ('switzerland', 0.0043666665),
#   ('united', 0.0043412517),
#   ('private', 0.004208519),
#   ('incentive', 0.004187223),
#   ('conflict', 0.0041697305),
#   ('environmental', 0.0041222544),
#   ('paper', 0.00397823),
#   ('service', 0.0039071576),
#   ('cost', 0.003649957),
#   ('crisis', 0.0036307138),
#   ('find', 0.0035987038),
#   ('contract', 0.0034511439),
#   ('actor', 0.0034007202),
#   ('welfare', 0.0033566318),
#   ('capital', 0.0033340422),
#   ('state', 0.0032812483),
#   ('level', 0.0032041047),
#   ('europe', 0.0031961005),
#   ('voting', 0.0031730346),
#   ('growth', 0.0031670518),
#   ('decision', 0.0031561404),
#   ('survey', 0.0031024953),
#   ('panel', 0.0031003936),
#   ('institutional', 0.0030808747),
#   ('effort', 0.003071756),
#   ('security', 0.0029954442),
#   ('trade', 0.0029611732),
#   ('measure', 0.0029542826),
#   ('company', 0.0029229694)],
#  [('training', 0.019878149),
#   ('exercise', 0.019830648),
#   ('walking', 0.016704181),
#   ('gait', 0.01588291),
#   ('muscle', 0.0146681005),
#   ('subject', 0.014078473),
#   ('motor', 0.013080347),
#   ('movement', 0.011830182),
#   ('task', 0.010799838),
#   ('stroke', 0.010046344),
#   ('limb', 0.009196874),
#   ('rehabilitation', 0.009041),
#   ('reliability', 0.008934614),
#   ('cognitive', 0.0087846955),
#   ('hand', 0.008441352),
#   ('older', 0.008126511),
#   ('performance', 0.007411533),
#   ('force', 0.007238601),
#   ('joint', 0.0065077203),
#   ('leg', 0.0064449254),
#   ('knee', 0.006155291),
#   ('adult', 0.005638569),
#   ('robot', 0.005604266),
#   ('velocity', 0.0055776867),
#   ('elderly', 0.0055495882)],
#  [('m', 0.019566162),
#   ('protein', 0.018202582),
#   ('spectrometry', 0.016279412),
#   ('workflow', 0.013628703),
#   ('pipeline', 0.010632056),
#   ('mass', 0.010251877),
#   ('detection', 0.01000401),
#   ('sample', 0.00983306),
#   ('proteome', 0.008792331),
#   ('drug', 0.008420106),
#   ('proteomics', 0.008285568),
#   ('lc', 0.008260674),
#   ('method', 0.008211852),
#   ('peptide', 0.008106729),
#   ('biology', 0.007788637),
#   ('identification', 0.007729541),
#   ('quantitative', 0.007654717),
#   ('tool', 0.007551005),
#   ('compound', 0.007454944),
#   ('chromatography', 0.0072641396),
#   ('laboratory', 0.006909695),
#   ('swath', 0.006908289),
#   ('quantification', 0.0066316333),
#   ('platform', 0.0065396586),
#   ('software', 0.00640936),
#   ('plasma', 0.006236413),
#   ('extraction', 0.0062191617),
#   ('protocol', 0.0060511967)],
#  [('cancer', 0.061298583),
#   ('tumor', 0.05158636),
#   ('cd', 0.021481158),
#   ('myc', 0.0157245),
#   ('patient', 0.014502131),
#   ('breast', 0.014396194),
#   ('cell', 0.013460182),
#   ('metastasis', 0.011577369),
#   ('tumour', 0.011568774),
#   ('survival', 0.010779709),
#   ('metastatic', 0.010372786),
#   ('treatment', 0.009847625),
#   ('carcinoma', 0.009675462)],
#  [('heat', 0.026538769),
#   ('adsorption', 0.024635687),
#   ('citation', 0.019756988),
#   ('switching', 0.019651903),
#   ('chiller', 0.01848764),
#   ('transfer', 0.015330376),
#   ('prion', 0.013352932),
#   ('adsorbent', 0.012998927),
#   ('circuit', 0.0129097635),
#   ('voltage', 0.01265399),
#   ('temperature', 0.011934763),
#   ('atgrp', 0.011671699),
#   ('cooling', 0.01065052),
#   ('purge', 0.010225961),
#   ('rotor', 0.010225961),
#   ('transformer', 0.010197612),
#   ('gate', 0.0094030965)]]

# %%
import pickle 
import numpy as np 
import os 
import time
import torch

# %%
# Loading from binary the glove vocabulary and embedding 
glove_vocab_path = "glove_vocab.uu"
glove_embedding_path = "glove_embedding.uu"
with open(glove_vocab_path, "rb") as fp:  
    glove_vocab = pickle.load(fp)
with open(glove_embedding_path, "rb") as fp: 
    glove_embedding = pickle.load(fp)

# %%
glove_vocab_normalised = {k:lemmatiser.lemmatize(v) for k,v in glove_vocab.items()}

# %%
def get_list_embeddings_topic(topic, vocab, embedding):
    """ Topic is represented as a list of tuples (word, word weight)"""
    matched = 0 
    total = 0
    topic_embeddings = []
    topic_weights = []
    
    start = time.time()
    
    for item in topic: 
        word, weight = item
        total+=1
        #check if the word appears in vocabulary 
        if word in vocab.values(): 
            matched+=1
            emb = embedding[list(vocab.values()).index(word)]
            topic_embeddings += [emb.numpy()]
            topic_weights += [weight]
    
    end = time.time()
    
    print("Total time: "+str(round(end-start,2))+" s.")
    print("Proportion of matched words: "+str(round(matched/total,2)))
    return topic_embeddings, topic_weights

# %%
topic_embeddings, topic_weights = get_list_embeddings_topic(topics2words_list[0][0], glove_vocab_normalised, 
                                                            glove_embedding)
# Out:
# Total time: 0.15 s.
# Proportion of matched words: 0.69

# %%
def get_convex_topic_embedding(topic_weights, topic_embeddings):
    """ Creates a topic embeddings as convex combination of embedding vectors according 
    to the weights provided."""
    weight_vec = np.asarray(topic_weights)
    topic_vec = np.asarray(topic_embeddings)
    normalized_weights = weight_vec / np.sqrt(np.sum(weight_vec**2))
    return normalized_weights.dot(topic_vec)

# %%
topic_emb = get_convex_topic_embedding(topic_weights, topic_embeddings)

# %%
def get_convex_topics_embeddings(batch_topics, vocab, embedding):
    """ Runs the above 2 functions to get the embedding for each topic in the batch."""
    topics_embs = []
    for topic2word in batch_topics:
        topic_embeddings, topic_weights = get_list_embeddings_topic(topic2word, glove_vocab_normalised, glove_embedding)
        topic_emb = get_convex_topic_embedding(topic_weights, topic_embeddings)
        topics_embs += [topic_emb]
    return topics_embs

# %%
topics_embs1 = get_convex_topics_embeddings(topics2words_list[0], glove_vocab_normalised, glove_embedding)
topics_embs2 = get_convex_topics_embeddings(topics2words_list[0], glove_vocab_normalised, glove_embedding)
topics_embs3 = get_convex_topics_embeddings(topics2words_list[0], glove_vocab_normalised, glove_embedding)
topics_embs = topics_embs1.add(topics_embs2.add(topics_embs3))
# Out:
# Total time: 0.16 s.
# Proportion of matched words: 0.69
# Total time: 0.21 s.
# Proportion of matched words: 0.96
# Total time: 0.16 s.
# Proportion of matched words: 1.0
# Total time: 0.14 s.
# Proportion of matched words: 1.0
# Total time: 0.21 s.
# Proportion of matched words: 1.0
# Total time: 0.11 s.
# Proportion of matched words: 1.0
# Total time: 0.24 s.
# Proportion of matched words: 0.67
# Total time: 0.05 s.
# Proportion of matched words: 1.0
# Total time: 0.13 s.
# Proportion of matched words: 1.0
# Total time: 0.4 s.
# Proportion of matched words: 0.89
# Total time: 0.12 s.
# Proportion of matched words: 1.0
# Total time: 0.07 s.
# Proportion of matched words: 1.0
# Total time: 0.11 s.
# Proportion of matched words: 1.0
# Total time: 0.1 s.
# Proportion of matched words: 1.0
# Total time: 0.18 s.
# Proportion of matched words: 0.97
# Total time: 0.03 s.
# Proportion of matched words: 0.67
# Total time: 0.08 s.
# Proportion of matched words: 0.93
# Total time: 0.07 s.
# Proportion of matched words: 1.0
# Total time: 0.11 s.
# Proportion of matched words: 0.94
# Total time: 0.08 s.
# Proportion of matched words: 1.0
# Total time: 0.13 s.
# Proportion of matched words: 1.0
# Total time: 0.08 s.
# Proportion of matched words: 0.85
# Total time: 0.09 s.
# Proportion of matched words: 0.87
# Total time: 0.05 s.
# Proportion of matched words: 1.0
# Total time: 0.16 s.
# Proportion of matched words: 1.0
# Total time: 0.1 s.
# Proportion of matched words: 0.94
# Total time: 0.15 s.
# Proportion of matched words: 1.0
# Total time: 0.24 s.
# Proportion of matched words: 0.98
# Total time: 0.09 s.
# Proportion of matched words: 1.0
# Total time: 0.17 s.
# Proportion of matched words: 1.0
# Total time: 0.23 s.
# Proportion of matched words: 1.0
# Total time: 0.25 s.
# Proportion of matched words: 0.98
# Total time: 0.11 s.
# Proportion of matched words: 1.0
# Total time: 0.14 s.
# Proportion of matched words: 1.0
# Total time: 0.82 s.
# Proportion of matched words: 0.86
# Total time: 0.11 s.
# Proportion of matched words: 0.82
# Total time: 0.11 s.
# Proportion of matched words: 1.0
# Total time: 0.09 s.
# Proportion of matched words: 0.93
# Total time: 0.12 s.
# Proportion of matched words: 0.89
# Total time: 0.09 s.
# Proportion of matched words: 0.87
# Total time: 0.12 s.
# Proportion of matched words: 1.0
# Total time: 0.1 s.
# Proportion of matched words: 0.83
# Total time: 0.24 s.
# Proportion of matched words: 1.0
# Total time: 0.14 s.
# Proportion of matched words: 0.87
# Total time: 0.09 s.
# Proportion of matched words: 0.93
# Total time: 0.11 s.
# Proportion of matched words: 0.88
# Total time: 0.04 s.
# Proportion of matched words: 1.0
# Total time: 0.11 s.
# Proportion of matched words: 0.89
# Total time: 0.2 s.
# Proportion of matched words: 0.97
# Total time: 0.13 s.
# Proportion of matched words: 1.0
# Total time: 0.12 s.
# Proportion of matched words: 0.85
# Total time: 0.16 s.
# Proportion of matched words: 0.97
# Total time: 0.08 s.
# Proportion of matched words: 0.93
# Total time: 0.07 s.
# Proportion of matched words: 1.0
# Total time: 0.11 s.
# Proportion of matched words: 1.0
# Total time: 0.06 s.
# Proportion of matched words: 1.0
# Total time: 0.07 s.
# Proportion of matched words: 1.0
# Total time: 0.13 s.
# Proportion of matched words: 1.0
# Total time: 0.05 s.
# Proportion of matched words: 1.0
# Total time: 0.09 s.
# Proportion of matched words: 1.0
# Total time: 0.19 s.
# Proportion of matched words: 0.97
# Total time: 0.05 s.
# Proportion of matched words: 1.0
# Total time: 0.46 s.
# Proportion of matched words: 0.84
# Total time: 0.09 s.
# Proportion of matched words: 1.0
# Total time: 0.12 s.
# Proportion of matched words: 0.9
# Total time: 0.1 s.
# Proportion of matched words: 0.95
# Total time: 0.15 s.
# Proportion of matched words: 1.0
# Total time: 0.04 s.
# Proportion of matched words: 0.88
# Total time: 0.09 s.
# Proportion of matched words: 0.93
# Total time: 0.13 s.
# Proportion of matched words: 1.0
# Total time: 0.16 s.
# Proportion of matched words: 1.0
# Total time: 0.11 s.
# Proportion of matched words: 1.0
# Total time: 0.12 s.
# Proportion of matched words: 1.0
# Total time: 0.13 s.
# Proportion of matched words: 0.74
# Total time: 0.2 s.
# Proportion of matched words: 1.0
# Total time: 0.15 s.
# Proportion of matched words: 1.0
# Total time: 0.17 s.
# Proportion of matched words: 1.0
# Total time: 0.13 s.
# Proportion of matched words: 1.0
# Total time: 0.1 s.
# Proportion of matched words: 1.0
# Total time: 0.12 s.
# Proportion of matched words: 1.0
# Total time: 0.28 s.
# Proportion of matched words: 1.0
# Total time: 0.06 s.
# Proportion of matched words: 1.0
# Total time: 0.14 s.
# Proportion of matched words: 0.91
# Total time: 0.09 s.
# Proportion of matched words: 0.91
# Total time: 0.1 s.
# Proportion of matched words: 1.0
# Total time: 0.08 s.
# Proportion of matched words: 1.0
# Total time: 0.08 s.
# Proportion of matched words: 1.0
# Total time: 0.11 s.
# Proportion of matched words: 0.95
# Total time: 0.06 s.
# Proportion of matched words: 0.9
# Total time: 0.09 s.
# Proportion of matched words: 0.86
# Total time: 0.39 s.
# Proportion of matched words: 1.0
# Total time: 0.14 s.
# Proportion of matched words: 1.0
# Total time: 0.14 s.
# Proportion of matched words: 1.0
# Total time: 0.06 s.
# Proportion of matched words: 1.0
# Total time: 0.1 s.
# Proportion of matched words: 0.94
# Total time: 0.06 s.
# Proportion of matched words: 1.0
# Total time: 0.12 s.
# Proportion of matched words: 0.95
# Total time: 0.14 s.
# Proportion of matched words: 0.97
# Total time: 0.08 s.
# Proportion of matched words: 0.86
# Total time: 0.08 s.
# Proportion of matched words: 1.0
# Total time: 0.11 s.
# Proportion of matched words: 0.69
# Total time: 0.16 s.
# Proportion of matched words: 0.96
# Total time: 0.12 s.
# Proportion of matched words: 1.0
# Total time: 0.11 s.
# Proportion of matched words: 1.0
# Total time: 0.16 s.
# Proportion of matched words: 1.0
# Total time: 0.1 s.
# Proportion of matched words: 1.0
# Total time: 0.23 s.
# Proportion of matched words: 0.67
# Total time: 0.05 s.
# Proportion of matched words: 1.0
# Total time: 0.13 s.
# Proportion of matched words: 1.0
# Total time: 0.39 s.
# Proportion of matched words: 0.89
# Total time: 0.11 s.
# Proportion of matched words: 1.0
# Total time: 0.08 s.
# Proportion of matched words: 1.0
# Total time: 0.11 s.
# Proportion of matched words: 1.0
# Total time: 0.1 s.
# Proportion of matched words: 1.0
# Total time: 0.18 s.
# Proportion of matched words: 0.97
# Total time: 0.03 s.
# Proportion of matched words: 0.67
# Total time: 0.08 s.
# Proportion of matched words: 0.93
# Total time: 0.07 s.
# Proportion of matched words: 1.0
# Total time: 0.1 s.
# Proportion of matched words: 0.94
# Total time: 0.08 s.
# Proportion of matched words: 1.0
# Total time: 0.12 s.
# Proportion of matched words: 1.0
# Total time: 0.08 s.
# Proportion of matched words: 0.85
# Total time: 0.08 s.
# Proportion of matched words: 0.87
# Total time: 0.05 s.
# Proportion of matched words: 1.0
# Total time: 0.16 s.
# Proportion of matched words: 1.0
# Total time: 0.09 s.
# Proportion of matched words: 0.94
# Total time: 0.14 s.
# Proportion of matched words: 1.0
# Total time: 0.24 s.
# Proportion of matched words: 0.98
# Total time: 0.09 s.
# Proportion of matched words: 1.0
# Total time: 0.15 s.
# Proportion of matched words: 1.0
# Total time: 0.22 s.
# Proportion of matched words: 1.0
# Total time: 0.25 s.
# Proportion of matched words: 0.98
# Total time: 0.1 s.
# Proportion of matched words: 1.0
# Total time: 0.14 s.
# Proportion of matched words: 1.0
# Total time: 0.81 s.
# Proportion of matched words: 0.86
# Total time: 0.11 s.
# Proportion of matched words: 0.82
# Total time: 0.11 s.
# Proportion of matched words: 1.0
# Total time: 0.09 s.
# Proportion of matched words: 0.93
# Total time: 0.12 s.
# Proportion of matched words: 0.89
# Total time: 0.09 s.
# Proportion of matched words: 0.87
# Total time: 0.12 s.
# Proportion of matched words: 1.0
# Total time: 0.1 s.
# Proportion of matched words: 0.83
# Total time: 0.24 s.
# Proportion of matched words: 1.0
# Total time: 0.15 s.
# Proportion of matched words: 0.87
# Total time: 0.08 s.
# Proportion of matched words: 0.93
# Total time: 0.1 s.
# Proportion of matched words: 0.88
# Total time: 0.04 s.
# Proportion of matched words: 1.0
# Total time: 0.1 s.
# Proportion of matched words: 0.89
# Total time: 0.2 s.
# Proportion of matched words: 0.97
# Total time: 0.14 s.
# Proportion of matched words: 1.0
# Total time: 0.12 s.
# Proportion of matched words: 0.85
# Total time: 0.16 s.
# Proportion of matched words: 0.97
# Total time: 0.08 s.
# Proportion of matched words: 0.93
# Total time: 0.07 s.
# Proportion of matched words: 1.0
# Total time: 0.11 s.
# Proportion of matched words: 1.0
# Total time: 0.05 s.
# Proportion of matched words: 1.0
# Total time: 0.07 s.
# Proportion of matched words: 1.0
# Total time: 0.13 s.
# Proportion of matched words: 1.0
# Total time: 0.05 s.
# Proportion of matched words: 1.0
# Total time: 0.08 s.
# Proportion of matched words: 1.0
# Total time: 0.19 s.
# Proportion of matched words: 0.97
# Total time: 0.05 s.
# Proportion of matched words: 1.0
# Total time: 0.46 s.
# Proportion of matched words: 0.84
# Total time: 0.09 s.
# Proportion of matched words: 1.0
# Total time: 0.12 s.
# Proportion of matched words: 0.9
# Total time: 0.11 s.
# Proportion of matched words: 0.95
# Total time: 0.15 s.
# Proportion of matched words: 1.0
# Total time: 0.04 s.
# Proportion of matched words: 0.88
# Total time: 0.08 s.
# Proportion of matched words: 0.93
# Total time: 0.12 s.
# Proportion of matched words: 1.0
# Total time: 0.16 s.
# Proportion of matched words: 1.0
# Total time: 0.11 s.
# Proportion of matched words: 1.0
# Total time: 0.12 s.
# Proportion of matched words: 1.0
# Total time: 0.14 s.
# Proportion of matched words: 0.74
# Total time: 0.19 s.
# Proportion of matched words: 1.0
# Total time: 0.15 s.
# Proportion of matched words: 1.0
# Total time: 0.17 s.
# Proportion of matched words: 1.0
# Total time: 0.13 s.
# Proportion of matched words: 1.0
# Total time: 0.1 s.
# Proportion of matched words: 1.0
# Total time: 0.12 s.
# Proportion of matched words: 1.0
# Total time: 0.28 s.
# Proportion of matched words: 1.0
# Total time: 0.06 s.
# Proportion of matched words: 1.0
# Total time: 0.14 s.
# Proportion of matched words: 0.91
# Total time: 0.08 s.
# Proportion of matched words: 0.91
# Total time: 0.1 s.
# Proportion of matched words: 1.0
# Total time: 0.08 s.
# Proportion of matched words: 1.0
# Total time: 0.08 s.
# Proportion of matched words: 1.0
# Total time: 0.11 s.
# Proportion of matched words: 0.95
# Total time: 0.06 s.
# Proportion of matched words: 0.9
# Total time: 0.09 s.
# Proportion of matched words: 0.86
# Total time: 0.26 s.
# Proportion of matched words: 1.0
# Total time: 0.14 s.
# Proportion of matched words: 1.0
# Total time: 0.14 s.
# Proportion of matched words: 1.0
# Total time: 0.05 s.
# Proportion of matched words: 1.0
# Total time: 0.1 s.
# Proportion of matched words: 0.94
# Total time: 0.06 s.
# Proportion of matched words: 1.0
# Total time: 0.12 s.
# Proportion of matched words: 0.95
# Total time: 0.14 s.
# Proportion of matched words: 0.97
# Total time: 0.08 s.
# Proportion of matched words: 0.86
# Total time: 0.08 s.
# Proportion of matched words: 1.0
# Total time: 0.11 s.
# Proportion of matched words: 0.69
# Total time: 0.16 s.
# Proportion of matched words: 0.96
# Total time: 0.11 s.
# Proportion of matched words: 1.0
# Total time: 0.11 s.
# Proportion of matched words: 1.0
# Total time: 0.14 s.
# Proportion of matched words: 1.0
# Total time: 0.1 s.
# Proportion of matched words: 1.0
# Total time: 0.23 s.
# Proportion of matched words: 0.67
# Total time: 0.05 s.
# Proportion of matched words: 1.0
# Total time: 0.14 s.
# Proportion of matched words: 1.0
# Total time: 0.4 s.
# Proportion of matched words: 0.89
# Total time: 0.11 s.
# Proportion of matched words: 1.0
# Total time: 0.07 s.
# Proportion of matched words: 1.0
# Total time: 0.11 s.
# Proportion of matched words: 1.0
# Total time: 0.1 s.
# Proportion of matched words: 1.0
# Total time: 0.18 s.
# Proportion of matched words: 0.97
# Total time: 0.03 s.
# Proportion of matched words: 0.67
# Total time: 0.08 s.
# Proportion of matched words: 0.93
# Total time: 0.07 s.
# Proportion of matched words: 1.0
# Total time: 0.1 s.
# Proportion of matched words: 0.94
# Total time: 0.08 s.
# Proportion of matched words: 1.0
# Total time: 0.13 s.
# Proportion of matched words: 1.0
# Total time: 0.08 s.
# Proportion of matched words: 0.85
# Total time: 0.08 s.
# Proportion of matched words: 0.87
# Total time: 0.05 s.
# Proportion of matched words: 1.0
# Total time: 0.16 s.
# Proportion of matched words: 1.0
# Total time: 0.11 s.
# Proportion of matched words: 0.94
# Total time: 0.14 s.
# Proportion of matched words: 1.0
# Total time: 0.23 s.
# Proportion of matched words: 0.98
# Total time: 0.09 s.
# Proportion of matched words: 1.0
# Total time: 0.15 s.
# Proportion of matched words: 1.0
# Total time: 0.23 s.
# Proportion of matched words: 1.0
# Total time: 0.25 s.
# Proportion of matched words: 0.98
# Total time: 0.1 s.
# Proportion of matched words: 1.0
# Total time: 0.14 s.
# Proportion of matched words: 1.0
# Total time: 0.81 s.
# Proportion of matched words: 0.86
# Total time: 0.11 s.
# Proportion of matched words: 0.82
# Total time: 0.11 s.
# Proportion of matched words: 1.0
# Total time: 0.09 s.
# Proportion of matched words: 0.93
# Total time: 0.12 s.
# Proportion of matched words: 0.89
# Total time: 0.09 s.
# Proportion of matched words: 0.87
# Total time: 0.12 s.
# Proportion of matched words: 1.0
# Total time: 0.1 s.
# Proportion of matched words: 0.83
# Total time: 0.24 s.
# Proportion of matched words: 1.0
# Total time: 0.14 s.
# Proportion of matched words: 0.87
# Total time: 0.08 s.
# Proportion of matched words: 0.93
# Total time: 0.1 s.
# Proportion of matched words: 0.88
# Total time: 0.04 s.
# Proportion of matched words: 1.0
# Total time: 0.11 s.
# Proportion of matched words: 0.89
# Total time: 0.2 s.
# Proportion of matched words: 0.97
# Total time: 0.13 s.
# Proportion of matched words: 1.0
# Total time: 0.12 s.
# Proportion of matched words: 0.85
# Total time: 0.17 s.
# Proportion of matched words: 0.97
# Total time: 0.08 s.
# Proportion of matched words: 0.93
# Total time: 0.07 s.
# Proportion of matched words: 1.0
# Total time: 0.11 s.
# Proportion of matched words: 1.0
# Total time: 0.06 s.
# Proportion of matched words: 1.0
# Total time: 0.07 s.
# Proportion of matched words: 1.0
# Total time: 0.13 s.
# Proportion of matched words: 1.0
# Total time: 0.05 s.
# Proportion of matched words: 1.0
# Total time: 0.08 s.
# Proportion of matched words: 1.0
# Total time: 0.18 s.
# Proportion of matched words: 0.97
# Total time: 0.05 s.
# Proportion of matched words: 1.0
# Total time: 0.46 s.
# Proportion of matched words: 0.84
# Total time: 0.09 s.
# Proportion of matched words: 1.0
# Total time: 0.13 s.
# Proportion of matched words: 0.9
# Total time: 0.1 s.
# Proportion of matched words: 0.95
# Total time: 0.15 s.
# Proportion of matched words: 1.0
# Total time: 0.04 s.
# Proportion of matched words: 0.88
# Total time: 0.08 s.
# Proportion of matched words: 0.93
# Total time: 0.12 s.
# Proportion of matched words: 1.0
# Total time: 0.15 s.
# Proportion of matched words: 1.0
# Total time: 0.11 s.
# Proportion of matched words: 1.0
# Total time: 0.12 s.
# Proportion of matched words: 1.0
# Total time: 0.13 s.
# Proportion of matched words: 0.74
# Total time: 0.18 s.
# Proportion of matched words: 1.0
# Total time: 0.15 s.
# Proportion of matched words: 1.0
# Total time: 0.18 s.
# Proportion of matched words: 1.0
# Total time: 0.13 s.
# Proportion of matched words: 1.0
# Total time: 0.1 s.
# Proportion of matched words: 1.0
# Total time: 0.12 s.
# Proportion of matched words: 1.0
# Total time: 0.28 s.
# Proportion of matched words: 1.0
# Total time: 0.06 s.
# Proportion of matched words: 1.0
# Total time: 0.14 s.
# Proportion of matched words: 0.91
# Total time: 0.09 s.
# Proportion of matched words: 0.91
# Total time: 0.1 s.
# Proportion of matched words: 1.0
# Total time: 0.08 s.
# Proportion of matched words: 1.0
# Total time: 0.08 s.
# Proportion of matched words: 1.0
# Total time: 0.11 s.
# Proportion of matched words: 0.95
# Total time: 0.06 s.
# Proportion of matched words: 0.9
# Total time: 0.09 s.
# Proportion of matched words: 0.86
# Total time: 0.26 s.
# Proportion of matched words: 1.0
# Total time: 0.14 s.
# Proportion of matched words: 1.0
# Total time: 0.14 s.
# Proportion of matched words: 1.0
# Total time: 0.05 s.
# Proportion of matched words: 1.0
# Total time: 0.09 s.
# Proportion of matched words: 0.94
# Total time: 0.06 s.
# Proportion of matched words: 1.0
# Total time: 0.12 s.
# Proportion of matched words: 0.95
# Total time: 0.14 s.
# Proportion of matched words: 0.97
# Total time: 0.09 s.
# Proportion of matched words: 0.86
# Total time: 0.08 s.
# Proportion of matched words: 1.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-101-6166fdad8834> in <module>
#       2 topics_embs2 = get_convex_topics_embeddings(topics2words_list[0], glove_vocab_normalised, glove_embedding)
#       3 topics_embs3 = get_convex_topics_embeddings(topics2words_list[0], glove_vocab_normalised, glove_embedding)
# ----> 4 topics_embs = topics_embs1.add(topics_embs2.add(topics_embs3))
#
# AttributeError: 'list' object has no attribute 'add'

# %%
def nearest_neighbors(topic, topics):
    """Returns the most similar topics to the given one in the listo of topics"""
    cos = torch.nn.CosineSimilarity(dim = -1)
    ranks = cos(torch.tensor(topic), torch.tensor(topics))
    mostSimilar = []
    return ranks.numpy().argsort()[::-1]

# %%
# let's look at the first topic 
nns_0 = nearest_neighbors(topics_embs[0], topics_embs)

# %%
def visualise_most_similar(topic_id, topics_embs, topics2words, n=10):
    """Prints the words of the topic and its neareast neighbors."""
    nns = nearest_neighbors(topics_embs[topic_id], topics_embs)
    print("-"*10)
    print("Topic "+ str(topic_id))
    print(" ".join(item[0] for item in topics2words[0]))
    print("-"*10)
    print(str(n)+" most similar topics")
    for i in range(n):
        print("Topic "+str(i+1))
        print(" ".join(item[0] for item in topics2words[nns[i+1]]))

# %%
visualise_most_similar(0, topics_embs, topics2words)
# Out:
# ----------
# Topic 0
# cc dsm dsms covariates pcv worldview cheat gcp cmet ωarag gcps paul envelope stereo nanosilver ph
# ----------
# 10 most similar topics
# Topic 1
# sf jnk malt displacement ip myo ssp midkine bt yield ductility ngo structure pig pacemaker shark
# Topic 2
# dot nogo pd qds ag icp microdroplets sc cdse nc ma polygyrus rab igg sp hemts hydroxythujone signal endosomes
# Topic 3
# cluster vapor liquid filter rbr uvi equilibrium diamond photoelectron cation dca metastable cvd ultraviolet alkaloid lattice
# Topic 4
# np ph wood acid hcl tio composite glass drying pore wt scaffold presence bioactive dental synthesis phosphate polymer material acetic adsorption ion peg formation nano light metal
# Topic 5
# oc mouse liver hepatic lipid cholesterol adipose fat agnp metabolic hscs hfd pparγ dbt fish creatine endometrial obesity
# Topic 6
# msc adhesion mirna cell myelin mirnas migration ecm sii grk mmp collagen tf regenerative differentiation tremor axon rkip alg fibronectin extracellular matrix dog cultured col
# Topic 7
# section stat syst cross measured tt decay meson pp measurement pb neutrino gev
# Topic 8
# dose caspase keratinocytes apoptosis dos ul oxidase gy irradiation aps nadph tumor melanoma nrf skin cancer therapy preservative plan
# Topic 9
# mri myocardial cardiac heart imaging patient mr cmr perfusion blood image intra ventricular magnetic resonance phantom acquisition volume ventricle echo inter dose diffusion
# Topic 10
# emission ch co methane inventory flux yr
