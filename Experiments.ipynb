# %%
import pandas as pd
import os 
import numpy as np
import re
import random
import tomotopy as tp
import sys
import pickle
import time

# %%
input_path = "abstracts_processed.csv"
with open(input_path, "rb") as fp:   
    # Unpickling
    documents = pickle.load(fp)

# %%
## Setting the hyperparameters
tw = tp.TermWeight.ONE # term weighting scheme in TermWeight. The default value is TermWeight.ONE
initial_k = 2
min_cf=3 # minimum collection frequency of words. Words with a smaller collection frequency than min_cf are excluded from the model. The default value is 0, which means no words are excluded.
min_df=0 # minimum document frequency of words. Words with a smaller document frequency than min_df are excluded from the model. The default value is 0, which means no words are excluded
rm_top=5 # the number of top words to be removed. If you want to remove too common words from model, you can set this value to 1 or more. The default value is 0, which means no top words are removed.
alpha = 0.1 # hyperparameter of Dirichlet distribution for document-topic
eta = 0.01 # hyperparameter of Dirichlet distribution for topic-word
gamma = 0.1 # concentration coeficient of Dirichlet Process for table-topic
transform = None # a callable object to manipulate arbitrary keyword arguments for a specific topic model
seed = 41 # random seed
model_burn_in = 500 
train_updates = 10000
train_iter = 10
save_path = "hdp_model.bin" #.bin format

# %%
model = tp.HDPModel(tw=tw, min_cf=min_cf, min_df=min_df, rm_top=rm_top, initial_k=initial_k, alpha=alpha, 
                    eta=eta, gamma=gamma, transform=transform)

# %%
# adding documents to the model 
for doc in documents: model.add_doc(doc)

# %%
start = time.time()
# training**
model.burn_in = model_burn_in
# initialising 
model.train(iter=0)
print('Num docs:', len(model.docs), ', Vocab size:', len(model.used_vocabs), ', Num words:', model.num_words)
print('Removed top words:', model.removed_top_words)
print('Training...', file=sys.stderr, flush=True)
# actual training 
t = []
LLs = []
for i in range(0, train_updates, train_iter):
    model.train(train_iter)
    if i%1000==0:print('Iteration: {}'.format(i))
    t.append(i)
    LLs.append(model.ll_per_word)

end = time.time()
print("Time elapsed: "+ str(round(end - start,1))+" s")
# Out:
# Training...
# Num docs: 20494 , Vocab size: 42219 , Num words: 2045097
# Removed top words: ['use', 'model', 'result', 'studi', 'base']
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900

# %%
model.summary()
# Out:
# <Basic Info>
# | HDPModel (current version: 0.9.1)
# | 20494 docs, 2045097 words
# | Total Vocabs: 69312, Used Vocabs: 42219
# | Entropy of words: -8.71136
# | Removed Vocabs: use model result studi base
# |
# <Training Info>
# | Iterations: 1000, Burn-in steps: 100
# | Optimization Interval: 10
# | Log-likelihood per word: -8.33705
# |
# <Initial Parameters>
# | tw: TermWeight.ONE
# | min_cf: 3 (minimum collection frequency of words)
# | min_df: 0 (minimum document frequency of words)
# | rm_top: 5 (the number of top words to be removed)
# | initial_k: 150 (the initial number of topics between 2 ~ 32767 The number of topics will be adjusted for data during training)
# | alpha: 0.1 (concentration coeficient of Dirichlet Process for document-table )
# | eta: 0.01 (hyperparameter of Dirichlet distribution for topic-word)
# | gamma: 0.1 (concentration coeficient of Dirichlet Process for table-topic)
# | seed: 205194031 (random seed)
# | trained in version 0.9.1
# |
# <Parameters>
# | alpha (concentration coeficient of Dirichlet Process for document-table)
# |  0.044955
# | eta (Dirichlet prior on the per-topic word distribution)
# |  0.01
# | gamma (concentration coeficient of Dirichlet Process for table-topic)
# |  22.36
# | Number of Topics: 159
# | Number of Tables: 25074
# |
# <Topics>
# | #0 (2304) : differ stimul increas tremor impuls
# | #1 (1129) : cr water bell age self_injuri
# | #2 (2838) : particip vr two group compar
# | #3 (19549) : treatment effect differ data infect
# | #4 (1453) : agnp teamwork se electrod particl
# | #5 (8421) : data map design research project
# | #6 (1914) : chemic concentr effect system measur
# | #7 (1357) : h differ explos crisi_map detect
# | #8 (2735) : child rotor peak increas patient
# | #9 (2831) : cell activ human effect product
# | #10 (3096) : water alloy age increas coupl
# | #11 (4133) : biofilm diffus snow water system
# | #12 (2694) : cassava show transform product r
# | #13 (25139) : gene plant protein genom differ
# | #14 (1989) : fossil sampl estim speci differ
# | #15 (1299) : particl tqi simul land_use trial
# | #16 (3816) : effect snail temperatur individu trait
# | #17 (16752) : neuron function cell network activ
# | #18 (2418) : exposur ec insect trend differ
# | #19 (1893) : read develop lago allerg differ
# | #20 (1484) : ratt potenti correl migrant hf
# | #21 (2095) : measur patient paint sampl date
# | #22 (3908) : ferment yeast wine associ product
# | #23 (3560) : system power compar switch current
# | #24 (3378) : plant herbivor interact prpc prion
# | #25 (88708) : speci soil increas effect differ
# | #26 (16475) : ozon simul chang observ increas
# | #27 (1992) : differ urban type forc task_failur
# | #28 (56032) : cell system method structur develop
# | #29 (2876) : measur evapor process hcl experi
# | #30 (34763) : problem algorithm set graph show
# | #31 (36596) : speci popul gene differ host
# | #32 (4446) : biowast treatment product increas spore
# | #33 (40034) : sampl melt data process rock
# | #34 (1799) : disrupt art cell indic characterist
# | #35 (48004) : aerosol measur particl cloud concentr
# | #36 (61960) : measur event product observ data
# | #37 (50064) : imag method data approach system
# | #38 (3347) : train oper delay reschedul passeng
# | #39 (7123) : imag tb activ tumor compar
# | #40 (60712) : system measur state electron observ
# | #41 (1971) : measur perform plant_height experi control
# | #42 (6292) : observ measur particl fire aerosol
# | #43 (2317) : phage detect asthma patient max
# | #44 (7297) : control robot system design motion
# | #45 (2096) : monkey lesion level recoveri mercuri
# | #46 (2780) : test wood adhes differ fire
# | #47 (1063) : test sonic rat pfu_mb gnp
# | #48 (2695) : cushion se biomass observ fault
# | #49 (1385) : measur depend distribut oa cul
# | #50 (1744) : effect rice steroid gene access
# | #51 (1521) : load zn flexibl applianc effect
# | #52 (1159) : soil zn effect applic two
# | #53 (1641) : np signal microdroplet index chang
# | #54 (1832) : plant sleep street_park respons cost
# | #55 (1434) : protein igf format layer neuron
# | #56 (11761) : system process network comput perform
# | #57 (17367) : der und die von de
# | #58 (2596) : microtubul spindl kar kinetochor spb
# | #59 (2217) : channel site capac receiv gener
# | #60 (15346) : patient imag measur method ass
# | #61 (2412) : event solut supplement child differ
# | #62 (16262) : cell infect vaccin cd_cell immun
# | #63 (2033) : pore cloud ice activ water
# | #64 (9540) : design optim approach method solut
# | #65 (2102) : de le la et fcd
# | #66 (3071) : structur semper approach eew o_
# | #67 (20665) : structur protein complex interact bind
# | #68 (54437) : patient train perform ass measur
# | #69 (82550) : measur structur materi perform design
# | #70 (2298) : access trend sort compar ocean
# | #71 (1037) : asp threat lysm_effector fm dlt
# | #72 (2775) : engin ignit combust household pre_chamber
# | #73 (2669) : exercis activ increas compar show
# | #74 (972) : state correct instanton farm_system spin_label
# | #75 (1073) : root effect root_growth al discontinu
# | #76 (1160) : wayfind navig navig_system rout instruct
# | #77 (27626) : estim effect price find data
# | #78 (3255) : transmiss asfv diseas asf infect
# | #79 (5054) : oxygen lake sediment methan si
# | #80 (5212) : sleep brain activ time regul
# | #81 (2071) : particl measur differ exposur correl
# | #82 (2836) : car activ gm mycolacton maiz
# | #83 (112264) : observ measur chang data simul
# | #84 (3927) : citi network observ scientist effect
# | #85 (2791) : mutat gene cancer alter data
# | #86 (35999) : system product energi technolog cost
# | #87 (2066) : ccm corros chang observ ccrit
# | #88 (32584) : observ seismic galaxi earthquak data
# | #89 (8549) : gene variant associ identifi genom
# | #90 (6442) : process equat space function gener
# | #91 (2949) : activ catalyst complex speci hb
# | #92 (57200) : process reaction materi structur co
# | #93 (18332) : infect cell bacteria antibiot pathogen
# | #94 (1525) : hg ebv flux infect patient
# | #95 (1385) : data famili_risk israd soil reward_process
# | #96 (3395) : observ fact tev flux energi
# | #97 (5334) : detector neutrino measur experi beam
# | #98 (1121) : first_last_mile hospit coffe mean iqr
# | #99 (3995) : plant effect function diver increas
# | #100 (3636) : process cut machin tool surfac
# | #101 (2883) : gene sequenc antibodi read bac
# | #102 (1541) : ep mn differ field al
# | #103 (5176) : behavior activ develop csn offspr
# | #104 (12968) : simul network vehicl demand differ
# | #105 (1650) : hyperacusi time invas salmonella tinnitu
# | #106 (144666) : cell protein activ function express
# | #107 (16039) : patient method data associ treatment
# | #108 (3991) : increas obes adipocyt mouse adipos_tissu
# | #109 (14263) : solut approxim problem method function
# | #110 (15333) : cell tissu bone il tendon
# | #111 (2320) : estim chang data eff plant
# | #112 (2119) : plant abcb differ measur ceramid
# | #113 (133756) : develop research data differ process
# | #114 (4347) : parasitoid includ differ aphid food
# | #115 (1221) : dr mtdna lysimet age differ
# | #116 (1023) : soil method trend score rhythmic_movement
# | #117 (11728) : polici effect product increas farmer
# | #118 (2355) : neuron measur materi inactiv song
# | #119 (1882) : architectur rossi citi rack design
# | #120 (1875) : broadcast network uic iodin ae_albopictu
# | #121 (2036) : malt composit effect particl wt
# | #122 (10946) : genom gene speci sequenc starch
# | #123 (2174) : system ef emiss street_garag_park measur
# | #124 (1399) : tax shp protocol urban uhi
# | #125 (8717) : process design optim approach integr
# | #126 (112567) : system method perform data approach
# | #127 (11245) : genotyp diet product popul genom
# | #128 (42649) : firm effect countri find differ
# | #129 (43161) : data activ differ time survey
# | #130 (23487) : process control differ effect task
# | #131 (4916) : mutat fit data effect sampl
# | #132 (3186) : activ simul pretreat time effect
# | #133 (2417) : iron child ice infect hepcidin
# | #134 (1604) : group al vo_max arb ash
# | #135 (2244) : pe chang effect show increas
# | #136 (2133) : pemf gii msc tile vlp
# | #137 (28773) : data system secur applic implement
# | #138 (14328) : sediment river soil carbon oc
# | #139 (29114) : gener theori show integr two
# | #140 (3643) : complex structur enzym method interact
# | #141 (2799) : seed express cca inform gene
# | #142 (7122) : magnet phase state materi show
# | #143 (5018) : protein sampl data method analysi
# | #144 (2502) : network observ mfd paramet effect
# | #145 (4107) : sampl method data microbiota iron
# | #146 (4690) : map imag perform method util
# | #147 (2225) : uc region surfac power increas
# | #148 (2730) : obes bmi slime memori increas
# | #149 (1408) : morph receiv applic sampler share
# | #150 (1117) : russia russian firstli secondli polit
# | #151 (209) : contract pipelight arbitr gmo attitud
# | #152 (256) : genet_engin hr flight hypox photoreceptor
# | #153 (117) : jfj snowpack kl tempor_evolut gpgpu
# | #154 (197) : sensor calibr frequenc sewer prha
# | #155 (189) : gel mine ro pi site
# | #156 (103) : feedthrough lin street_canyon pisim man
# | #158 (78) : reservoir turbid_current bagta particl quasi_stationari
# | #160 (121) : repertoir duckiepond ml spinosyn educ
# |

# %%
def train_HDP()
